# %% [markdown]
# # Assignment 1
# Choose a personality on Wikipedia who
# has the same name as yours, save it as a text document, and do the exercises given below on it.
#
# Show your working to get credit for the following tasks:
#
# 1. convert the complete text to lower case.
# 2. remove all the stop words.
# 3. Apply POS tagging on the whole text
# 4. Lemmatize the most frequently occurring 5 adjectives
# 5. Stem the least frequently occurring 5 verbs.
# 6. Show the concordance for a word of your choice.
# 7. Draw the dispersion plot for 2 frequently occurring terms in the document.

# %%
import bs4
import requests

# %%
res = requests.get("https://en.wikipedia.org/wiki/Vishal_(actor)")
res.raise_for_status()
corpus = bs4.BeautifulSoup(res.text,"html.parser")
for i in corpus.select('p'):
    print(i.getText())
# Out:
# Vishal Krishna Reddy (born 29 August 1977),[1] also known as Vishal, is an Indian actor and film producer who works at Tamil cinema. The younger son of film producer G. K. Reddy, Vishal studied Visual Communications at Loyola College, Chennai. Best known for his roles in action films, he produces films under his production company, Vishal Film Factory.[2]
#
# Vishal made an entrance into the film industry as an assistant director for Arjun. He then became an actor and played his first lead role in the romantic thriller Chellamae (2004), before going on to star in the commercially successful action films Sandakozhi, Thimiru, Thaamirabharani and Malaikottai.[3] Following a series of unsuccessful films at the box office, Vishal chose to create his own production studio and has since produced and worked on profitable ventures such as Pandiya Naadu (2013), Naan Sigappu Manithan (2014) and Poojai (2014).[4]
#
# Vishal was elected as the General Secretary of the Nadigar Sangam in October 2015 after initiating a movement against the previous committee.[5] He was expelled from Tamil Film Producers' Council (TFPC) for remarks against the council.[6][7] Later in April 2017, he won the election and got elected as President of Tamil Film Producers Council.
#
# Vishal Krishna Reddy was born on 29 August 1977[8][9] into a Telugu family in Chennai, Tamil Nadu.[10] His father GK Reddy is a businessman and a film producer for Telugu and Tamil films.[11] His elder brother Vikram Krishna is also an actor and producer who has produced several of Vishal's films.[12] Vishal obtained his degree in visual communications from Loyola College, Chennai.[13]
#
# Vishal assisted actor-director Arjun Sarja in his venture Vedham (2001), and a producer spotted Vishal on the sets of the film and signed him to appear in an acting role in Gandhi Krishna's Chellamae (2004).[14][15] Accepting the role, Vishal prepared by joining Koothu-P-Pattarai to hone his acting skills and played the protagonist role of Raghunandan, whose wife is kidnapped by her childhood friend.[15] A critic described his performance is "apt" but "there was plenty left to hone".[16][17] His next film was Sandakozhi (2005) with N. Linguswamy, who had previously worked with his father's production house as an assistant director.[18] Vishal was described to have "improved from his Chellamae days" and "clicked as an action hero".[19] Film journalists stated that he was "the fastest rising action hero" of the time.[20] After a cameo as himself in Sasi's Dishyum (2006), he went on to appear in Tarun Gopi's action film Thimiru (2006). The film opened to mixed reviews with Vishal being praised for his intense performance with a critic calling his performance "the film's only strength and, to an extent, making up for the weak script and poor characterisation".[21] The film became Vishal's third consecutive commercial success, and he began to emerge in Tamil films.[22]
#
# His next film, the political action drama Sivappathigaram (2006), directed by Karu Pazhaniappan was a failure financially despite favourable reviews.[23] His next film was released in January 2007, Hari's multi-starring family action drama Thaamirabharani (2007) and the film went on to gain considerable box office success, carrying good reports amidst other big budget releases.[24][25] Later in the year, he appeared in Boopathy Pandian's Malaikottai (2007), a comedy entertainer. In his first full-length comic role, Vishal received mixed feedback for his portrayal from critics, with Rediff stating that he is "a far cry from the rather endearing young man in Sandakozhi", whilst describing his performance as "cringe-able".[26] Behindwoods stated it as an "Average masala-mix entertainer".[27] The film took a large opening and was declared a blockbuster, featuring in the top 10 at behindwoods box office. In the year 2008, for the first time, Vishal portrayed a police officer in Sathyam, which became a commercial failure at the box office. Then both his films Thoranai (2009) and Theeradha Vilaiyattu Pillai (2010) were just average grossers. Additionally, the box-office duds, Sathyam and Thoranai, both of which were bilingual in Tamil and Telugu, failed to establish his popularity in Telugu cinema.[28]
#
# Vishal was then given the opportunity to feature in Bala's dark comedy Avan Ivan (2011), after being recommended to the director by his friend Arya. Portraying a village stage actor with a squint, Vishal had severe eye pain and headaches, and he also had a serious muscular injury on sets.[29] The film opened to mixed reviews, though Vishal's performance won positive reviews. Indiaglitz stated that Vishal delivered an "award winning performance" and that his "mannerisms and body language give you goosebumps". The reviewer further cited that "Vishal's spontaneous response to his mentor's death in the movie is touching. His demonstration of Navarasas in front of actor Suriya will melt you in tears".[30][31] Vishal played the role of a police officer in his following release Vedi (2011), directed by Prabhu Deva, which was declared an instant flop at the box office.[32]
#
# In the 2013 film Samar, Vishal played a forest trek guide. Behindwoods stated that he "rocks in the action sequences".[33][34] Following a cameo role in Theeya Velai Seiyyanum Kumaru, he starred in the action films Pattathu Yaanai and Pandiya Naadu. The latter was Vishal's debut production venture.[35][36] Vishal opted to produce and collaborate with Thiru for a third venture Naan Sigappu Manithan (2014), a revenge drama, in which his character had narcolepsy. To prepare for the lead role, Vishal read up and studied real life case studies of people with the disorder, citing that there were no references from cinema which he could watch and learn. Then he had acted under director Hari for the second time in Poojai (2014), which did somewhat good business at the box office. In 2015, he acted two films, namely, Aambala and Paayum Puli.[37][38]
#
# In 2016, he appeared in three movies; Kathakali, Marudhu and Kaththi Sandai. The first two were average grossers, while Kaththi Sandai became a flop at the box office. In January 2017, Vishal signed his debut Malayalam film, as the main antagonist in the Mohanlal-starrer Villain, directed by B. Unnikrishnan.[39][40] In September 2017, Vishal played a detective in Thupparivaalan directed by Mysskin which was loosely based on the British writer Arthur Conan Doyle's detective character, Sherlock Holmes. The film was a commercial success and was appreciated by audiences and critics.[41] In 2018, Vishal had two major releases. The first one was Irumbu Thirai directed by newcomer P. S. Mithran which released in May 2018.[42] And second was Sandakozhi 2 released in October 2018 was written and directed by N. Linguswamy. A sequel to the successful Sandakozhi (2005), the film stars Vishal in his 25th film.[43] The film turned out to be an average grosser.[44] In 2019, he did one movie titled Action directed by Sundar C.[45] The film received mixed reviews and was a box office failure.[46] In 2021, he acted in the action thriller Chakra directed my newcomer M.S Anandan. The film which released on 19 February, received mixed reviews from critics and audience.[47]
#
# He was elected as President of Tamil Film Producers Council election, which was held on 2 April 2017.[48][49][50] Apart from this, Vishal is also a staunch advocate against online piracy since 2014, having started an anti-piracy cell.[51]
#
# He made his television début in October 2018 as a host of Sun Naam Oruvar, a talk show airing on Sun TV.[52][53]
#
# Vishal filed his nomination as an independent candidate for the by-poll to Radhakrishnan Nagar constituency in Chennai, which fell vacant following Jayalalithaa's death in December 2017.[54] But his nomination was rejected.[55]
#
# Vishal was arrested by police in December 2018 when he tried to enter inside the Tamil Film Producers Council in T Nagar, Chennai by forcefully trying to break the lock. The council was locked by 300 film producers alleging that Vishal failed to fulfil his promises during the elections in 2015.[56]
#
# Vishal made his debut as a  playback singer in Madha Gaja Raja, an unreleased film directed by Sundar C, crapping up for the song My Dear Loveru.

# %%
corpus
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Vishal (actor) - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"89839686-ba0a-4362-ad77-8d5819dd9b11","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Vishal_(actor)","wgTitle":"Vishal (actor)","wgCurRevisionId":1109152472,"wgRevisionId":1109152472,"wgArticleId":11541203,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All articles with bare URLs for citations","Articles with bare URLs for citations from August 2022","CS1 maint: unfit URL","Articles with short description","Short description is different from Wikidata","Use Indian English from October 2015","All Wikipedia articles written in Indian English"
# ,"Use dmy dates from March 2022","Articles with hCards","Commons category link is on Wikidata","Articles with MusicBrainz identifiers","Living people","Male actors in Telugu cinema","Male actors in Tamil cinema","Male actors from Visakhapatnam","Indian male film actors","People from Visakhapatnam district","Male actors from Andhra Pradesh","Don Bosco schools alumni","Loyola College, Chennai alumni","21st-century Indian male actors","1977 births","Film producers from Andhra Pradesh","Telugu male actors","Male actors in Malayalam cinema"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Vishal_(actor)","wgRelevantArticleId":11541203,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,
# "watchlist":true,"tagline":false},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":40000,"wgNoticeProject":"wikipedia","wgVector2022PreviewPages":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q3534989","GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":
# "ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.uls.compactlinks","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});});});</script>
# <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <meta content="MediaWiki 1.39.0-wmf.28" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-crossorigin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/3/30/Vishal2018.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/3/30/Vishal2018.jpg/800px-Vishal2018.jpg" property="og:image"/>
# <meta content="800" property="og:image:width"/>
# <meta content="800" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/3/30/Vishal2018.jpg/640px-Vishal2018.jpg" property="og:image"/>
# <meta content="640" property="og:image:width"/>
# <meta content="640" property="og:image:height"/>
# <meta content="width=1000" name="viewport"/>
# <meta content="Vishal (actor) - Wikipedia" property="og:title"/>
# <meta content="website" property="og:type"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//en.m.wikipedia.org/wiki/Vishal_(actor)" media="only screen and (max-width: 720px)" rel="alternate"/>
# <link href="/w/index.php?title=Vishal_(actor)&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
# <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="https://creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
# <link href="https://en.wikipedia.org/wiki/Vishal_(actor)" rel="canonical"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Vishal_actor rootpage-Vishal_actor skin-vector action-view skin-vector-legacy vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-sticky-header-edit-disabled vector-feature-table-of-contents-disabled vector-feature-visual-enhancement-next-disabled"><div class="noprint" id="mw-page-base"></div>
# <div class="noprint" id="mw-head-base"></div>
# <div class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators">
# </div>
# <h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">Vishal (actor)</span></h1>
# <div class="vector-body" id="bodyContent">
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
# <div id="contentSub"></div>
# <div id="contentSub2"></div>
# <div id="jump-to-nav"></div>
# <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# <a class="mw-jump-link" href="#searchInput">Jump to search</a>
# <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">Indian actor and producer</div>
# <p class="mw-empty-elt">
# </p>
# <style data-mw-deduplicate="TemplateStyles:r1066479718">.mw-parser-output .infobox-subbox{padding:0;border:none;margin:-3px;width:auto;min-width:100%;font-size:100%;clear:none;float:none;background-color:transparent}.mw-parser-output .infobox-3cols-child{margin:auto}.mw-parser-output .infobox .navbar{font-size:100%}body.skin-minerva .mw-parser-output .infobox-header,body.skin-minerva .mw-parser-output .infobox-subheader,body.skin-minerva .mw-parser-output .infobox-above,body.skin-minerva .mw-parser-output .infobox-title,body.skin-minerva .mw-parser-output .infobox-image,body.skin-minerva .mw-parser-output .infobox-full-data,body.skin-minerva .mw-parser-output .infobox-below{text-align:center}</style><table class="infobox biography vcard"><tbody><tr><th class="infobox-above" colspan="2" style="font-size:125%;"><div class="fn" style="display:inline">Vishal</div></th></tr><tr><td class="infobox-image" colspan="2"><a class="image" href="/wiki/File:Vishal2018.jpg"><img alt="Vishal2018.jpg" data-file-height="1080" data-file-width="1080" decoding="async" height="220" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/30/Vishal2018.jpg/220px-Vishal2018.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/30/Vishal2018.jpg/330px-Vishal2018.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/30/Vishal2018.jpg/440px-Vishal2018.jpg 2x" width="220"/></a><div class="infobox-caption">Vishal in 2018</div></td></tr><tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><div class="nickname" style="display:inline">Vishal Krishna Reddy</div><br/><span style="display:none"> (<span class="bday">1977-08-29</span>) </span>29 August 1977<span class="noprint ForceAgeToShow"> (age 45)</span><br/><div class="birthplace" style="display:inline"><a class="mw-redirect" href="/wiki/Madras" title="Madras">Madras</a>, <a href="/wiki/Tamil_Nadu" title="Tamil Nadu">Tamil Nadu</a>, India</div></td></tr><tr><th class="infobox-label" scope="row">Alma mater</th><td class="infobox-data"><a href="/wiki/Loyola_College,_Chennai" title="Loyola College, Chennai">Loyola College, Chennai</a></td></tr><tr><th class="infobox-label" scope="row">Occupation</th><td class="infobox-data role">Actor, film producer</td></tr><tr><th class="infobox-label" scope="row">Years active</th><td class="infobox-data"><a href="/wiki/2004_in_film" title="2004 in film">2004</a>–present</td></tr><tr><th class="infobox-label" scope="row">Relatives</th><td class="infobox-data"><a href="/wiki/Sriya_Reddy" title="Sriya Reddy">Sriya Reddy</a> (sister-in-law)</td></tr></tbody></table>
# <p><b>Vishal Krishna Reddy</b> (born 29 August 1977),<sup class="reference" id="cite_ref-age_1-0"><a href="#cite_note-age-1">[1]</a></sup> also known as <b>Vishal</b>, is an Indian actor and film producer who works at <a href="/wiki/Tamil_cinema" title="Tamil cinema">Tamil cinema</a>. The younger son of film producer G. K. Reddy, Vishal studied Visual Communications at Loyola College, Chennai. Best known for his roles in <a href="/wiki/Action_film" title="Action film">action films</a>, he produces films under his <a href="/wiki/Production_company" title="Production company">production company</a>, <a href="/wiki/Vishal_Film_Factory" title="Vishal Film Factory">Vishal Film Factory</a>.<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>
# </p><p>Vishal made an entrance into the film industry as an assistant director for <a href="/wiki/Arjun_Sarja" title="Arjun Sarja">Arjun</a>. He then became an actor and played his first lead role in the romantic thriller <i><a href="/wiki/Chellamae" title="Chellamae">Chellamae</a></i> (2004), before going on to star in the commercially successful action films <i><a href="/wiki/Sandakozhi" title="Sandakozhi">Sandakozhi</a></i>, <i><a href="/wiki/Thimiru" title="Thimiru">Thimiru</a></i>, <i><a href="/wiki/Thaamirabharani" title="Thaamirabharani">Thaamirabharani</a></i> and <i><a href="/wiki/Malaikottai" title="Malaikottai">Malaikottai</a></i>.<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup> Following a series of unsuccessful films at the box office, Vishal chose to create his own production studio and has since produced and worked on profitable ventures such as <i><a href="/wiki/Pandiya_Naadu" title="Pandiya Naadu">Pandiya Naadu</a></i> (2013), <i><a href="/wiki/Naan_Sigappu_Manithan_(2014_film)" title="Naan Sigappu Manithan (2014 film)">Naan Sigappu Manithan</a></i> (2014) and <i><a href="/wiki/Poojai" title="Poojai">Poojai</a></i> (2014).<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup>
# </p><p>Vishal was elected as the General Secretary of the <a href="/wiki/Nadigar_Sangam" title="Nadigar Sangam">Nadigar Sangam</a> in October 2015 after initiating a movement against the previous committee.<sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup> He was expelled from <a href="/wiki/Tamil_Film_Producers_Council" title="Tamil Film Producers Council">Tamil Film Producers' Council</a> (TFPC) for remarks against the council.<sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup><sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup> Later in April 2017, he won the election and got elected as President of <a href="/wiki/Tamil_Film_Producers_Council" title="Tamil Film Producers Council">Tamil Film Producers Council</a>.
# </p>
# <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Early_life"><span class="tocnumber">1</span> <span class="toctext">Early life</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Acting_career"><span class="tocnumber">2</span> <span class="toctext">Acting career</span></a>
# <ul>
# <li class="toclevel-2 tocsection-3"><a href="#2004–2011"><span class="tocnumber">2.1</span> <span class="toctext">2004–2011</span></a></li>
# <li class="toclevel-2 tocsection-4"><a href="#2013–present"><span class="tocnumber">2.2</span> <span class="toctext">2013–present</span></a></li>
# <li class="toclevel-2 tocsection-5"><a href="#Tamil_Film_Producers_Council_(2017–present)"><span class="tocnumber">2.3</span> <span class="toctext">Tamil Film Producers Council (2017–present)</span></a></li>
# <li class="toclevel-2 tocsection-6"><a href="#Television"><span class="tocnumber">2.4</span> <span class="toctext">Television</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-7"><a href="#Politics"><span class="tocnumber">3</span> <span class="toctext">Politics</span></a></li>
# <li class="toclevel-1 tocsection-8"><a href="#Legal_issues"><span class="tocnumber">4</span> <span class="toctext">Legal issues</span></a></li>
# <li class="toclevel-1 tocsection-9"><a href="#Playback_singing"><span class="tocnumber">5</span> <span class="toctext">Playback singing</span></a></li>
# <li class="toclevel-1 tocsection-10"><a href="#Filmography"><span class="tocnumber">6</span> <span class="toctext">Filmography</span></a>
# <ul>
# <li class="toclevel-2 tocsection-11"><a href="#Film"><span class="tocnumber">6.1</span> <span class="toctext">Film</span></a></li>
# <li class="toclevel-2 tocsection-12"><a href="#Television_2"><span class="tocnumber">6.2</span> <span class="toctext">Television</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-13"><a href="#Notes"><span class="tocnumber">7</span> <span class="toctext">Notes</span></a></li>
# <li class="toclevel-1 tocsection-14"><a href="#References"><span class="tocnumber">8</span> <span class="toctext">References</span></a></li>
# <li class="toclevel-1 tocsection-15"><a href="#External_links"><span class="tocnumber">9</span> <span class="toctext">External links</span></a></li>
# </ul>
# </div>
# <h2><span class="mw-headline" id="Early_life">Early life</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Vishal_(actor)&amp;action=edit&amp;section=1" title="Edit section: Early life">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="thumb tright"><div class="thumbinner" style="width:194px;"><a class="image" href="/wiki/File:Vishal_Karunanidhi_GK_Reddy.jpg"><img alt="" class="thumbimage" data-file-height="814" data-file-width="544" decoding="async" height="288" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Vishal_Karunanidhi_GK_Reddy.jpg/192px-Vishal_Karunanidhi_GK_Reddy.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Vishal_Karunanidhi_GK_Reddy.jpg/289px-Vishal_Karunanidhi_GK_Reddy.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Vishal_Karunanidhi_GK_Reddy.jpg/385px-Vishal_Karunanidhi_GK_Reddy.jpg 2x" width="192"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:Vishal_Karunanidhi_GK_Reddy.jpg" title="Enlarge"></a></div>Vishal with his father G. K. Reddy and late <a href="/wiki/Politician" title="Politician">politician</a> <a href="/wiki/M._Karunanidhi" title="M. Karunanidhi">M. Karunanidhi</a>.</div></div></div><p>Vishal Krishna Reddy was born on 29 August 1977<sup class="reference" id="cite_ref-age2_8-0"><a href="#cite_note-age2-8">[8]</a></sup><sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup> into a <a href="/wiki/Telugu_language" title="Telugu language">Telugu</a> family in <a class="mw-redirect" href="/wiki/Chennai,_Tamil_Nadu" title="Chennai, Tamil Nadu">Chennai, Tamil Nadu</a>.<sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup> His father GK Reddy is a businessman and a film producer for <a href="/wiki/Telugu_language" title="Telugu language">Telugu</a> and <a href="/wiki/Tamil_language" title="Tamil language">Tamil</a> films.<sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup> His elder brother <a href="/wiki/Vikram_Krishna" title="Vikram Krishna">Vikram Krishna</a> is also an actor and producer who has produced several of Vishal's films.<sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup> Vishal obtained his degree in <a class="mw-redirect" href="/wiki/Visual_communications" title="Visual communications">visual communications</a> from <a href="/wiki/Loyola_College,_Chennai" title="Loyola College, Chennai">Loyola College, Chennai</a>.<sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[13]</a></sup>
# </p><h2><span class="mw-headline" id="Acting_career">Acting career</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Vishal_(actor)&amp;action=edit&amp;section=2" title="Edit section: Acting career">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <h3><span id="2004.E2.80.932011"></span><span class="mw-headline" id="2004–2011">2004–2011</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Vishal_(actor)&amp;action=edit&amp;section=3" title="Edit section: 2004–2011">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>Vishal assisted actor-director <a href="/wiki/Arjun_Sarja" title="Arjun Sarja">Arjun Sarja</a> in his venture <i><a href="/wiki/Vedham" title="Vedham">Vedham</a></i> (2001), and a producer spotted Vishal on the sets of the film and signed him to appear in an acting role in <a href="/wiki/Gandhi_Krishna" title="Gandhi Krishna">Gandhi Krishna</a>'s <i><a href="/wiki/Chellamae" title="Chellamae">Chellamae</a></i> (2004).<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[14]</a></sup><sup class="reference" id="cite_ref-intglitz_15-0"><a href="#cite_note-intglitz-15">[15]</a></sup> Accepting the role, Vishal prepared by joining <a href="/wiki/Koothu-P-Pattarai" title="Koothu-P-Pattarai">Koothu-P-Pattarai</a> to hone his acting skills and played the protagonist role of Raghunandan, whose wife is kidnapped by her childhood friend.<sup class="reference" id="cite_ref-intglitz_15-1"><a href="#cite_note-intglitz-15">[15]</a></sup> A critic described his performance is "apt" but "there was plenty left to hone".<sup class="reference" id="cite_ref-chelhind_16-0"><a href="#cite_note-chelhind-16">[16]</a></sup><sup class="reference" id="cite_ref-chelsify_17-0"><a href="#cite_note-chelsify-17">[17]</a></sup> His next film was <i><a href="/wiki/Sandakozhi" title="Sandakozhi">Sandakozhi</a></i> (2005) with <a class="mw-redirect" href="/wiki/N._Linguswamy" title="N. Linguswamy">N. Linguswamy</a>, who had previously worked with his father's production house as an assistant director.<sup class="reference" id="cite_ref-sandlingu_18-0"><a href="#cite_note-sandlingu-18">[18]</a></sup> Vishal was described to have "improved from his <i>Chellamae</i> days" and "clicked as an action hero".<sup class="reference" id="cite_ref-sandasify_19-0"><a href="#cite_note-sandasify-19">[19]</a></sup> Film journalists stated that he was "the fastest rising action hero" of the time.<sup class="reference" id="cite_ref-sandahit_20-0"><a href="#cite_note-sandahit-20">[20]</a></sup> After a cameo as himself in <a href="/wiki/Sasi_(director)" title="Sasi (director)">Sasi</a>'s <i><a href="/wiki/Dishyum" title="Dishyum">Dishyum</a></i> (2006), he went on to appear in <a href="/wiki/Tarun_Gopi" title="Tarun Gopi">Tarun Gopi</a>'s action film <i><a href="/wiki/Thimiru" title="Thimiru">Thimiru</a></i> (2006). The film opened to mixed reviews with Vishal being praised for his intense performance with a critic calling his performance "the film's only strength and, to an extent, making up for the weak script and poor characterisation".<sup class="reference" id="cite_ref-rediffthi_21-0"><a href="#cite_note-rediffthi-21">[21]</a></sup> The film became Vishal's third consecutive commercial success, and he began to emerge in Tamil films.<sup class="reference" id="cite_ref-bwdvishal_22-0"><a href="#cite_note-bwdvishal-22">[22]</a></sup>
# </p><p>His next film, the political action drama <i><a href="/wiki/Sivappathigaram" title="Sivappathigaram">Sivappathigaram</a></i> (2006), directed by <a class="mw-redirect" href="/wiki/Karu_Pazhaniappan" title="Karu Pazhaniappan">Karu Pazhaniappan</a> was a failure financially despite favourable reviews.<sup class="reference" id="cite_ref-spgvishal_23-0"><a href="#cite_note-spgvishal-23">[23]</a></sup> His next film was released in January 2007, <a href="/wiki/Hari_(director)" title="Hari (director)">Hari</a>'s multi-starring family action drama <i><a href="/wiki/Thaamirabharani" title="Thaamirabharani">Thaamirabharani</a></i> (2007) and the film went on to gain considerable box office success, carrying good reports amidst other big budget releases.<sup class="reference" id="cite_ref-tbvishal_24-0"><a href="#cite_note-tbvishal-24">[24]</a></sup><sup class="reference" id="cite_ref-tbhbo_25-0"><a href="#cite_note-tbhbo-25">[25]</a></sup> Later in the year, he appeared in <a href="/wiki/Boopathy_Pandian" title="Boopathy Pandian">Boopathy Pandian</a>'s <i><a href="/wiki/Malaikottai" title="Malaikottai">Malaikottai</a></i> (2007), a comedy entertainer. In his first full-length comic role, Vishal received mixed feedback for his portrayal from critics, with <a class="mw-redirect" href="/wiki/Rediff" title="Rediff">Rediff</a> stating that he is "a far cry from the rather endearing young man in Sandakozhi", whilst describing his performance as "cringe-able".<sup class="reference" id="cite_ref-bwdsify_26-0"><a href="#cite_note-bwdsify-26">[26]</a></sup> Behindwoods stated it as an "Average masala-mix entertainer".<sup class="reference" id="cite_ref-mkbwd_27-0"><a href="#cite_note-mkbwd-27">[27]</a></sup> The film took a large opening and was declared a blockbuster, featuring in the top 10 at behindwoods box office. In the year 2008, for the first time, Vishal portrayed a police officer in <i><a href="/wiki/Satyam_(2008_film)" title="Satyam (2008 film)">Sathyam</a></i>, which became a commercial failure at the box office. Then both his films <i><a href="/wiki/Thoranai" title="Thoranai">Thoranai</a></i> (2009) and <i><a href="/wiki/Theeradha_Vilaiyattu_Pillai" title="Theeradha Vilaiyattu Pillai">Theeradha Vilaiyattu Pillai</a></i> (2010) were just average grossers. Additionally, the box-office duds, <i>Sathyam</i> and <i>Thoranai</i>, both of which were bilingual in Tamil and Telugu, failed to establish his popularity in Telugu cinema.<sup class="reference" id="cite_ref-BVS_Prakash_28-0"><a href="#cite_note-BVS_Prakash-28">[28]</a></sup>
# </p><p>Vishal was then given the opportunity to feature in <a href="/wiki/Bala_(director)" title="Bala (director)">Bala</a>'s dark comedy <i><a href="/wiki/Avan_Ivan" title="Avan Ivan">Avan Ivan</a></i> (2011), after being recommended to the director by his friend <a href="/wiki/Arya_(actor)" title="Arya (actor)">Arya</a>. Portraying a village stage actor with a squint, Vishal had severe eye pain and headaches, and he also had a serious muscular injury on sets.<sup class="reference" id="cite_ref-squint_29-0"><a href="#cite_note-squint-29">[29]</a></sup> The film opened to mixed reviews, though Vishal's performance won positive reviews. <i>Indiaglitz</i> stated that Vishal delivered an "award winning performance" and that his "mannerisms and body language give you goosebumps". The reviewer further cited that "Vishal's spontaneous response to his mentor's death in the movie is touching. His demonstration of <i>Navarasas</i> in front of actor Suriya will melt you in tears".<sup class="reference" id="cite_ref-30"><a href="#cite_note-30">[30]</a></sup><sup class="reference" id="cite_ref-31"><a href="#cite_note-31">[31]</a></sup> Vishal played the role of a police officer in his following release <i><a href="/wiki/Vedi_(film)" title="Vedi (film)">Vedi</a></i> (2011), directed by <a href="/wiki/Prabhu_Deva" title="Prabhu Deva">Prabhu Deva</a>, which was declared an instant flop at the box office.<sup class="reference" id="cite_ref-fut_32-0"><a href="#cite_note-fut-32">[32]</a></sup>
# </p>
# <h3><span id="2013.E2.80.93present"></span><span class="mw-headline" id="2013–present">2013–present</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Vishal_(actor)&amp;action=edit&amp;section=4" title="Edit section: 2013–present">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="thumb tright"><div class="thumbinner" style="width:195px;"><a class="image" href="/wiki/File:Vishal_Krishna.jpg"><img alt="" class="thumbimage" data-file-height="557" data-file-width="374" decoding="async" height="288" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f5/Vishal_Krishna.jpg/193px-Vishal_Krishna.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f5/Vishal_Krishna.jpg/290px-Vishal_Krishna.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/f/f5/Vishal_Krishna.jpg 2x" width="193"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:Vishal_Krishna.jpg" title="Enlarge"></a></div>Vishal in 2013.</div></div></div><p>In the 2013 film <i><a href="/wiki/Samar_(2013_film)" title="Samar (2013 film)">Samar</a></i>, Vishal played a forest trek guide. Behindwoods stated that he "rocks in the action sequences".<sup class="reference" id="cite_ref-33"><a href="#cite_note-33">[33]</a></sup><sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[34]</a></sup> Following a cameo role in <i><a href="/wiki/Theeya_Velai_Seiyyanum_Kumaru" title="Theeya Velai Seiyyanum Kumaru">Theeya Velai Seiyyanum Kumaru</a></i>, he starred in the action films <i><a href="/wiki/Pattathu_Yaanai" title="Pattathu Yaanai">Pattathu Yaanai</a></i> and <i><a href="/wiki/Pandiya_Naadu" title="Pandiya Naadu">Pandiya Naadu</a></i>. The latter was Vishal's debut production venture.<sup class="reference" id="cite_ref-35"><a href="#cite_note-35">[35]</a></sup><sup class="reference" id="cite_ref-36"><a href="#cite_note-36">[36]</a></sup> Vishal opted to produce and collaborate with Thiru for a third venture <i><a href="/wiki/Naan_Sigappu_Manithan_(2014_film)" title="Naan Sigappu Manithan (2014 film)">Naan Sigappu Manithan</a></i> (2014), a revenge drama, in which his character had <a href="/wiki/Narcolepsy" title="Narcolepsy">narcolepsy</a>. To prepare for the lead role, Vishal read up and studied real life case studies of people with the disorder, citing that there were no references from cinema which he could watch and learn. Then he had acted under director <a href="/wiki/Hari" title="Hari">Hari</a> for the second time in <i><a href="/wiki/Poojai" title="Poojai">Poojai</a></i> (2014), which did somewhat good business at the box office. In 2015, he acted two films, namely, <i><a href="/wiki/Aambala" title="Aambala">Aambala</a></i> and <i><a href="/wiki/Paayum_Puli_(2015_film)" title="Paayum Puli (2015 film)">Paayum Puli</a></i>.<sup class="reference" id="cite_ref-37"><a href="#cite_note-37">[37]</a></sup><sup class="reference" id="cite_ref-38"><a href="#cite_note-38">[38]</a></sup>
# </p><p>In 2016, he appeared in three movies; <i><a href="/wiki/Kathakali_(film)" title="Kathakali (film)">Kathakali</a></i>, <i><a href="/wiki/Marudhu" title="Marudhu">Marudhu</a></i> and <i><a href="/wiki/Kaththi_Sandai" title="Kaththi Sandai">Kaththi Sandai</a></i>. The first two were average grossers, while <i><a href="/wiki/Kaththi_Sandai" title="Kaththi Sandai">Kaththi Sandai</a></i> became a flop at the box office. In January 2017, Vishal signed his debut <a href="/wiki/Malayalam" title="Malayalam">Malayalam</a> film, as the main antagonist in the <a href="/wiki/Mohanlal" title="Mohanlal">Mohanlal</a>-starrer <i><a href="/wiki/Villain_(2017_film)" title="Villain (2017 film)">Villain</a></i>, directed by <a href="/wiki/B._Unnikrishnan" title="B. Unnikrishnan">B. Unnikrishnan</a>.<sup class="reference" id="cite_ref-auto1_39-0"><a href="#cite_note-auto1-39">[39]</a></sup><sup class="reference" id="cite_ref-40"><a href="#cite_note-40">[40]</a></sup> In September 2017, Vishal played a detective in <i><a href="/wiki/Thupparivaalan" title="Thupparivaalan">Thupparivaalan</a></i> directed by <a href="/wiki/Mysskin" title="Mysskin">Mysskin</a> which was loosely based on the British writer <a href="/wiki/Arthur_Conan_Doyle" title="Arthur Conan Doyle">Arthur Conan Doyle</a>'s detective character, <a href="/wiki/Sherlock_Holmes" title="Sherlock Holmes">Sherlock Holmes</a>. The film was a commercial success and was appreciated by audiences and critics.<sup class="reference" id="cite_ref-41"><a href="#cite_note-41">[41]</a></sup> In 2018, Vishal had two major releases. The first one was <i><a href="/wiki/Irumbu_Thirai_(2018_film)" title="Irumbu Thirai (2018 film)">Irumbu Thirai</a></i> directed by newcomer <a href="/wiki/P._S._Mithran" title="P. S. Mithran">P. S. Mithran</a> which released in May 2018.<sup class="reference" id="cite_ref-42"><a href="#cite_note-42">[42]</a></sup> And second was <i><a href="/wiki/Sandakozhi_2" title="Sandakozhi 2">Sandakozhi 2</a></i> released in October 2018 was written and directed by <a class="mw-redirect" href="/wiki/N._Linguswamy" title="N. Linguswamy">N. Linguswamy</a>. A sequel to the successful <i>Sandakozhi</i> (2005), the film stars Vishal in his 25th film.<sup class="reference" id="cite_ref-43"><a href="#cite_note-43">[43]</a></sup> The film turned out to be an average grosser.<sup class="reference" id="cite_ref-44"><a href="#cite_note-44">[44]</a></sup> In 2019, he did one movie titled <i><a href="/wiki/Action_(2019_film)" title="Action (2019 film)">Action</a></i> directed by <a href="/wiki/Sundar_C." title="Sundar C.">Sundar C.</a><sup class="reference" id="cite_ref-45"><a href="#cite_note-45">[45]</a></sup> The film received mixed reviews and was a box office failure.<sup class="reference" id="cite_ref-46"><a href="#cite_note-46">[46]</a></sup> In 2021, he acted in the <a class="mw-redirect" href="/wiki/Action_thriller" title="Action thriller">action thriller</a> <i><a href="/wiki/Chakra_(2021_film)" title="Chakra (2021 film)">Chakra</a></i> directed my newcomer M.S Anandan. The film which released on 19 February, received mixed reviews from critics and audience.<sup class="reference" id="cite_ref-47"><a href="#cite_note-47">[47]</a></sup>
# </p>
# <h3><span id="Tamil_Film_Producers_Council_.282017.E2.80.93present.29"></span><span class="mw-headline" id="Tamil_Film_Producers_Council_(2017–present)">Tamil Film Producers Council (2017–present)</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Vishal_(actor)&amp;action=edit&amp;section=5" title="Edit section: Tamil Film Producers Council (2017–present)">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>He was elected as <i>President</i> of <a href="/wiki/Tamil_Film_Producers_Council" title="Tamil Film Producers Council">Tamil Film Producers Council</a> election, which was held on 2 April 2017.<sup class="reference" id="cite_ref-48"><a href="#cite_note-48">[48]</a></sup><sup class="reference" id="cite_ref-49"><a href="#cite_note-49">[49]</a></sup><sup class="reference" id="cite_ref-50"><a href="#cite_note-50">[50]</a></sup> Apart from this, Vishal is also a staunch advocate against <a href="/wiki/Online_piracy" title="Online piracy">online piracy</a> since 2014, having started an anti-piracy cell.<sup class="reference" id="cite_ref-51"><a href="#cite_note-51">[51]</a></sup>
# </p>
# <h3><span class="mw-headline" id="Television">Television</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Vishal_(actor)&amp;action=edit&amp;section=6" title="Edit section: Television">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>He made his television début in October 2018 as a host of <i><a href="/wiki/Sun_Naam_Oruvar" title="Sun Naam Oruvar">Sun Naam Oruvar</a></i>, a talk show airing on <a href="/wiki/Sun_TV_(India)" title="Sun TV (India)">Sun TV</a>.<sup class="reference" id="cite_ref-52"><a href="#cite_note-52">[52]</a></sup><sup class="reference" id="cite_ref-53"><a href="#cite_note-53">[53]</a></sup>
# </p>
# <h2><span class="mw-headline" id="Politics">Politics</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Vishal_(actor)&amp;action=edit&amp;section=7" title="Edit section: Politics">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Vishal filed his nomination as an independent candidate for the by-poll to <a class="mw-redirect" href="/wiki/Radhakrishnan_Nagar" title="Radhakrishnan Nagar">Radhakrishnan Nagar constituency</a> in Chennai, which fell vacant following <a href="/wiki/J._Jayalalithaa" title="J. Jayalalithaa">Jayalalithaa</a>'s death in December 2017.<sup class="reference" id="cite_ref-54"><a href="#cite_note-54">[54]</a></sup> But his nomination was rejected.<sup class="reference" id="cite_ref-55"><a href="#cite_note-55">[55]</a></sup>
# </p>
# <h2><span class="mw-headline" id="Legal_issues">Legal issues</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Vishal_(actor)&amp;action=edit&amp;section=8" title="Edit section: Legal issues">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Vishal was arrested by police in December 2018 when he tried to enter inside the Tamil Film Producers Council in T Nagar, Chennai by forcefully trying to break the lock. The council was locked by 300 film producers alleging that Vishal failed to fulfil his promises during the elections in 2015.<sup class="reference" id="cite_ref-56"><a href="#cite_note-56">[56]</a></sup>
# </p>
# <h2><span class="mw-headline" id="Playback_singing">Playback singing</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Vishal_(actor)&amp;action=edit&amp;section=9" title="Edit section: Playback singing">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Vishal made his debut as a  playback singer in <a class="mw-redirect" href="/wiki/Madha_Gaja_Raja" title="Madha Gaja Raja">Madha Gaja Raja</a>, an unreleased film directed by <a href="/wiki/Sundar_C." title="Sundar C.">Sundar C</a>, crapping up for the song My Dear Loveru.
# </p>
# <h2><span class="mw-headline" id="Filmography">Filmography</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Vishal_(actor)&amp;action=edit&amp;section=10" title="Edit section: Filmography">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <h3><span class="mw-headline" id="Film">Film</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Vishal_(actor)&amp;action=edit&amp;section=11" title="Edit section: Film">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <table class="wikitable">
# <caption>Key
# </caption>
# <tbody><tr>
# <td class="partial table-partial" style="background: #FFD; vertical-align: middle; text-align: center;"><img alt="Films that have not yet been released" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/>
# </td>
# <td>Denotes films that have not yet been released
# </td></tr></tbody></table>
# <ul><li><i>All films are in <a href="/wiki/Tamil_language" title="Tamil language">Tamil</a>, unless otherwise noted.</i></li></ul>
# <table class="wikitable sortable plainrowheaders">
# <caption>
# </caption>
# <tbody><tr>
# <th>Year
# </th>
# <th>Film
# </th>
# <th>Role
# </th>
# <th class="unsortable">Notes
# </th>
# <th class="unsortable"><style data-mw-deduplicate="TemplateStyles:r1038841319">.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}</style><span class="rt-commentedText tooltip tooltip-dotted" title="Reference(s)">Ref.</span>
# </th></tr>
# <tr>
# <td>1989
# </td>
# <th scope="row"><i>Jadikketha Moodi</i>
# </th>
# <td class="table-na" data-sort-value="" style="background: #ececec; color: #2C2C2C; vertical-align: middle; text-align: center;">—</td>
# <td>Child artist</td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-57"><a href="#cite_note-57">[57]</a></sup>
# </td></tr>
# <tr>
# <td>2004
# </td>
# <th scope="row"><i><a href="/wiki/Chellamae" title="Chellamae">Chellamae</a></i>
# </th>
# <td>Ragunandan</td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-chelsify_17-1"><a href="#cite_note-chelsify-17">[17]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2005
# </td>
# <th scope="row"><i><a href="/wiki/Sandakozhi" title="Sandakozhi">Sandakozhi</a></i>
# </th>
# <td>Balu</td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-sandahit_20-1"><a href="#cite_note-sandahit-20">[20]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a class="mw-redirect" href="/wiki/Dishum" title="Dishum">Dishum</a></i>
# </th>
# <td>Himself</td>
# <td>Cameo appearance</td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-58"><a href="#cite_note-58">[58]</a></sup><br/><sup class="reference" id="cite_ref-59"><a href="#cite_note-59">[59]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2006
# </td>
# <th scope="row"><i><a href="/wiki/Thimiru" title="Thimiru">Thimiru</a></i>
# </th>
# <td>Ganesh</td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-bwdvishal_22-1"><a href="#cite_note-bwdvishal-22">[22]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Sivappathigaram" title="Sivappathigaram">Sivappathigaram</a></i>
# </th>
# <td>Sathyamoorthy</td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-spgvishal_23-1"><a href="#cite_note-spgvishal-23">[23]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2007
# </td>
# <th scope="row"><i><a href="/wiki/Thaamirabharani" title="Thaamirabharani">Thaamirabharani</a></i>
# </th>
# <td>Bharaniputhiran</td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-tbvishal_24-1"><a href="#cite_note-tbvishal-24">[24]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Malaikottai" title="Malaikottai">Malaikottai</a></i>
# </th>
# <td>Anbu</td>
# <td>
# </td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-mkbwd_27-1"><a href="#cite_note-mkbwd-27">[27]</a></sup>
# </td></tr>
# <tr>
# <td>2008
# </td>
# <th scope="row"><i><a href="/wiki/Satyam_(2008_film)" title="Satyam (2008 film)">Satyam</a></i>
# </th>
# <td>ACP Sathyam</td>
# <td>Simultaneously shot in <a href="/wiki/Telugu_language" title="Telugu language">Telugu</a> as <i>Salute</i></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-60"><a href="#cite_note-60">[60]</a></sup><br/><sup class="reference" id="cite_ref-61"><a href="#cite_note-61">[61]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2009
# </td>
# <th scope="row"><i><a href="/wiki/Thoranai" title="Thoranai">Thoranai</a></i>
# </th>
# <td>Murugan</td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-62"><a href="#cite_note-62">[62]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i>Pistha</i>
# </th>
# <td>Muralikrishna</td>
# <td>Telugu film</td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-63"><a href="#cite_note-63">[63]</a></sup><br/><sup class="reference" id="cite_ref-BVS_Prakash_28-1"><a href="#cite_note-BVS_Prakash-28">[28]</a></sup>
# </td></tr>
# <tr>
# <td>2010
# </td>
# <th scope="row"><i><a href="/wiki/Theeradha_Vilaiyattu_Pillai" title="Theeradha Vilaiyattu Pillai">Theeradha Vilaiyattu Pillai</a></i>
# </th>
# <td>Karthik</td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-64"><a href="#cite_note-64">[64]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2011
# </td>
# <th scope="row"><i><a href="/wiki/Avan_Ivan" title="Avan Ivan">Avan Ivan</a></i>
# </th>
# <td>Walter Vanangamudi</td>
# <td>Won, <a href="/wiki/Norway_Tamil_Film_Festival_Awards" title="Norway Tamil Film Festival Awards">Norway Tamil Film Festival Award for Special Jury Award</a><br/>Nominated, <a href="/wiki/1st_South_Indian_International_Movie_Awards" title="1st South Indian International Movie Awards">1st South Indian International Movie Awards</a> For Best Actor<br/>Nominated, <a href="/wiki/6th_Vijay_Awards" title="6th Vijay Awards">6th Vijay Awards</a> For Best Actor
# </td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-65"><a href="#cite_note-65">[65]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Vedi_(film)" title="Vedi (film)">Vedi</a></i>
# </th>
# <td>ASP Prabhakaran (Balu)<sup class="reference" id="cite_ref-character_66-0"><a href="#cite_note-character-66">[a]</a></sup></td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-67"><a href="#cite_note-67">[66]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="4">2013
# </td>
# <th scope="row"><i><a href="/wiki/Samar_(2013_film)" title="Samar (2013 film)">Samar</a></i>
# </th>
# <td>Shakthi</td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-68"><a href="#cite_note-68">[67]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Theeya_Velai_Seiyyanum_Kumaru" title="Theeya Velai Seiyyanum Kumaru">Theeya Velai Seiyyanum Kumaru</a></i>
# </th>
# <td>Himself</td>
# <td>Cameo appearance</td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-69"><a href="#cite_note-69">[68]</a></sup><br/><sup class="reference" id="cite_ref-70"><a href="#cite_note-70">[69]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Pattathu_Yaanai" title="Pattathu Yaanai">Pattathu Yaanai</a></i>
# </th>
# <td>Saravanan</td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-71"><a href="#cite_note-71">[70]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Pandiya_Naadu" title="Pandiya Naadu">Pandiya Naadu</a></i>
# </th>
# <td>Sivakumar</td>
# <td>Also producer <br/>Won, <a class="mw-redirect" href="/wiki/SIIMA_Awards" title="SIIMA Awards">SIIMA Award for Best Debutant Producer</a><br/>Nominated, <a href="/wiki/3rd_South_Indian_International_Movie_Awards" title="3rd South Indian International Movie Awards">3rd South Indian International Movie Awards</a> For Best Actor<br/>Nominated, <a href="/wiki/8th_Vijay_Awards" title="8th Vijay Awards">8th Vijay Awards</a> For Best Actor
# </td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-72"><a href="#cite_note-72">[71]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="3">2014
# </td>
# <th scope="row"><i><a href="/wiki/Naan_Sigappu_Manithan_(2014_film)" title="Naan Sigappu Manithan (2014 film)">Naan Sigappu Manithan</a></i>
# </th>
# <td>Indhiran</td>
# <td>Also producer</td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-73"><a href="#cite_note-73">[72]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Kathai_Thiraikathai_Vasanam_Iyakkam" title="Kathai Thiraikathai Vasanam Iyakkam">Kathai Thiraikathai Vasanam Iyakkam</a></i>
# </th>
# <td>Himself</td>
# <td>Cameo appearance</td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-74"><a href="#cite_note-74">[73]</a></sup><br/><sup class="reference" id="cite_ref-75"><a href="#cite_note-75">[74]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Poojai" title="Poojai">Poojai</a></i>
# </th>
# <td>Vasudevan</td>
# <td>Also producer</td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-76"><a href="#cite_note-76">[75]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="3">2015
# </td>
# <th scope="row"><i><a href="/wiki/Aambala" title="Aambala">Aambala</a></i>
# </th>
# <td>Saravanan</td>
# <td>Also producer</td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-77"><a href="#cite_note-77">[76]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Vasuvum_Saravananum_Onna_Padichavanga" title="Vasuvum Saravananum Onna Padichavanga">Vasuvum Saravananum Onna Padichavanga</a></i>
# </th>
# <td>ACP Vetrivel</td>
# <td>Cameo appearance</td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-78"><a href="#cite_note-78">[77]</a></sup><br/><sup class="reference" id="cite_ref-79"><a href="#cite_note-79">[78]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Paayum_Puli_(2015_film)" title="Paayum Puli (2015 film)">Paayum Puli</a></i>
# </th>
# <td>ACP Jayaseelan</td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-80"><a href="#cite_note-80">[79]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="3">2016
# </td>
# <th scope="row"><i><a href="/wiki/Kathakali_(film)" title="Kathakali (film)">Kathakali</a></i>
# </th>
# <td>Amudhavel</td>
# <td>Also producer</td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-81"><a href="#cite_note-81">[80]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Marudhu" title="Marudhu">Marudhu</a></i>
# </th>
# <td>Marudhu</td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-82"><a href="#cite_note-82">[81]</a></sup>
# </td></tr>
# <tr>
# <th scope="row"><i><a href="/wiki/Kaththi_Sandai" title="Kaththi Sandai">Kaththi Sandai</a></i>
# </th>
# <td>Arjun Ramakrishnan (Cheenu)<sup class="reference" id="cite_ref-character_66-1"><a href="#cite_note-character-66">[a]</a></sup></td>
# <td></td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-83"><a href="#cite_note-83">[82]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2017
# </td>
# <th scope="row"><i><a href="/wiki/Thupparivaalan" title="Thupparivaalan">Thupparivaalan</a></i>
# </th>
# <td>Kaniyan Poongundran</td>
# <td>Nominated, <a href="/wiki/Vijay_Awards" title="Vijay Awards">Vijay Award for Best Actor</a></td>
# ...
# <h3 class="vector-menu-heading" id="p-navigation-label">
# <span class="vector-menu-heading-label">Navigation</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="n-mainpage-description"><a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a></li><li class="mw-list-item" id="n-contents"><a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a></li><li class="mw-list-item" id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a></li><li class="mw-list-item" id="n-randompage"><a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a></li><li class="mw-list-item" id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a></li><li class="mw-list-item" id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a></li><li class="mw-list-item" id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation"><span>Donate</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-interaction-label" class="vector-menu mw-portlet mw-portlet-interaction vector-menu-portal portal" id="p-interaction" role="navigation">
# <h3 class="vector-menu-heading" id="p-interaction-label">
# <span class="vector-menu-heading-label">Contribute</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a></li><li class="mw-list-item" id="n-introduction"><a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a></li><li class="mw-list-item" id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="The hub for editors"><span>Community portal</span></a></li><li class="mw-list-item" id="n-recentchanges"><a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]"><span>Recent changes</span></a></li><li class="mw-list-item" id="n-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Add images or other media for use on Wikipedia"><span>Upload file</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-tb-label" class="vector-menu mw-portlet mw-portlet-tb vector-menu-portal portal" id="p-tb" role="navigation">
# <h3 class="vector-menu-heading" id="p-tb-label">
# <span class="vector-menu-heading-label">Tools</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="t-whatlinkshere"><a accesskey="j" href="/wiki/Special:WhatLinksHere/Vishal_(actor)" title="List of all English Wikipedia pages containing links to this page [j]"><span>What links here</span></a></li><li class="mw-list-item" id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Special:RecentChangesLinked/Vishal_(actor)" rel="nofollow" title="Recent changes in pages linked from this page [k]"><span>Related changes</span></a></li><li class="mw-list-item" id="t-upload"><a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]"><span>Upload file</span></a></li><li class="mw-list-item" id="t-specialpages"><a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]"><span>Special pages</span></a></li><li class="mw-list-item" id="t-permalink"><a href="/w/index.php?title=Vishal_(actor)&amp;oldid=1109152472" title="Permanent link to this revision of this page"><span>Permanent link</span></a></li><li class="mw-list-item" id="t-info"><a href="/w/index.php?title=Vishal_(actor)&amp;action=info" title="More information about this page"><span>Page information</span></a></li><li class="mw-list-item" id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Vishal_%28actor%29&amp;id=1109152472&amp;wpFormIdentifier=titleform" title="Information on how to cite this page"><span>Cite this page</span></a></li><li class="mw-list-item" id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q3534989" title="Structured data on this page hosted by Wikidata [g]"><span>Wikidata item</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-coll-print_export-label" class="vector-menu mw-portlet mw-portlet-coll-print_export vector-menu-portal portal" id="p-coll-print_export" role="navigation">
# <h3 class="vector-menu-heading" id="p-coll-print_export-label">
# <span class="vector-menu-heading-label">Print/export</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="coll-download-as-rl"><a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=Vishal_%28actor%29&amp;action=show-download-screen" title="Download this page as a PDF file"><span>Download as PDF</span></a></li><li class="mw-list-item" id="t-print"><a accesskey="p" href="/w/index.php?title=Vishal_(actor)&amp;printable=yes" title="Printable version of this page [p]"><span>Printable version</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-wikibase-otherprojects-label" class="vector-menu mw-portlet mw-portlet-wikibase-otherprojects vector-menu-portal portal" id="p-wikibase-otherprojects" role="navigation">
# <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
# <span class="vector-menu-heading-label">In other projects</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="wb-otherproject-link wb-otherproject-commons mw-list-item"><a href="https://commons.wikimedia.org/wiki/Category:Vishal_(actor)" hreflang="en"><span>Wikimedia Commons</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-lang-label" class="vector-menu mw-portlet mw-portlet-lang vector-menu-portal portal" id="p-lang" role="navigation">
# <h3 class="vector-menu-heading" id="p-lang-label">
# <span class="vector-menu-heading-label">Languages</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="interlanguage-link interwiki-ar mw-list-item"><a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D9%81%D9%8A%D8%B4%D8%A7%D9%84" hreflang="ar" lang="ar" title="فيشال – Arabic"><span>العربية</span></a></li><li class="interlanguage-link interwiki-as mw-list-item"><a class="interlanguage-link-target" href="https://as.wikipedia.org/wiki/%E0%A6%AC%E0%A6%BF%E0%A6%B6%E0%A6%BE%E0%A6%B2_%E0%A6%95%E0%A7%83%E0%A6%B7%E0%A7%8D%E0%A6%A3" hreflang="as" lang="as" title="বিশাল কৃষ্ণ – Assamese"><span>অসমীয়া</span></a></li><li class="interlanguage-link interwiki-bn mw-list-item"><a class="interlanguage-link-target" href="https://bn.wikipedia.org/wiki/%E0%A6%AC%E0%A6%BF%E0%A6%B6%E0%A6%BE%E0%A6%B2_%E0%A6%95%E0%A7%83%E0%A6%B7%E0%A7%8D%E0%A6%A3" hreflang="bn" lang="bn" title="বিশাল কৃষ্ণ – Bangla"><span>বাংলা</span></a></li><li class="interlanguage-link interwiki-fa mw-list-item"><a class="interlanguage-link-target" href="https://fa.wikipedia.org/wiki/%D9%88%DB%8C%D8%B4%D8%A7%D9%84_(%D8%A8%D8%A7%D8%B2%DB%8C%DA%AF%D8%B1)" hreflang="fa" lang="fa" title="ویشال (بازیگر) – Persian"><span>فارسی</span></a></li><li class="interlanguage-link interwiki-ko mw-list-item"><a class="interlanguage-link-target" href="https://ko.wikipedia.org/wiki/%EB%B9%84%EC%85%9C_%ED%81%AC%EB%A6%AC%EC%8A%88%EB%82%98" hreflang="ko" lang="ko" title="비셜 크리슈나 – Korean"><span>한국어</span></a></li><li class="interlanguage-link interwiki-hi mw-list-item"><a class="interlanguage-link-target" href="https://hi.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%B6%E0%A4%BE%E0%A4%B2_(%E0%A4%85%E0%A4%AD%E0%A4%BF%E0%A4%A8%E0%A5%87%E0%A4%A4%E0%A4%BE)" hreflang="hi" lang="hi" title="विशाल (अभिनेता) – Hindi"><span>हिन्दी</span></a></li><li class="interlanguage-link interwiki-mai mw-list-item"><a class="interlanguage-link-target" href="https://mai.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%B6%E0%A4%BE%E0%A4%B2_(%E0%A4%85%E0%A4%AD%E0%A4%BF%E0%A4%A8%E0%A5%87%E0%A4%A4%E0%A4%BE)" hreflang="mai" lang="mai" title="विशाल (अभिनेता) – Maithili"><span>मैथिली</span></a></li><li class="interlanguage-link interwiki-mr mw-list-item"><a class="interlanguage-link-target" href="https://mr.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%B6%E0%A4%BE%E0%A4%B2_(%E0%A4%85%E0%A4%AD%E0%A4%BF%E0%A4%A8%E0%A5%87%E0%A4%A4%E0%A4%BE)" hreflang="mr" lang="mr" title="विशाल (अभिनेता) – Marathi"><span>मराठी</span></a></li><li class="interlanguage-link interwiki-arz mw-list-item"><a class="interlanguage-link-target" href="https://arz.wikipedia.org/wiki/%D9%81%D9%8A%D8%B4%D8%A7%D9%84" hreflang="arz" lang="arz" title="فيشال – Egyptian Arabic"><span>مصرى</span></a></li><li class="interlanguage-link interwiki-ne mw-list-item"><a class="interlanguage-link-target" href="https://ne.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%B6%E0%A4%BE%E0%A4%B2_(%E0%A4%85%E0%A4%AD%E0%A4%BF%E0%A4%A8%E0%A5%87%E0%A4%A4%E0%A4%BE)" hreflang="ne" lang="ne" title="विशाल (अभिनेता) – Nepali"><span>नेपाली</span></a></li><li class="interlanguage-link interwiki-ta mw-list-item"><a class="interlanguage-link-target" href="https://ta.wikipedia.org/wiki/%E0%AE%B5%E0%AE%BF%E0%AE%B7%E0%AE%BE%E0%AE%B2%E0%AF%8D" hreflang="ta" lang="ta" title="விஷால் – Tamil"><span>தமிழ்</span></a></li><li class="interlanguage-link interwiki-te mw-list-item"><a class="interlanguage-link-target" href="https://te.wikipedia.org/wiki/%E0%B0%B5%E0%B0%BF%E0%B0%B6%E0%B0%BE%E0%B0%B2%E0%B1%8D_%E0%B0%95%E0%B1%83%E0%B0%B7%E0%B1%8D%E0%B0%A3" hreflang="te" lang="te" title="విశాల్ కృష్ణ – Telugu"><span>తెలుగు</span></a></li><li class="interlanguage-link interwiki-ur mw-list-item"><a class="interlanguage-link-target" href="https://ur.wikipedia.org/wiki/%D9%88%D8%B4%D8%A7%D9%84_(%D8%A7%D8%AF%D8%A7%DA%A9%D8%A7%D8%B1)" hreflang="ur" lang="ur" title="وشال (اداکار) – Urdu"><span>اردو</span></a></li></ul>
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q3534989#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a></span></div>
# </div>
# </nav>
# </div>
# </div>
# <footer class="mw-footer" id="footer" role="contentinfo">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> This page was last edited on 8 September 2022, at 08:21<span class="anonymous-show"> (UTC)</span>.</li>
# <li id="footer-info-copyright">Text is available under the <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">Creative Commons Attribution-ShareAlike License 3.0</a><a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a href="https://foundation.wikimedia.org/wiki/Privacy_policy">Privacy policy</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikipedia:About">About Wikipedia</a></li>
# <li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer">Disclaimers</a></li>
# <li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Vishal_(actor)&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>
# <li id="footer-places-developers"><a href="https://developer.wikimedia.org">Developers</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a></li>
# <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
# </ul>
# </footer>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.716","walltime":"0.920","ppvisitednodes":{"value":6003,"limit":1000000},"postexpandincludesize":{"value":158627,"limit":2097152},"templateargumentsize":{"value":3766,"limit":2097152},"expansiondepth":{"value":14,"limit":100},"expensivefunctioncount":{"value":4,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":258907,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  822.586      1 -total"," 50.69%  416.988      2 Template:Reflist"," 32.18%  264.721     65 Template:Cite_web"," 15.58%  128.126      1 Template:Infobox_person"," 13.04%  107.240      1 Template:Infobox","  7.63%   62.751     18 Template:Cite_news","  6.10%   50.137      1 Template:Short_description","  5.51%   45.345      5 Template:Br_separated_entries","  4.83%   39.755      1 Template:Vishal_Film_Factory","  4.61%   37.910      1 Template:Navbox"]},"scribunto":{"limitreport-timeusage":{"value":"0.425","limit":"10.000"},"limitreport-memusage":{"value":8971985,"limit":52428800}},"cachereport":{"origin":"mw2359","timestamp":"20220914102601","ttl":1814400,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Vishal (actor)","url":"https:\/\/en.wikipedia.org\/wiki\/Vishal_(actor)","sameAs":"http:\/\/www.wikidata.org\/entity\/Q3534989","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q3534989","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2006-08-20T17:44:06Z","dateModified":"2022-09-08T08:21:30Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/3\/30\/Vishal2018.jpg","headline":"Indian film actor"}</script><script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Vishal (actor)","url":"https:\/\/en.wikipedia.org\/wiki\/Vishal_(actor)","sameAs":"http:\/\/www.wikidata.org\/entity\/Q3534989","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q3534989","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2006-08-20T17:44:06Z","dateModified":"2022-09-08T08:21:30Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/3\/30\/Vishal2018.jpg","headline":"Indian film actor"}</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":1032,"wgHostname":"mw2359"});});</script>
# </body>
# </html>

# %%
text = " "
for paragraph in corpus.select('p'):
    text += paragraph.text

# %%
text
# Out:
# ' \nVishal Krishna Reddy (born 29 August 1977),[1] also known as Vishal, is an Indian actor and film producer who works at Tamil cinema. The younger son of film producer G. K. Reddy, Vishal studied Visual Communications at Loyola College, Chennai. Best known for his roles in action films, he produces films under his production company, Vishal Film Factory.[2]\nVishal made an entrance into the film industry as an assistant director for Arjun. He then became an actor and played his first lead role in the romantic thriller Chellamae (2004), before going on to star in the commercially successful action films Sandakozhi, Thimiru, Thaamirabharani and Malaikottai.[3] Following a series of unsuccessful films at the box office, Vishal chose to create his own production studio and has since produced and worked on profitable ventures such as Pandiya Naadu (2013), Naan Sigappu Manithan (2014) and Poojai (2014).[4]\nVishal was elected as the General Secretary of the Nadigar Sangam in October 2015 after initiating a movement against the previous committee.[5] He was expelled from Tamil Film Producers\' Council (TFPC) for remarks against the council.[6][7] Later in April 2017, he won the election and got elected as President of Tamil Film Producers Council.\nVishal Krishna Reddy was born on 29 August 1977[8][9] into a Telugu family in Chennai, Tamil Nadu.[10] His father GK Reddy is a businessman and a film producer for Telugu and Tamil films.[11] His elder brother Vikram Krishna is also an actor and producer who has produced several of Vishal\'s films.[12] Vishal obtained his degree in visual communications from Loyola College, Chennai.[13]\nVishal assisted actor-director Arjun Sarja in his venture Vedham (2001), and a producer spotted Vishal on the sets of the film and signed him to appear in an acting role in Gandhi Krishna\'s Chellamae (2004).[14][15] Accepting the role, Vishal prepared by joining Koothu-P-Pattarai to hone his acting skills and played the protagonist role of Raghunandan, whose wife is kidnapped by her childhood friend.[15] A critic described his performance is "apt" but "there was plenty left to hone".[16][17] His next film was Sandakozhi (2005) with N. Linguswamy, who had previously worked with his father\'s production house as an assistant director.[18] Vishal was described to have "improved from his Chellamae days" and "clicked as an action hero".[19] Film journalists stated that he was "the fastest rising action hero" of the time.[20] After a cameo as himself in Sasi\'s Dishyum (2006), he went on to appear in Tarun Gopi\'s action film Thimiru (2006). The film opened to mixed reviews with Vishal being praised for his intense performance with a critic calling his performance "the film\'s only strength and, to an extent, making up for the weak script and poor characterisation".[21] The film became Vishal\'s third consecutive commercial success, and he began to emerge in Tamil films.[22]\nHis next film, the political action drama Sivappathigaram (2006), directed by Karu Pazhaniappan was a failure financially despite favourable reviews.[23] His next film was released in January 2007, Hari\'s multi-starring family action drama Thaamirabharani (2007) and the film went on to gain considerable box office success, carrying good reports amidst other big budget releases.[24][25] Later in the year, he appeared in Boopathy Pandian\'s Malaikottai (2007), a comedy entertainer. In his first full-length comic role, Vishal received mixed feedback for his portrayal from critics, with Rediff stating that he is "a far cry from the rather endearing young man in Sandakozhi", whilst describing his performance as "cringe-able".[26] Behindwoods stated it as an "Average masala-mix entertainer".[27] The film took a large opening and was declared a blockbuster, featuring in the top 10 at behindwoods box office. In the year 2008, for the first time, Vishal portrayed a police officer in Sathyam, which became a commercial failure at the box office. T ...

# %% [markdown]
# 1. convert the complete text to lower case.

# %%
text.lower()
# Out:
# ' \nvishal krishna reddy (born 29 august 1977),[1] also known as vishal, is an indian actor and film producer who works at tamil cinema. the younger son of film producer g. k. reddy, vishal studied visual communications at loyola college, chennai. best known for his roles in action films, he produces films under his production company, vishal film factory.[2]\nvishal made an entrance into the film industry as an assistant director for arjun. he then became an actor and played his first lead role in the romantic thriller chellamae (2004), before going on to star in the commercially successful action films sandakozhi, thimiru, thaamirabharani and malaikottai.[3] following a series of unsuccessful films at the box office, vishal chose to create his own production studio and has since produced and worked on profitable ventures such as pandiya naadu (2013), naan sigappu manithan (2014) and poojai (2014).[4]\nvishal was elected as the general secretary of the nadigar sangam in october 2015 after initiating a movement against the previous committee.[5] he was expelled from tamil film producers\' council (tfpc) for remarks against the council.[6][7] later in april 2017, he won the election and got elected as president of tamil film producers council.\nvishal krishna reddy was born on 29 august 1977[8][9] into a telugu family in chennai, tamil nadu.[10] his father gk reddy is a businessman and a film producer for telugu and tamil films.[11] his elder brother vikram krishna is also an actor and producer who has produced several of vishal\'s films.[12] vishal obtained his degree in visual communications from loyola college, chennai.[13]\nvishal assisted actor-director arjun sarja in his venture vedham (2001), and a producer spotted vishal on the sets of the film and signed him to appear in an acting role in gandhi krishna\'s chellamae (2004).[14][15] accepting the role, vishal prepared by joining koothu-p-pattarai to hone his acting skills and played the protagonist role of raghunandan, whose wife is kidnapped by her childhood friend.[15] a critic described his performance is "apt" but "there was plenty left to hone".[16][17] his next film was sandakozhi (2005) with n. linguswamy, who had previously worked with his father\'s production house as an assistant director.[18] vishal was described to have "improved from his chellamae days" and "clicked as an action hero".[19] film journalists stated that he was "the fastest rising action hero" of the time.[20] after a cameo as himself in sasi\'s dishyum (2006), he went on to appear in tarun gopi\'s action film thimiru (2006). the film opened to mixed reviews with vishal being praised for his intense performance with a critic calling his performance "the film\'s only strength and, to an extent, making up for the weak script and poor characterisation".[21] the film became vishal\'s third consecutive commercial success, and he began to emerge in tamil films.[22]\nhis next film, the political action drama sivappathigaram (2006), directed by karu pazhaniappan was a failure financially despite favourable reviews.[23] his next film was released in january 2007, hari\'s multi-starring family action drama thaamirabharani (2007) and the film went on to gain considerable box office success, carrying good reports amidst other big budget releases.[24][25] later in the year, he appeared in boopathy pandian\'s malaikottai (2007), a comedy entertainer. in his first full-length comic role, vishal received mixed feedback for his portrayal from critics, with rediff stating that he is "a far cry from the rather endearing young man in sandakozhi", whilst describing his performance as "cringe-able".[26] behindwoods stated it as an "average masala-mix entertainer".[27] the film took a large opening and was declared a blockbuster, featuring in the top 10 at behindwoods box office. in the year 2008, for the first time, vishal portrayed a police officer in sathyam, which became a commercial failure at the box office. t ...

# %%
text = text.lower()

# %%
text
# Out:
# ' \nvishal krishna reddy (born 29 august 1977),[1] also known as vishal, is an indian actor and film producer who works at tamil cinema. the younger son of film producer g. k. reddy, vishal studied visual communications at loyola college, chennai. best known for his roles in action films, he produces films under his production company, vishal film factory.[2]\nvishal made an entrance into the film industry as an assistant director for arjun. he then became an actor and played his first lead role in the romantic thriller chellamae (2004), before going on to star in the commercially successful action films sandakozhi, thimiru, thaamirabharani and malaikottai.[3] following a series of unsuccessful films at the box office, vishal chose to create his own production studio and has since produced and worked on profitable ventures such as pandiya naadu (2013), naan sigappu manithan (2014) and poojai (2014).[4]\nvishal was elected as the general secretary of the nadigar sangam in october 2015 after initiating a movement against the previous committee.[5] he was expelled from tamil film producers\' council (tfpc) for remarks against the council.[6][7] later in april 2017, he won the election and got elected as president of tamil film producers council.\nvishal krishna reddy was born on 29 august 1977[8][9] into a telugu family in chennai, tamil nadu.[10] his father gk reddy is a businessman and a film producer for telugu and tamil films.[11] his elder brother vikram krishna is also an actor and producer who has produced several of vishal\'s films.[12] vishal obtained his degree in visual communications from loyola college, chennai.[13]\nvishal assisted actor-director arjun sarja in his venture vedham (2001), and a producer spotted vishal on the sets of the film and signed him to appear in an acting role in gandhi krishna\'s chellamae (2004).[14][15] accepting the role, vishal prepared by joining koothu-p-pattarai to hone his acting skills and played the protagonist role of raghunandan, whose wife is kidnapped by her childhood friend.[15] a critic described his performance is "apt" but "there was plenty left to hone".[16][17] his next film was sandakozhi (2005) with n. linguswamy, who had previously worked with his father\'s production house as an assistant director.[18] vishal was described to have "improved from his chellamae days" and "clicked as an action hero".[19] film journalists stated that he was "the fastest rising action hero" of the time.[20] after a cameo as himself in sasi\'s dishyum (2006), he went on to appear in tarun gopi\'s action film thimiru (2006). the film opened to mixed reviews with vishal being praised for his intense performance with a critic calling his performance "the film\'s only strength and, to an extent, making up for the weak script and poor characterisation".[21] the film became vishal\'s third consecutive commercial success, and he began to emerge in tamil films.[22]\nhis next film, the political action drama sivappathigaram (2006), directed by karu pazhaniappan was a failure financially despite favourable reviews.[23] his next film was released in january 2007, hari\'s multi-starring family action drama thaamirabharani (2007) and the film went on to gain considerable box office success, carrying good reports amidst other big budget releases.[24][25] later in the year, he appeared in boopathy pandian\'s malaikottai (2007), a comedy entertainer. in his first full-length comic role, vishal received mixed feedback for his portrayal from critics, with rediff stating that he is "a far cry from the rather endearing young man in sandakozhi", whilst describing his performance as "cringe-able".[26] behindwoods stated it as an "average masala-mix entertainer".[27] the film took a large opening and was declared a blockbuster, featuring in the top 10 at behindwoods box office. in the year 2008, for the first time, vishal portrayed a police officer in sathyam, which became a commercial failure at the box office. t ...

# %% [markdown]
# 2. remove all the stop words.

# %%
from nltk.corpus import stopwords

# %%
stopwords.words("english")
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
def remove_stopwords(text):
    new_text = []
    
    for word in text.split():
        if word in stopwords.words("english"):
            new_text.append(" ")
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

# %%
remove_stopwords(text)
# Out:
# 'vishal krishna reddy (born 29 august 1977),[1] also known   vishal,     indian actor   film producer   works   tamil cinema.   younger son   film producer g. k. reddy, vishal studied visual communications   loyola college, chennai. best known     roles   action films,   produces films     production company, vishal film factory.[2] vishal made   entrance     film industry     assistant director   arjun.     became   actor   played   first lead role     romantic thriller chellamae (2004),   going     star     commercially successful action films sandakozhi, thimiru, thaamirabharani   malaikottai.[3] following   series   unsuccessful films     box office, vishal chose   create     production studio     since produced   worked   profitable ventures     pandiya naadu (2013), naan sigappu manithan (2014)   poojai (2014).[4] vishal   elected     general secretary     nadigar sangam   october 2015   initiating   movement     previous committee.[5]     expelled   tamil film producers\' council (tfpc)   remarks     council.[6][7] later   april 2017,       election   got elected   president   tamil film producers council. vishal krishna reddy   born   29 august 1977[8][9]     telugu family   chennai, tamil nadu.[10]   father gk reddy     businessman     film producer   telugu   tamil films.[11]   elder brother vikram krishna   also   actor   producer     produced several   vishal\'s films.[12] vishal obtained   degree   visual communications   loyola college, chennai.[13] vishal assisted actor-director arjun sarja     venture vedham (2001),     producer spotted vishal     sets     film   signed     appear     acting role   gandhi krishna\'s chellamae (2004).[14][15] accepting   role, vishal prepared   joining koothu-p-pattarai   hone   acting skills   played   protagonist role   raghunandan, whose wife   kidnapped     childhood friend.[15]   critic described   performance   "apt"   "there   plenty left   hone".[16][17]   next film   sandakozhi (2005)   n. linguswamy,     previously worked     father\'s production house     assistant director.[18] vishal   described     "improved     chellamae days"   "clicked     action hero".[19] film journalists stated       "the fastest rising action hero"     time.[20]     cameo       sasi\'s dishyum (2006),   went     appear   tarun gopi\'s action film thimiru (2006).   film opened   mixed reviews   vishal   praised     intense performance     critic calling   performance "the film\'s   strength and,     extent, making       weak script   poor characterisation".[21]   film became vishal\'s third consecutive commercial success,     began   emerge   tamil films.[22]   next film,   political action drama sivappathigaram (2006), directed   karu pazhaniappan     failure financially despite favourable reviews.[23]   next film   released   january 2007, hari\'s multi-starring family action drama thaamirabharani (2007)     film went     gain considerable box office success, carrying good reports amidst   big budget releases.[24][25] later     year,   appeared   boopathy pandian\'s malaikottai (2007),   comedy entertainer.     first full-length comic role, vishal received mixed feedback     portrayal   critics,   rediff stating       "a far cry     rather endearing young man   sandakozhi", whilst describing   performance   "cringe-able".[26] behindwoods stated       "average masala-mix entertainer".[27]   film took   large opening     declared   blockbuster, featuring     top 10   behindwoods box office.     year 2008,     first time, vishal portrayed   police officer   sathyam,   became   commercial failure     box office.       films thoranai (2009)   theeradha vilaiyattu pillai (2010)     average grossers. additionally,   box-office duds, sathyam   thoranai,         bilingual   tamil   telugu, failed   establish   popularity   telugu cinema.[28] vishal     given   opportunity   feature   bala\'s dark comedy avan ivan (2011),     recommended     director     friend arya. portraying   village stage actor  ...

# %%
text = remove_stopwords(text)

# %%
text
# Out:
# 'vishal krishna reddy (born 29 august 1977),[1] also known   vishal,     indian actor   film producer   works   tamil cinema.   younger son   film producer g. k. reddy, vishal studied visual communications   loyola college, chennai. best known     roles   action films,   produces films     production company, vishal film factory.[2] vishal made   entrance     film industry     assistant director   arjun.     became   actor   played   first lead role     romantic thriller chellamae (2004),   going     star     commercially successful action films sandakozhi, thimiru, thaamirabharani   malaikottai.[3] following   series   unsuccessful films     box office, vishal chose   create     production studio     since produced   worked   profitable ventures     pandiya naadu (2013), naan sigappu manithan (2014)   poojai (2014).[4] vishal   elected     general secretary     nadigar sangam   october 2015   initiating   movement     previous committee.[5]     expelled   tamil film producers\' council (tfpc)   remarks     council.[6][7] later   april 2017,       election   got elected   president   tamil film producers council. vishal krishna reddy   born   29 august 1977[8][9]     telugu family   chennai, tamil nadu.[10]   father gk reddy     businessman     film producer   telugu   tamil films.[11]   elder brother vikram krishna   also   actor   producer     produced several   vishal\'s films.[12] vishal obtained   degree   visual communications   loyola college, chennai.[13] vishal assisted actor-director arjun sarja     venture vedham (2001),     producer spotted vishal     sets     film   signed     appear     acting role   gandhi krishna\'s chellamae (2004).[14][15] accepting   role, vishal prepared   joining koothu-p-pattarai   hone   acting skills   played   protagonist role   raghunandan, whose wife   kidnapped     childhood friend.[15]   critic described   performance   "apt"   "there   plenty left   hone".[16][17]   next film   sandakozhi (2005)   n. linguswamy,     previously worked     father\'s production house     assistant director.[18] vishal   described     "improved     chellamae days"   "clicked     action hero".[19] film journalists stated       "the fastest rising action hero"     time.[20]     cameo       sasi\'s dishyum (2006),   went     appear   tarun gopi\'s action film thimiru (2006).   film opened   mixed reviews   vishal   praised     intense performance     critic calling   performance "the film\'s   strength and,     extent, making       weak script   poor characterisation".[21]   film became vishal\'s third consecutive commercial success,     began   emerge   tamil films.[22]   next film,   political action drama sivappathigaram (2006), directed   karu pazhaniappan     failure financially despite favourable reviews.[23]   next film   released   january 2007, hari\'s multi-starring family action drama thaamirabharani (2007)     film went     gain considerable box office success, carrying good reports amidst   big budget releases.[24][25] later     year,   appeared   boopathy pandian\'s malaikottai (2007),   comedy entertainer.     first full-length comic role, vishal received mixed feedback     portrayal   critics,   rediff stating       "a far cry     rather endearing young man   sandakozhi", whilst describing   performance   "cringe-able".[26] behindwoods stated       "average masala-mix entertainer".[27]   film took   large opening     declared   blockbuster, featuring     top 10   behindwoods box office.     year 2008,     first time, vishal portrayed   police officer   sathyam,   became   commercial failure     box office.       films thoranai (2009)   theeradha vilaiyattu pillai (2010)     average grossers. additionally,   box-office duds, sathyam   thoranai,         bilingual   tamil   telugu, failed   establish   popularity   telugu cinema.[28] vishal     given   opportunity   feature   bala\'s dark comedy avan ivan (2011),     recommended     director     friend arya. portraying   village stage actor  ...

# %% [markdown]
# 3. Apply POS tagging on the whole text

# %%
import re

# %%
text_tokens = re.findall("[\w']+",text)

# %%
text_tokens
# Out:
# ['vishal',
#  'krishna',
#  'reddy',
#  'born',
#  '29',
#  'august',
#  '1977',
#  '1',
#  'also',
#  'known',
#  'vishal',
#  'indian',
#  'actor',
#  'film',
#  'producer',
#  'works',
#  'tamil',
#  'cinema',
#  'younger',
#  'son',
#  'film',
#  'producer',
#  'g',
#  'k',
#  'reddy',
#  'vishal',
#  'studied',
#  'visual',
#  'communications',
#  'loyola',
#  'college',
#  'chennai',
#  'best',
#  'known',
#  'roles',
#  'action',
#  'films',
#  'produces',
#  'films',
#  'production',
#  'company',
#  'vishal',
#  'film',
#  'factory',
#  '2',
#  'vishal',
#  'made',
#  'entrance',
#  'film',
#  'industry',
#  'assistant',
#  'director',
#  'arjun',
#  'became',
#  'actor',
#  'played',
#  'first',
#  'lead',
#  'role',
#  'romantic',
#  'thriller',
#  'chellamae',
#  '2004',
#  'going',
#  'star',
#  'commercially',
#  'successful',
#  'action',
#  'films',
#  'sandakozhi',
#  'thimiru',
#  'thaamirabharani',
#  'malaikottai',
#  '3',
#  'following',
#  'series',
#  'unsuccessful',
#  'films',
#  'box',
#  'office',
#  'vishal',
#  'chose',
#  'create',
#  'production',
#  'studio',
#  'since',
#  'produced',
#  'worked',
#  'profitable',
#  'ventures',
#  'pandiya',
#  'naadu',
#  '2013',
#  'naan',
#  'sigappu',
#  'manithan',
#  '2014',
#  'poojai',
#  '2014',
#  '4',
#  'vishal',
#  'elected',
#  'general',
#  'secretary',
#  'nadigar',
#  'sangam',
#  'october',
#  '2015',
#  'initiating',
#  'movement',
#  'previous',
#  'committee',
#  '5',
#  'expelled',
#  'tamil',
#  'film',
#  "producers'",
#  'council',
#  'tfpc',
#  'remarks',
#  'council',
#  '6',
#  '7',
#  'later',
#  'april',
#  '2017',
#  'election',
#  'got',
#  'elected',
#  'president',
#  'tamil',
#  'film',
#  'producers',
#  'council',
#  'vishal',
#  'krishna',
#  'reddy',
#  'born',
#  '29',
#  'august',
#  '1977',
#  '8',
#  '9',
#  'telugu',
#  'family',
#  'chennai',
#  'tamil',
#  'nadu',
#  '10',
#  'father',
#  'gk',
#  'reddy',
#  'businessman',
#  'film',
#  'producer',
#  'telugu',
#  'tamil',
#  'films',
#  '11',
#  'elder',
#  'brother',
#  'vikram',
#  'krishna',
#  'also',
#  'actor',
#  'producer',
#  'produced',
#  'several',
#  "vishal's",
#  'films',
#  '12',
#  'vishal',
#  'obtained',
#  'degree',
#  'visual',
#  'communications',
#  'loyola',
#  'college',
#  'chennai',
#  '13',
#  'vishal',
#  'assisted',
#  'actor',
#  'director',
#  'arjun',
#  'sarja',
#  'venture',
#  'vedham',
#  '2001',
#  'producer',
#  'spotted',
#  'vishal',
#  'sets',
#  'film',
#  'signed',
#  'appear',
#  'acting',
#  'role',
#  'gandhi',
#  "krishna's",
#  'chellamae',
#  '2004',
#  '14',
#  '15',
#  'accepting',
#  'role',
#  'vishal',
#  'prepared',
#  'joining',
#  'koothu',
#  'p',
#  'pattarai',
#  'hone',
#  'acting',
#  'skills',
#  'played',
#  'protagonist',
#  'role',
#  'raghunandan',
#  'whose',
#  'wife',
#  'kidnapped',
#  'childhood',
#  'friend',
#  '15',
#  'critic',
#  'described',
#  'performance',
#  'apt',
#  'there',
#  'plenty',
#  'left',
#  'hone',
#  '16',
#  '17',
#  'next',
#  'film',
#  'sandakozhi',
#  '2005',
#  'n',
#  'linguswamy',
#  'previously',
#  'worked',
#  "father's",
#  'production',
#  'house',
#  'assistant',
#  'director',
#  '18',
#  'vishal',
#  'described',
#  'improved',
#  'chellamae',
#  'days',
#  'clicked',
#  'action',
#  'hero',
#  '19',
#  'film',
#  'journalists',
#  'stated',
#  'the',
#  'fastest',
#  'rising',
#  'action',
#  'hero',
#  'time',
#  '20',
#  'cameo',
#  "sasi's",
#  'dishyum',
#  '2006',
#  'went',
#  'appear',
#  'tarun',
#  "gopi's",
#  'action',
#  'film',
#  'thimiru',
#  '2006',
#  'film',
#  'opened',
#  'mixed',
#  'reviews',
#  'vishal',
#  'praised',
#  'intense',
#  'performance',
#  'critic',
#  'calling',
#  'performance',
#  'the',
#  "film's",
#  'strength',
#  'and',
#  'extent',
#  'making',
#  'weak',
#  'script',
#  'poor',
#  'characterisation',
#  '21',
#  'film',
#  'became',
#  "vishal's",
#  'third',
#  'consecutive',
#  'commercial',
#  'success',
#  'began',
#  'emerge',
#  'tamil',
#  'films',
#  '22',
#  'next',
#  'film',
#  'political',
#  'action',
#  'drama',
#  'sivappathigaram',
#  '2006',
#  'directed',
#  'karu',
#  'pazhaniappan',
#  'failure',
#  'financially',
#  'despite',
#  'favourable',
#  'reviews',
#  '23',
#  'next',
#  'film',
#  'released',
#  'january',
#  '2007',
#  "hari's",
#  'multi',
#  'starring',
#  'family',
#  'action',
#  'drama',
#  'thaamirabharani',
#  '2007',
#  'film',
#  'went',
#  'gain',
#  'considerable',
#  'box',
#  'office',
#  'success',
#  'carrying',
#  'good',
#  'reports',
#  'amidst',
#  'big',
#  'budget',
#  'releases',
#  '24',
#  '25',
#  'later',
#  'year',
#  'appeared',
#  'boopathy',
#  "pandian's",
#  'malaikottai',
#  '2007',
#  'comedy',
#  'entertainer',
#  'first',
#  'full',
#  'length',
#  'comic',
#  'role',
#  'vishal',
#  'received',
#  'mixed',
#  'feedback',
#  'portrayal',
#  'critics',
#  'rediff',
#  'stating',
#  'a',
#  'far',
#  'cry',
#  'rather',
#  'endearing',
#  'young',
#  'man',
#  'sandakozhi',
#  'whilst',
#  'describing',
#  'performance',
#  'cringe',
#  'able',
#  '26',
#  'behindwoods',
#  'stated',
#  'average',
#  'masala',
#  'mix',
#  'entertainer',
#  '27',
#  'film',
#  'took',
#  'large',
#  'opening',
#  'declared',
#  'blockbuster',
#  'featuring',
#  'top',
#  '10',
#  'behindwoods',
#  'box',
#  'office',
#  'year',
#  '2008',
#  'first',
#  'time',
#  'vishal',
#  'portrayed',
#  'police',
#  'officer',
#  'sathyam',
#  'became',
#  'commercial',
#  'failure',
#  'box',
#  'office',
#  'films',
#  'thoranai',
#  '2009',
#  'theeradha',
#  'vilaiyattu',
#  'pillai',
#  '2010',
#  'average',
#  'grossers',
#  'additionally',
#  'box',
#  'office',
#  'duds',
#  'sathyam',
#  'thoranai',
#  'bilingual',
#  'tamil',
#  'telugu',
#  'failed',
#  'establish',
#  'popularity',
#  'telugu',
#  'cinema',
#  '28',
#  'vishal',
#  'given',
#  'opportunity',
#  'feature',
#  "bala's",
#  'dark',
#  'comedy',
#  'avan',
#  'ivan',
#  '2011',
#  'recommended',
#  'director',
#  'friend',
#  'arya',
#  'portraying',
#  'village',
#  'stage',
#  'actor',
#  'squint',
#  'vishal',
#  'severe',
#  'eye',
#  'pain',
#  'headaches',
#  'also',
#  'serious',
#  'muscular',
#  'injury',
#  'sets',
#  '29',
#  'film',
#  'opened',
#  'mixed',
#  'reviews',
#  'though',
#  "vishal's",
#  'performance',
#  'positive',
#  'reviews',
#  'indiaglitz',
#  'stated',
#  'vishal',
#  'delivered',
#  'award',
#  'winning',
#  'performance',
#  'mannerisms',
#  'body',
#  'language',
#  'give',
#  'goosebumps',
#  'reviewer',
#  'cited',
#  "vishal's",
#  'spontaneous',
#  'response',
#  "mentor's",
#  'death',
#  'movie',
#  'touching',
#  'demonstration',
#  'navarasas',
#  'front',
#  'actor',
#  'suriya',
#  'melt',
#  'tears',
#  '30',
#  '31',
#  'vishal',
#  'played',
#  'role',
#  'police',
#  'officer',
#  'following',
#  'release',
#  'vedi',
#  '2011',
#  'directed',
#  'prabhu',
#  'deva',
#  'declared',
#  'instant',
#  'flop',
#  'box',
#  'office',
#  '32',
#  '2013',
#  'film',
#  'samar',
#  'vishal',
#  'played',
#  'forest',
#  'trek',
#  'guide',
#  'behindwoods',
#  'stated',
#  'rocks',
#  'action',
#  'sequences',
#  '33',
#  '34',
#  'following',
#  'cameo',
#  'role',
#  'theeya',
#  'velai',
#  'seiyyanum',
#  'kumaru',
#  'starred',
#  'action',
#  'films',
#  'pattathu',
#  'yaanai',
#  'pandiya',
#  'naadu',
#  'latter',
#  "vishal's",
#  'debut',
#  'production',
#  'venture',
#  '35',
#  '36',
#  'vishal',
#  'opted',
#  'produce',
#  'collaborate',
#  'thiru',
#  'third',
#  'venture',
#  'naan',
#  'sigappu',
#  'manithan',
#  '2014',
#  'revenge',
#  'drama',
#  'character',
#  'narcolepsy',
#  'prepare',
#  'lead',
#  'role',
#  'vishal',
#  'read',
#  'studied',
#  'real',
#  'life',
#  'case',
#  'studies',
#  'people',
#  'disorder',
#  'citing',
#  'references',
#  'cinema',
#  'could',
#  'watch',
#  'learn',
#  'acted',
#  'director',
#  'hari',
#  'second',
#  'time',
#  'poojai',
#  '2014',
#  'somewhat',
#  'good',
#  'business',
#  'box',
#  'office',
#  '2015',
#  'acted',
#  'two',
#  'films',
#  'namely',
#  'aambala',
#  'paayum',
#  'puli',
#  '37',
#  '38',
#  '2016',
#  'appeared',
#  'three',
#  'movies',
#  'kathakali',
#  'marudhu',
#  'kaththi',
#  'sandai',
#  'first',
#  'two',
#  'average',
#  'grossers',
#  'kaththi',
#  'sandai',
#  'became',
#  'flop',
#  'box',
#  'office',
#  'january',
#  '2017',
#  'vishal',
#  'signed',
#  'debut',
#  'malayalam',
#  'film',
#  'main',
#  'antagonist',
#  'mohanlal',
#  'starrer',
#  'villain',
#  'directed',
#  'b',
#  'unnikrishnan',
#  '39',
#  '40',
#  'september',
#  '2017',
#  'vishal',
#  'played',
#  'detective',
#  'thupparivaalan',
#  'directed',
#  'mysskin',
#  'loosely',
#  'based',
#  'british',
#  'writer',
#  'arthur',
#  'conan',
#  "doyle's",
#  'detective',
#  'character',
#  'sherlock',
#  'holmes',
#  'film',
#  'commercial',
#  'success',
#  'appreciated',
#  'audiences',
#  'critics',
#  '41',
#  '2018',
#  'vishal',
#  'two',
#  'major',
#  'releases',
#  'first',
#  'one',
#  'irumbu',
#  'thirai',
#  'directed',
#  'newcomer',
#  'p',
#  's',
#  'mithran',
#  'released',
#  'may',
#  '2018',
#  '42',
#  'second',
#  'sandakozhi',
#  '2',
#  'released',
#  'october',
#  '2018',
#  'written',
#  'directed',
#  'n',
#  'linguswamy',
#  'sequel',
#  'successful',
#  'sandakozhi',
#  '2005',
#  'film',
#  'stars',
#  'vishal',
#  '25th',
#  'film',
#  '43',
#  'film',
#  'turned',
#  'average',
#  'grosser',
#  '44',
#  '2019',
#  'one',
#  'movie',
#  'titled',
#  'action',
#  'directed',
#  'sundar',
#  'c',
#  '45',
#  'film',
#  'received',
#  'mixed',
#  'reviews',
#  'box',
#  'office',
#  'failure',
#  '46',
#  '2021',
#  'acted',
#  'action',
#  'thriller',
#  'chakra',
#  'directed',
#  'newcomer',
#  'm',
#  's',
#  'anandan',
#  'film',
#  'released',
#  '19',
#  'february',
#  'received',
#  'mixed',
#  'reviews',
#  'critics',
#  'audience',
#  '47',
#  'elected',
#  'president',
#  'tamil',
#  'film',
#  'producers',
#  'council',
#  'election',
#  'held',
#  '2',
#  'april',
#  '2017',
#  '48',
#  '49',
#  '50',
#  'apart',
#  'this',
#  'vishal',
#  'also',
#  'staunch',
#  'advocate',
#  'online',
#  'piracy',
#  'since',
#  '2014',
#  'started',
#  'anti',
#  'piracy',
#  'cell',
#  '51',
#  'made',
#  'television',
#  'début',
#  'october',
#  '2018',
#  'host',
#  'sun',
#  'naam',
#  'oruvar',
#  'talk',
#  'show',
#  'airing',
#  'sun',
#  'tv',
#  '52',
#  '53',
#  'vishal',
#  'filed',
#  'nomination',
#  'independent',
#  'candidate',
#  'by',
#  'poll',
#  'radhakrishnan',
#  'nagar',
#  'constituency',
#  'chennai',
#  'fell',
#  'vacant',
#  'following',
#  "jayalalithaa's",
#  'death',
#  'december',
#  '2017',
#  '54',
#  'nomination',
#  'rejected',
#  '55',
#  'vishal',
#  'arrested',
#  'police',
#  'december',
#  '2018',
#  'tried',
#  'enter',
#  'inside',
#  'tamil',
#  'film',
#  'producers',
#  'council',
#  'nagar',
#  'chennai',
#  'forcefully',
#  'trying',
#  'break',
#  'lock',
#  'council',
#  'locked',
#  '300',
#  'film',
#  'producers',
#  'alleging',
#  'vishal',
#  'failed',
#  'fulfil',
#  'promises',
#  'elections',
#  '2015',
#  '56',
#  'vishal',
#  'made',
#  'debut',
#  'playback',
#  'singer',
#  'madha',
#  'gaja',
#  'raja',
#  'unreleased',
#  'film',
#  'directed',
#  'sundar',
#  'c',
#  'crapping',
#  'song',
#  'dear',
#  'loveru']

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
word_tokenize(text)
# Out:
# ['vishal',
#  'krishna',
#  'reddy',
#  '(',
#  'born',
#  '29',
#  'august',
#  '1977',
#  ')',
#  ',',
#  '[',
#  '1',
#  ']',
#  'also',
#  'known',
#  'vishal',
#  ',',
#  'indian',
#  'actor',
#  'film',
#  'producer',
#  'works',
#  'tamil',
#  'cinema',
#  '.',
#  'younger',
#  'son',
#  'film',
#  'producer',
#  'g.',
#  'k.',
#  'reddy',
#  ',',
#  'vishal',
#  'studied',
#  'visual',
#  'communications',
#  'loyola',
#  'college',
#  ',',
#  'chennai',
#  '.',
#  'best',
#  'known',
#  'roles',
#  'action',
#  'films',
#  ',',
#  'produces',
#  'films',
#  'production',
#  'company',
#  ',',
#  'vishal',
#  'film',
#  'factory',
#  '.',
#  '[',
#  '2',
#  ']',
#  'vishal',
#  'made',
#  'entrance',
#  'film',
#  'industry',
#  'assistant',
#  'director',
#  'arjun',
#  '.',
#  'became',
#  'actor',
#  'played',
#  'first',
#  'lead',
#  'role',
#  'romantic',
#  'thriller',
#  'chellamae',
#  '(',
#  '2004',
#  ')',
#  ',',
#  'going',
#  'star',
#  'commercially',
#  'successful',
#  'action',
#  'films',
#  'sandakozhi',
#  ',',
#  'thimiru',
#  ',',
#  'thaamirabharani',
#  'malaikottai',
#  '.',
#  '[',
#  '3',
#  ']',
#  'following',
#  'series',
#  'unsuccessful',
#  'films',
#  'box',
#  'office',
#  ',',
#  'vishal',
#  'chose',
#  'create',
#  'production',
#  'studio',
#  'since',
#  'produced',
#  'worked',
#  'profitable',
#  'ventures',
#  'pandiya',
#  'naadu',
#  '(',
#  '2013',
#  ')',
#  ',',
#  'naan',
#  'sigappu',
#  'manithan',
#  '(',
#  '2014',
#  ')',
#  'poojai',
#  '(',
#  '2014',
#  ')',
#  '.',
#  '[',
#  '4',
#  ']',
#  'vishal',
#  'elected',
#  'general',
#  'secretary',
#  'nadigar',
#  'sangam',
#  'october',
#  '2015',
#  'initiating',
#  'movement',
#  'previous',
#  'committee',
#  '.',
#  '[',
#  '5',
#  ']',
#  'expelled',
#  'tamil',
#  'film',
#  'producers',
#  "'",
#  'council',
#  '(',
#  'tfpc',
#  ')',
#  'remarks',
#  'council',
#  '.',
#  '[',
#  '6',
#  ']',
#  '[',
#  '7',
#  ']',
#  'later',
#  'april',
#  '2017',
#  ',',
#  'election',
#  'got',
#  'elected',
#  'president',
#  'tamil',
#  'film',
#  'producers',
#  'council',
#  '.',
#  'vishal',
#  'krishna',
#  'reddy',
#  'born',
#  '29',
#  'august',
#  '1977',
#  '[',
#  '8',
#  ']',
#  '[',
#  '9',
#  ']',
#  'telugu',
#  'family',
#  'chennai',
#  ',',
#  'tamil',
#  'nadu',
#  '.',
#  '[',
#  '10',
#  ']',
#  'father',
#  'gk',
#  'reddy',
#  'businessman',
#  'film',
#  'producer',
#  'telugu',
#  'tamil',
#  'films',
#  '.',
#  '[',
#  '11',
#  ']',
#  'elder',
#  'brother',
#  'vikram',
#  'krishna',
#  'also',
#  'actor',
#  'producer',
#  'produced',
#  'several',
#  'vishal',
#  "'s",
#  'films',
#  '.',
#  '[',
#  '12',
#  ']',
#  'vishal',
#  'obtained',
#  'degree',
#  'visual',
#  'communications',
#  'loyola',
#  'college',
#  ',',
#  'chennai',
#  '.',
#  '[',
#  '13',
#  ']',
#  'vishal',
#  'assisted',
#  'actor-director',
#  'arjun',
#  'sarja',
#  'venture',
#  'vedham',
#  '(',
#  '2001',
#  ')',
#  ',',
#  'producer',
#  'spotted',
#  'vishal',
#  'sets',
#  'film',
#  'signed',
#  'appear',
#  'acting',
#  'role',
#  'gandhi',
#  'krishna',
#  "'s",
#  'chellamae',
#  '(',
#  '2004',
#  ')',
#  '.',
#  '[',
#  '14',
#  ']',
#  '[',
#  '15',
#  ']',
#  'accepting',
#  'role',
#  ',',
#  'vishal',
#  'prepared',
#  'joining',
#  'koothu-p-pattarai',
#  'hone',
#  'acting',
#  'skills',
#  'played',
#  'protagonist',
#  'role',
#  'raghunandan',
#  ',',
#  'whose',
#  'wife',
#  'kidnapped',
#  'childhood',
#  'friend',
#  '.',
#  '[',
#  '15',
#  ']',
#  'critic',
#  'described',
#  'performance',
#  '``',
#  'apt',
#  "''",
#  '``',
#  'there',
#  'plenty',
#  'left',
#  'hone',
#  "''",
#  '.',
#  '[',
#  '16',
#  ']',
#  '[',
#  '17',
#  ']',
#  'next',
#  'film',
#  'sandakozhi',
#  '(',
#  '2005',
#  ')',
#  'n.',
#  'linguswamy',
#  ',',
#  'previously',
#  'worked',
#  'father',
#  "'s",
#  'production',
#  'house',
#  'assistant',
#  'director',
#  '.',
#  '[',
#  '18',
#  ']',
#  'vishal',
#  'described',
#  '``',
#  'improved',
#  'chellamae',
#  'days',
#  "''",
#  '``',
#  'clicked',
#  'action',
#  'hero',
#  "''",
#  '.',
#  '[',
#  '19',
#  ']',
#  'film',
#  'journalists',
#  'stated',
#  '``',
#  'the',
#  'fastest',
#  'rising',
#  'action',
#  'hero',
#  "''",
#  'time',
#  '.',
#  '[',
#  '20',
#  ']',
#  'cameo',
#  'sasi',
#  "'s",
#  'dishyum',
#  '(',
#  '2006',
#  ')',
#  ',',
#  'went',
#  'appear',
#  'tarun',
#  'gopi',
#  "'s",
#  'action',
#  'film',
#  'thimiru',
#  '(',
#  '2006',
#  ')',
#  '.',
#  'film',
#  'opened',
#  'mixed',
#  'reviews',
#  'vishal',
#  'praised',
#  'intense',
#  'performance',
#  'critic',
#  'calling',
#  'performance',
#  '``',
#  'the',
#  'film',
#  "'s",
#  'strength',
#  'and',
#  ',',
#  'extent',
#  ',',
#  'making',
#  'weak',
#  'script',
#  'poor',
#  'characterisation',
#  "''",
#  '.',
#  '[',
#  '21',
#  ']',
#  'film',
#  'became',
#  'vishal',
#  "'s",
#  'third',
#  'consecutive',
#  'commercial',
#  'success',
#  ',',
#  'began',
#  'emerge',
#  'tamil',
#  'films',
#  '.',
#  '[',
#  '22',
#  ']',
#  'next',
#  'film',
#  ',',
#  'political',
#  'action',
#  'drama',
#  'sivappathigaram',
#  '(',
#  '2006',
#  ')',
#  ',',
#  'directed',
#  'karu',
#  'pazhaniappan',
#  'failure',
#  'financially',
#  'despite',
#  'favourable',
#  'reviews',
#  '.',
#  '[',
#  '23',
#  ']',
#  'next',
#  'film',
#  'released',
#  'january',
#  '2007',
#  ',',
#  'hari',
#  "'s",
#  'multi-starring',
#  'family',
#  'action',
#  'drama',
#  'thaamirabharani',
#  '(',
#  '2007',
#  ')',
#  'film',
#  'went',
#  'gain',
#  'considerable',
#  'box',
#  'office',
#  'success',
#  ',',
#  'carrying',
#  'good',
#  'reports',
#  'amidst',
#  'big',
#  'budget',
#  'releases',
#  '.',
#  '[',
#  '24',
#  ']',
#  '[',
#  '25',
#  ']',
#  'later',
#  'year',
#  ',',
#  'appeared',
#  'boopathy',
#  'pandian',
#  "'s",
#  'malaikottai',
#  '(',
#  '2007',
#  ')',
#  ',',
#  'comedy',
#  'entertainer',
#  '.',
#  'first',
#  'full-length',
#  'comic',
#  'role',
#  ',',
#  'vishal',
#  'received',
#  'mixed',
#  'feedback',
#  'portrayal',
#  'critics',
#  ',',
#  'rediff',
#  'stating',
#  '``',
#  'a',
#  'far',
#  'cry',
#  'rather',
#  'endearing',
#  'young',
#  'man',
#  'sandakozhi',
#  "''",
#  ',',
#  'whilst',
#  'describing',
#  'performance',
#  '``',
#  'cringe-able',
#  "''",
#  '.',
#  '[',
#  '26',
#  ']',
#  'behindwoods',
#  'stated',
#  '``',
#  'average',
#  'masala-mix',
#  'entertainer',
#  "''",
#  '.',
#  '[',
#  '27',
#  ']',
#  'film',
#  'took',
#  'large',
#  'opening',
#  'declared',
#  'blockbuster',
#  ',',
#  'featuring',
#  'top',
#  '10',
#  'behindwoods',
#  'box',
#  'office',
#  '.',
#  'year',
#  '2008',
#  ',',
#  'first',
#  'time',
#  ',',
#  'vishal',
#  'portrayed',
#  'police',
#  'officer',
#  'sathyam',
#  ',',
#  'became',
#  'commercial',
#  'failure',
#  'box',
#  'office',
#  '.',
#  'films',
#  'thoranai',
#  '(',
#  '2009',
#  ')',
#  'theeradha',
#  'vilaiyattu',
#  'pillai',
#  '(',
#  '2010',
#  ')',
#  'average',
#  'grossers',
#  '.',
#  'additionally',
#  ',',
#  'box-office',
#  'duds',
#  ',',
#  'sathyam',
#  'thoranai',
#  ',',
#  'bilingual',
#  'tamil',
#  'telugu',
#  ',',
#  'failed',
#  'establish',
#  'popularity',
#  'telugu',
#  'cinema',
#  '.',
#  '[',
#  '28',
#  ']',
#  'vishal',
#  'given',
#  'opportunity',
#  'feature',
#  'bala',
#  "'s",
#  'dark',
#  'comedy',
#  'avan',
#  'ivan',
#  '(',
#  '2011',
#  ')',
#  ',',
#  'recommended',
#  'director',
#  'friend',
#  'arya',
#  '.',
#  'portraying',
#  'village',
#  'stage',
#  'actor',
#  'squint',
#  ',',
#  'vishal',
#  'severe',
#  'eye',
#  'pain',
#  'headaches',
#  ',',
#  'also',
#  'serious',
#  'muscular',
#  'injury',
#  'sets',
#  '.',
#  '[',
#  '29',
#  ']',
#  'film',
#  'opened',
#  'mixed',
#  'reviews',
#  ',',
#  'though',
#  'vishal',
#  "'s",
#  'performance',
#  'positive',
#  'reviews',
#  '.',
#  'indiaglitz',
#  'stated',
#  'vishal',
#  'delivered',
#  '``',
#  'award',
#  'winning',
#  'performance',
#  "''",
#  '``',
#  'mannerisms',
#  'body',
#  'language',
#  'give',
#  'goosebumps',
#  "''",
#  '.',
#  'reviewer',
#  'cited',
#  '``',
#  'vishal',
#  "'s",
#  'spontaneous',
#  'response',
#  'mentor',
#  "'s",
#  'death',
#  'movie',
#  'touching',
#  '.',
#  'demonstration',
#  'navarasas',
#  'front',
#  'actor',
#  'suriya',
#  'melt',
#  'tears',
#  "''",
#  '.',
#  '[',
#  '30',
#  ']',
#  '[',
#  '31',
#  ']',
#  'vishal',
#  'played',
#  'role',
#  'police',
#  'officer',
#  'following',
#  'release',
#  'vedi',
#  '(',
#  '2011',
#  ')',
#  ',',
#  'directed',
#  'prabhu',
#  'deva',
#  ',',
#  'declared',
#  'instant',
#  'flop',
#  'box',
#  'office',
#  '.',
#  '[',
#  '32',
#  ']',
#  '2013',
#  'film',
#  'samar',
#  ',',
#  'vishal',
#  'played',
#  'forest',
#  'trek',
#  'guide',
#  '.',
#  'behindwoods',
#  'stated',
#  '``',
#  'rocks',
#  'action',
#  'sequences',
#  "''",
#  '.',
#  '[',
#  '33',
#  ']',
#  '[',
#  '34',
#  ']',
#  'following',
#  'cameo',
#  'role',
#  'theeya',
#  'velai',
#  'seiyyanum',
#  'kumaru',
#  ',',
#  'starred',
#  'action',
#  'films',
#  'pattathu',
#  'yaanai',
#  'pandiya',
#  'naadu',
#  '.',
#  'latter',
#  'vishal',
#  "'s",
#  'debut',
#  'production',
#  'venture',
#  '.',
#  '[',
#  '35',
#  ']',
#  '[',
#  '36',
#  ']',
#  'vishal',
#  'opted',
#  'produce',
#  'collaborate',
#  'thiru',
#  'third',
#  'venture',
#  'naan',
#  'sigappu',
#  'manithan',
#  '(',
#  '2014',
#  ')',
#  ',',
#  'revenge',
#  'drama',
#  ',',
#  'character',
#  'narcolepsy',
#  '.',
#  'prepare',
#  'lead',
#  'role',
#  ',',
#  'vishal',
#  'read',
#  'studied',
#  'real',
#  'life',
#  'case',
#  'studies',
#  'people',
#  'disorder',
#  ',',
#  'citing',
#  'references',
#  'cinema',
#  'could',
#  'watch',
#  'learn',
#  '.',
#  'acted',
#  'director',
#  'hari',
#  'second',
#  'time',
#  'poojai',
#  '(',
#  '2014',
#  ')',
#  ',',
#  'somewhat',
#  'good',
#  'business',
#  'box',
#  'office',
#  '.',
#  '2015',
#  ',',
#  'acted',
#  'two',
#  'films',
#  ',',
#  'namely',
#  ',',
#  'aambala',
#  'paayum',
#  'puli',
#  '.',
#  '[',
#  '37',
#  ']',
#  '[',
#  '38',
#  ']',
#  '2016',
#  ',',
#  'appeared',
#  'three',
#  'movies',
#  ';',
#  'kathakali',
#  ',',
#  'marudhu',
#  'kaththi',
#  'sandai',
#  '.',
#  'first',
#  'two',
#  'average',
#  'grossers',
#  ',',
#  'kaththi',
#  'sandai',
#  'became',
#  'flop',
#  'box',
#  'office',
#  '.',
#  'january',
#  '2017',
#  ',',
#  'vishal',
#  'signed',
#  'debut',
#  'malayalam',
#  'film',
#  ',',
#  'main',
#  'antagonist',
#  'mohanlal-starrer',
#  'villain',
#  ',',
#  'directed',
#  'b',
#  '.',
#  'unnikrishnan',
#  '.',
#  '[',
#  '39',
#  ']',
#  '[',
#  '40',
#  ']',
#  'september',
#  '2017',
#  ',',
#  'vishal',
#  'played',
#  'detective',
#  'thupparivaalan',
#  'directed',
#  'mysskin',
#  'loosely',
#  'based',
#  'british',
#  'writer',
#  'arthur',
#  'conan',
#  'doyle',
#  "'s",
#  'detective',
#  'character',
#  ',',
#  'sherlock',
#  'holmes',
#  '.',
#  'film',
#  'commercial',
#  'success',
#  'appreciated',
#  'audiences',
#  'critics',
#  '.',
#  '[',
#  '41',
#  ']',
#  '2018',
#  ',',
#  'vishal',
#  'two',
#  'major',
#  'releases',
#  '.',
#  'first',
#  'one',
#  'irumbu',
#  'thirai',
#  'directed',
#  'newcomer',
#  'p.',
#  's.',
#  'mithran',
#  'released',
#  'may',
#  '2018',
#  '.',
#  '[',
#  '42',
#  ']',
#  'second',
#  'sandakozhi',
#  '2',
#  'released',
#  'october',
#  '2018',
#  'written',
#  'directed',
#  'n.',
#  'linguswamy',
#  '.',
#  'sequel',
#  'successful',
#  ...]

# %%
nltk_text = word_tokenize(text)

# %%
nltk.hel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 nltk.help.upenn_tagset(pos_tag)
#
# NameError: name 'pos_tag' is not defined

# %%
nltk.pos_tag(nltk_text)
# Out:
# [('vishal', 'JJ'),
#  ('krishna', 'NN'),
#  ('reddy', 'NN'),
#  ('(', '('),
#  ('born', 'JJ'),
#  ('29', 'CD'),
#  ('august', 'JJ'),
#  ('1977', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('[', '$'),
#  ('1', 'CD'),
#  (']', 'NNP'),
#  ('also', 'RB'),
#  ('known', 'VBN'),
#  ('vishal', 'NN'),
#  (',', ','),
#  ('indian', 'JJ'),
#  ('actor', 'NN'),
#  ('film', 'NN'),
#  ('producer', 'NN'),
#  ('works', 'VBZ'),
#  ('tamil', 'JJ'),
#  ('cinema', 'NN'),
#  ('.', '.'),
#  ('younger', 'JJR'),
#  ('son', 'NN'),
#  ('film', 'NN'),
#  ('producer', 'NN'),
#  ('g.', 'NN'),
#  ('k.', 'NN'),
#  ('reddy', 'NN'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('studied', 'VBN'),
#  ('visual', 'JJ'),
#  ('communications', 'NNS'),
#  ('loyola', 'VBP'),
#  ('college', 'NN'),
#  (',', ','),
#  ('chennai', 'NN'),
#  ('.', '.'),
#  ('best', 'JJS'),
#  ('known', 'JJ'),
#  ('roles', 'NNS'),
#  ('action', 'NN'),
#  ('films', 'NNS'),
#  (',', ','),
#  ('produces', 'VBZ'),
#  ('films', 'NNS'),
#  ('production', 'NN'),
#  ('company', 'NN'),
#  (',', ','),
#  ('vishal', 'NN'),
#  ('film', 'NN'),
#  ('factory', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('2', 'CD'),
#  (']', 'NN'),
#  ('vishal', 'NN'),
#  ('made', 'VBD'),
#  ('entrance', 'NN'),
#  ('film', 'NN'),
#  ('industry', 'NN'),
#  ('assistant', 'NN'),
#  ('director', 'NN'),
#  ('arjun', 'NN'),
#  ('.', '.'),
#  ('became', 'VBD'),
#  ('actor', 'JJ'),
#  ('played', 'VBD'),
#  ('first', 'JJ'),
#  ('lead', 'JJ'),
#  ('role', 'NN'),
#  ('romantic', 'JJ'),
#  ('thriller', 'NN'),
#  ('chellamae', 'NN'),
#  ('(', '('),
#  ('2004', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('going', 'VBG'),
#  ('star', 'NN'),
#  ('commercially', 'RB'),
#  ('successful', 'JJ'),
#  ('action', 'NN'),
#  ('films', 'NNS'),
#  ('sandakozhi', 'NN'),
#  (',', ','),
#  ('thimiru', 'NN'),
#  (',', ','),
#  ('thaamirabharani', 'JJ'),
#  ('malaikottai', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('3', 'CD'),
#  (']', 'NN'),
#  ('following', 'VBG'),
#  ('series', 'NN'),
#  ('unsuccessful', 'JJ'),
#  ('films', 'NNS'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  (',', ','),
#  ('vishal', 'VBP'),
#  ('chose', 'JJ'),
#  ('create', 'NN'),
#  ('production', 'NN'),
#  ('studio', 'NN'),
#  ('since', 'IN'),
#  ('produced', 'VBN'),
#  ('worked', 'VBD'),
#  ('profitable', 'JJ'),
#  ('ventures', 'NNS'),
#  ('pandiya', 'VBP'),
#  ('naadu', 'RB'),
#  ('(', '('),
#  ('2013', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('naan', 'JJ'),
#  ('sigappu', 'NN'),
#  ('manithan', 'NN'),
#  ('(', '('),
#  ('2014', 'CD'),
#  (')', ')'),
#  ('poojai', 'NN'),
#  ('(', '('),
#  ('2014', 'CD'),
#  (')', ')'),
#  ('.', '.'),
#  ('[', '$'),
#  ('4', 'CD'),
#  (']', 'NNP'),
#  ('vishal', 'NN'),
#  ('elected', 'VBD'),
#  ('general', 'JJ'),
#  ('secretary', 'NN'),
#  ('nadigar', 'NN'),
#  ('sangam', 'VBD'),
#  ('october', 'JJ'),
#  ('2015', 'CD'),
#  ('initiating', 'VBG'),
#  ('movement', 'NN'),
#  ('previous', 'JJ'),
#  ('committee', 'NN'),
#  ('.', '.'),
#  ('[', '$'),
#  ('5', 'CD'),
#  (']', 'NNP'),
#  ('expelled', 'VBD'),
#  ('tamil', 'NN'),
#  ('film', 'NN'),
#  ('producers', 'NNS'),
#  ("'", 'POS'),
#  ('council', 'NN'),
#  ('(', '('),
#  ('tfpc', 'NN'),
#  (')', ')'),
#  ('remarks', 'NNS'),
#  ('council', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('6', 'CD'),
#  (']', 'JJ'),
#  ('[', '$'),
#  ('7', 'CD'),
#  (']', 'NN'),
#  ('later', 'RB'),
#  ('april', 'JJ'),
#  ('2017', 'CD'),
#  (',', ','),
#  ('election', 'NN'),
#  ('got', 'VBD'),
#  ('elected', 'VBN'),
#  ('president', 'NN'),
#  ('tamil', 'NN'),
#  ('film', 'NN'),
#  ('producers', 'NNS'),
#  ('council', 'VBP'),
#  ('.', '.'),
#  ('vishal', 'JJ'),
#  ('krishna', 'NN'),
#  ('reddy', 'NN'),
#  ('born', 'VBD'),
#  ('29', 'CD'),
#  ('august', 'JJ'),
#  ('1977', 'CD'),
#  ('[', 'NN'),
#  ('8', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('9', 'CD'),
#  (']', 'NNP'),
#  ('telugu', 'VBD'),
#  ('family', 'NN'),
#  ('chennai', 'NN'),
#  (',', ','),
#  ('tamil', 'JJ'),
#  ('nadu', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('10', 'CD'),
#  (']', 'NN'),
#  ('father', 'NN'),
#  ('gk', 'NN'),
#  ('reddy', 'JJ'),
#  ('businessman', 'NN'),
#  ('film', 'NN'),
#  ('producer', 'NN'),
#  ('telugu', 'NN'),
#  ('tamil', 'NN'),
#  ('films', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('11', 'CD'),
#  (']', 'NNP'),
#  ('elder', 'NN'),
#  ('brother', 'NN'),
#  ('vikram', 'NN'),
#  ('krishna', 'NN'),
#  ('also', 'RB'),
#  ('actor', 'JJ'),
#  ('producer', 'NN'),
#  ('produced', 'VBD'),
#  ('several', 'JJ'),
#  ('vishal', 'NN'),
#  ("'s", 'POS'),
#  ('films', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('12', 'CD'),
#  (']', 'NNP'),
#  ('vishal', 'NN'),
#  ('obtained', 'VBD'),
#  ('degree', 'JJ'),
#  ('visual', 'JJ'),
#  ('communications', 'NNS'),
#  ('loyola', 'VBP'),
#  ('college', 'NN'),
#  (',', ','),
#  ('chennai', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('13', 'CD'),
#  (']', 'JJ'),
#  ('vishal', 'NN'),
#  ('assisted', 'VBD'),
#  ('actor-director', 'JJ'),
#  ('arjun', 'NN'),
#  ('sarja', 'JJ'),
#  ('venture', 'NN'),
#  ('vedham', 'NN'),
#  ('(', '('),
#  ('2001', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('producer', 'NN'),
#  ('spotted', 'VBD'),
#  ('vishal', 'JJ'),
#  ('sets', 'NNS'),
#  ('film', 'NN'),
#  ('signed', 'VBD'),
#  ('appear', 'RB'),
#  ('acting', 'VBG'),
#  ('role', 'NN'),
#  ('gandhi', 'NN'),
#  ('krishna', 'NN'),
#  ("'s", 'POS'),
#  ('chellamae', 'NN'),
#  ('(', '('),
#  ('2004', 'CD'),
#  (')', ')'),
#  ('.', '.'),
#  ('[', '$'),
#  ('14', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('15', 'CD'),
#  (']', 'JJ'),
#  ('accepting', 'VBG'),
#  ('role', 'NN'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('prepared', 'JJ'),
#  ('joining', 'VBG'),
#  ('koothu-p-pattarai', 'JJ'),
#  ('hone', 'NN'),
#  ('acting', 'VBG'),
#  ('skills', 'NNS'),
#  ('played', 'VBN'),
#  ('protagonist', 'JJ'),
#  ('role', 'NN'),
#  ('raghunandan', 'NN'),
#  (',', ','),
#  ('whose', 'WP$'),
#  ('wife', 'NN'),
#  ('kidnapped', 'VBD'),
#  ('childhood', 'NN'),
#  ('friend', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('15', 'CD'),
#  (']', 'JJ'),
#  ('critic', 'JJ'),
#  ('described', 'VBD'),
#  ('performance', 'NN'),
#  ('``', '``'),
#  ('apt', 'JJ'),
#  ("''", "''"),
#  ('``', '``'),
#  ('there', 'EX'),
#  ('plenty', 'JJ'),
#  ('left', 'VBD'),
#  ('hone', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('16', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('17', 'CD'),
#  (']', 'NNP'),
#  ('next', 'JJ'),
#  ('film', 'NN'),
#  ('sandakozhi', 'NN'),
#  ('(', '('),
#  ('2005', 'CD'),
#  (')', ')'),
#  ('n.', 'FW'),
#  ('linguswamy', 'NN'),
#  (',', ','),
#  ('previously', 'RB'),
#  ('worked', 'VBD'),
#  ('father', 'NN'),
#  ("'s", 'POS'),
#  ('production', 'NN'),
#  ('house', 'NN'),
#  ('assistant', 'JJ'),
#  ('director', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('18', 'CD'),
#  (']', 'JJ'),
#  ('vishal', 'NN'),
#  ('described', 'VBD'),
#  ('``', '``'),
#  ('improved', 'JJ'),
#  ('chellamae', 'NN'),
#  ('days', 'NNS'),
#  ("''", "''"),
#  ('``', '``'),
#  ('clicked', 'VBD'),
#  ('action', 'NN'),
#  ('hero', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('19', 'CD'),
#  (']', 'NNP'),
#  ('film', 'NN'),
#  ('journalists', 'NNS'),
#  ('stated', 'VBD'),
#  ('``', '``'),
#  ('the', 'DT'),
#  ('fastest', 'JJS'),
#  ('rising', 'VBG'),
#  ('action', 'NN'),
#  ('hero', 'NN'),
#  ("''", "''"),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('20', 'CD'),
#  (']', 'NNP'),
#  ('cameo', 'NN'),
#  ('sasi', 'NN'),
#  ("'s", 'POS'),
#  ('dishyum', 'NN'),
#  ('(', '('),
#  ('2006', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('went', 'VBD'),
#  ('appear', 'JJ'),
#  ('tarun', 'IN'),
#  ('gopi', 'NN'),
#  ("'s", 'POS'),
#  ('action', 'NN'),
#  ('film', 'NN'),
#  ('thimiru', 'NN'),
#  ('(', '('),
#  ('2006', 'CD'),
#  (')', ')'),
#  ('.', '.'),
#  ('film', 'NN'),
#  ('opened', 'VBD'),
#  ('mixed', 'JJ'),
#  ('reviews', 'NNS'),
#  ('vishal', 'NNS'),
#  ('praised', 'VBD'),
#  ('intense', 'JJ'),
#  ('performance', 'NN'),
#  ('critic', 'JJ'),
#  ('calling', 'VBG'),
#  ('performance', 'NN'),
#  ('``', '``'),
#  ('the', 'DT'),
#  ('film', 'NN'),
#  ("'s", 'POS'),
#  ('strength', 'NN'),
#  ('and', 'CC'),
#  (',', ','),
#  ('extent', 'NN'),
#  (',', ','),
#  ('making', 'VBG'),
#  ('weak', 'JJ'),
#  ('script', 'NN'),
#  ('poor', 'JJ'),
#  ('characterisation', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('21', 'CD'),
#  (']', 'NNP'),
#  ('film', 'NN'),
#  ('became', 'VBD'),
#  ('vishal', 'NN'),
#  ("'s", 'POS'),
#  ('third', 'JJ'),
#  ('consecutive', 'JJ'),
#  ('commercial', 'JJ'),
#  ('success', 'NN'),
#  (',', ','),
#  ('began', 'VBD'),
#  ('emerge', 'JJ'),
#  ('tamil', 'JJ'),
#  ('films', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('22', 'CD'),
#  (']', 'NNP'),
#  ('next', 'JJ'),
#  ('film', 'NN'),
#  (',', ','),
#  ('political', 'JJ'),
#  ('action', 'NN'),
#  ('drama', 'NN'),
#  ('sivappathigaram', 'NN'),
#  ('(', '('),
#  ('2006', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('directed', 'VBD'),
#  ('karu', 'NN'),
#  ('pazhaniappan', 'NN'),
#  ('failure', 'NN'),
#  ('financially', 'RB'),
#  ('despite', 'IN'),
#  ('favourable', 'JJ'),
#  ('reviews', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('23', 'CD'),
#  (']', 'NNP'),
#  ('next', 'JJ'),
#  ('film', 'NN'),
#  ('released', 'VBN'),
#  ('january', 'JJ'),
#  ('2007', 'CD'),
#  (',', ','),
#  ('hari', 'PRP'),
#  ("'s", 'VBZ'),
#  ('multi-starring', 'JJ'),
#  ('family', 'NN'),
#  ('action', 'NN'),
#  ('drama', 'NN'),
#  ('thaamirabharani', 'NN'),
#  ('(', '('),
#  ('2007', 'CD'),
#  (')', ')'),
#  ('film', 'NN'),
#  ('went', 'VBD'),
#  ('gain', 'NN'),
#  ('considerable', 'JJ'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  ('success', 'NN'),
#  (',', ','),
#  ('carrying', 'VBG'),
#  ('good', 'JJ'),
#  ('reports', 'NNS'),
#  ('amidst', 'RB'),
#  ('big', 'JJ'),
#  ('budget', 'NN'),
#  ('releases', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('24', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('25', 'CD'),
#  (']', 'NN'),
#  ('later', 'RB'),
#  ('year', 'NN'),
#  (',', ','),
#  ('appeared', 'VBD'),
#  ('boopathy', 'JJ'),
#  ('pandian', 'NN'),
#  ("'s", 'POS'),
#  ('malaikottai', 'NN'),
#  ('(', '('),
#  ('2007', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('comedy', 'NN'),
#  ('entertainer', 'NN'),
#  ('.', '.'),
#  ('first', 'JJ'),
#  ('full-length', 'JJ'),
#  ('comic', 'JJ'),
#  ('role', 'NN'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('received', 'VBD'),
#  ('mixed', 'JJ'),
#  ('feedback', 'NN'),
#  ('portrayal', 'NN'),
#  ('critics', 'NNS'),
#  (',', ','),
#  ('rediff', 'NN'),
#  ('stating', 'VBG'),
#  ('``', '``'),
#  ('a', 'DT'),
#  ('far', 'RB'),
#  ('cry', 'NN'),
#  ('rather', 'RB'),
#  ('endearing', 'VBG'),
#  ('young', 'JJ'),
#  ('man', 'NN'),
#  ('sandakozhi', 'NN'),
#  ("''", "''"),
#  (',', ','),
#  ('whilst', 'VBD'),
#  ('describing', 'VBG'),
#  ('performance', 'NN'),
#  ('``', '``'),
#  ('cringe-able', 'JJ'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('26', 'CD'),
#  (']', 'NNP'),
#  ('behindwoods', 'NNS'),
#  ('stated', 'VBD'),
#  ('``', '``'),
#  ('average', 'JJ'),
#  ('masala-mix', 'JJ'),
#  ('entertainer', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('27', 'CD'),
#  (']', 'NNP'),
#  ('film', 'NN'),
#  ('took', 'VBD'),
#  ('large', 'JJ'),
#  ('opening', 'NN'),
#  ('declared', 'VBD'),
#  ('blockbuster', 'NN'),
#  (',', ','),
#  ('featuring', 'VBG'),
#  ('top', 'JJ'),
#  ('10', 'CD'),
#  ('behindwoods', 'NNS'),
#  ('box', 'JJ'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('year', 'NN'),
#  ('2008', 'CD'),
#  (',', ','),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  (',', ','),
#  ('vishal', 'JJ'),
#  ('portrayed', 'JJ'),
#  ('police', 'NN'),
#  ('officer', 'NN'),
#  ('sathyam', 'NN'),
#  (',', ','),
#  ('became', 'VBD'),
#  ('commercial', 'JJ'),
#  ('failure', 'NN'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('films', 'NNS'),
#  ('thoranai', 'NN'),
#  ('(', '('),
#  ('2009', 'CD'),
#  (')', ')'),
#  ('theeradha', 'NN'),
#  ('vilaiyattu', 'NN'),
#  ('pillai', 'NN'),
#  ('(', '('),
#  ('2010', 'CD'),
#  (')', ')'),
#  ('average', 'NN'),
#  ('grossers', 'NNS'),
#  ('.', '.'),
#  ('additionally', 'RB'),
#  (',', ','),
#  ('box-office', 'JJ'),
#  ('duds', 'NN'),
#  (',', ','),
#  ('sathyam', 'NN'),
#  ('thoranai', 'NN'),
#  (',', ','),
#  ('bilingual', 'JJ'),
#  ('tamil', 'NN'),
#  ('telugu', 'NN'),
#  (',', ','),
#  ('failed', 'VBD'),
#  ('establish', 'VB'),
#  ('popularity', 'NN'),
#  ('telugu', 'JJ'),
#  ('cinema', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('28', 'CD'),
#  (']', 'JJ'),
#  ('vishal', 'NN'),
#  ('given', 'VBN'),
#  ('opportunity', 'NN'),
#  ('feature', 'NN'),
#  ('bala', 'NN'),
#  ("'s", 'POS'),
#  ('dark', 'JJ'),
#  ('comedy', 'NN'),
#  ('avan', 'NN'),
#  ('ivan', 'NN'),
#  ('(', '('),
#  ('2011', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('recommended', 'VBD'),
#  ('director', 'NN'),
#  ('friend', 'NN'),
#  ('arya', 'NN'),
#  ('.', '.'),
#  ('portraying', 'VBG'),
#  ('village', 'NN'),
#  ('stage', 'NN'),
#  ('actor', 'NN'),
#  ('squint', 'NN'),
#  (',', ','),
#  ('vishal', 'NN'),
#  ('severe', 'JJ'),
#  ('eye', 'NN'),
#  ('pain', 'NN'),
#  ('headaches', 'NNS'),
#  (',', ','),
#  ('also', 'RB'),
#  ('serious', 'JJ'),
#  ('muscular', 'JJ'),
#  ('injury', 'NN'),
#  ('sets', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('29', 'CD'),
#  (']', 'NNP'),
#  ('film', 'NN'),
#  ('opened', 'VBD'),
#  ('mixed', 'JJ'),
#  ('reviews', 'NNS'),
#  (',', ','),
#  ('though', 'IN'),
#  ('vishal', 'NN'),
#  ("'s", 'POS'),
#  ('performance', 'NN'),
#  ('positive', 'JJ'),
#  ('reviews', 'NNS'),
#  ('.', '.'),
#  ('indiaglitz', 'NN'),
#  ('stated', 'VBD'),
#  ('vishal', 'RB'),
#  ('delivered', 'VBN'),
#  ('``', '``'),
#  ('award', 'JJ'),
#  ('winning', 'NN'),
#  ('performance', 'NN'),
#  ("''", "''"),
#  ('``', '``'),
#  ('mannerisms', 'FW'),
#  ('body', 'NN'),
#  ('language', 'NN'),
#  ('give', 'JJ'),
#  ('goosebumps', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('reviewer', 'VB'),
#  ('cited', 'VBN'),
#  ('``', '``'),
#  ('vishal', 'NN'),
#  ("'s", 'POS'),
#  ('spontaneous', 'JJ'),
#  ('response', 'NN'),
#  ('mentor', 'NN'),
#  ("'s", 'POS'),
#  ('death', 'NN'),
#  ('movie', 'NN'),
#  ('touching', 'VBG'),
#  ('.', '.'),
#  ('demonstration', 'NN'),
#  ('navarasas', 'JJ'),
#  ('front', 'JJ'),
#  ('actor', 'NN'),
#  ('suriya', 'NN'),
#  ('melt', 'VBD'),
#  ('tears', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('30', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('31', 'CD'),
#  (']', 'NNP'),
#  ('vishal', 'FW'),
#  ('played', 'VBD'),
#  ('role', 'NN'),
#  ('police', 'NNS'),
#  ('officer', 'NN'),
#  ('following', 'VBG'),
#  ('release', 'NN'),
#  ('vedi', 'NN'),
#  ('(', '('),
#  ('2011', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('directed', 'VBD'),
#  ('prabhu', 'NN'),
#  ('deva', 'NN'),
#  (',', ','),
#  ('declared', 'VBD'),
#  ('instant', 'JJ'),
#  ('flop', 'NN'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('32', 'CD'),
#  (']', 'JJ'),
#  ('2013', 'CD'),
#  ('film', 'NN'),
#  ('samar', 'NN'),
#  (',', ','),
#  ('vishal', 'JJ'),
#  ('played', 'VBD'),
#  ('forest', 'JJS'),
#  ('trek', 'NN'),
#  ('guide', 'NN'),
#  ('.', '.'),
#  ('behindwoods', 'NNS'),
#  ('stated', 'VBD'),
#  ('``', '``'),
#  ('rocks', 'NNS'),
#  ('action', 'NN'),
#  ('sequences', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('33', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('34', 'CD'),
#  (']', 'NN'),
#  ('following', 'VBG'),
#  ('cameo', 'JJ'),
#  ('role', 'NN'),
#  ('theeya', 'NN'),
#  ('velai', 'FW'),
#  ('seiyyanum', 'NN'),
#  ('kumaru', 'NN'),
#  (',', ','),
#  ('starred', 'VBN'),
#  ('action', 'NN'),
#  ('films', 'NNS'),
#  ('pattathu', 'VBP'),
#  ('yaanai', 'JJ'),
#  ('pandiya', 'NN'),
#  ('naadu', 'NN'),
#  ('.', '.'),
#  ('latter', 'JJ'),
#  ('vishal', 'NN'),
#  ("'s", 'POS'),
#  ('debut', 'NN'),
#  ('production', 'NN'),
#  ('venture', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('35', 'CD'),
#  (']', 'JJ'),
#  ('[', '$'),
#  ('36', 'CD'),
#  (']', 'NNP'),
#  ('vishal', 'NN'),
#  ('opted', 'VBD'),
#  ('produce', 'JJ'),
#  ('collaborate', 'NN'),
#  ('thiru', 'NNS'),
#  ('third', 'JJ'),
#  ('venture', 'NN'),
#  ('naan', 'JJ'),
#  ('sigappu', 'NN'),
#  ('manithan', 'NN'),
#  ('(', '('),
#  ('2014', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('revenge', 'JJ'),
#  ('drama', 'NN'),
#  (',', ','),
#  ('character', 'NN'),
#  ('narcolepsy', 'NN'),
#  ('.', '.'),
#  ('prepare', 'JJ'),
#  ('lead', 'JJ'),
#  ('role', 'NN'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('read', 'VBP'),
#  ('studied', 'VBN'),
#  ('real', 'JJ'),
#  ('life', 'NN'),
#  ('case', 'NN'),
#  ('studies', 'NNS'),
#  ('people', 'NNS'),
#  ('disorder', 'VBP'),
#  (',', ','),
#  ('citing', 'VBG'),
#  ('references', 'NNS'),
#  ('cinema', 'NN'),
#  ('could', 'MD'),
#  ('watch', 'VB'),
#  ('learn', 'NN'),
#  ('.', '.'),
#  ('acted', 'VBN'),
#  ('director', 'NN'),
#  ('hari', 'JJ'),
#  ('second', 'JJ'),
#  ('time', 'NN'),
#  ('poojai', 'NN'),
#  ('(', '('),
#  ('2014', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('somewhat', 'RB'),
#  ('good', 'JJ'),
#  ('business', 'NN'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('2015', 'CD'),
#  (',', ','),
#  ('acted', 'VBD'),
#  ('two', 'CD'),
#  ('films', 'NNS'),
#  (',', ','),
#  ('namely', 'RB'),
#  (',', ','),
#  ('aambala', 'JJ'),
#  ('paayum', 'NN'),
#  ('puli', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('37', 'CD'),
#  (']', 'JJ'),
#  ('[', '$'),
#  ('38', 'CD'),
#  (']', 'NN'),
#  ('2016', 'CD'),
#  (',', ','),
#  ('appeared', 'VBD'),
#  ('three', 'CD'),
#  ('movies', 'NNS'),
#  (';', ':'),
#  ('kathakali', 'VB'),
#  (',', ','),
#  ('marudhu', 'FW'),
#  ('kaththi', 'FW'),
#  ('sandai', 'NN'),
#  ('.', '.'),
#  ('first', 'JJ'),
#  ('two', 'CD'),
#  ('average', 'JJ'),
#  ('grossers', 'NNS'),
#  (',', ','),
#  ('kaththi', 'FW'),
#  ('sandai', 'NN'),
#  ('became', 'VBD'),
#  ('flop', 'JJ'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('january', 'JJ'),
#  ('2017', 'CD'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('signed', 'VBN'),
#  ('debut', 'NN'),
#  ('malayalam', 'NN'),
#  ('film', 'NN'),
#  (',', ','),
#  ('main', 'JJ'),
#  ('antagonist', 'JJ'),
#  ('mohanlal-starrer', 'NN'),
#  ('villain', 'NN'),
#  (',', ','),
#  ('directed', 'VBD'),
#  ('b', 'NN'),
#  ('.', '.'),
#  ('unnikrishnan', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('39', 'CD'),
#  (']', 'JJ'),
#  ('[', '$'),
#  ('40', 'CD'),
#  (']', 'NNP'),
#  ('september', 'NN'),
#  ('2017', 'CD'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('played', 'VBD'),
#  ('detective', 'NN'),
#  ('thupparivaalan', 'NN'),
#  ('directed', 'VBD'),
#  ('mysskin', 'RBR'),
#  ('loosely', 'RB'),
#  ('based', 'VBN'),
#  ('british', 'JJ'),
#  ('writer', 'NN'),
#  ('arthur', 'NN'),
#  ('conan', 'NN'),
#  ('doyle', 'NN'),
#  ("'s", 'POS'),
#  ('detective', 'JJ'),
#  ('character', 'NN'),
#  (',', ','),
#  ('sherlock', 'NN'),
#  ('holmes', 'NNS'),
#  ('.', '.'),
#  ('film', 'NN'),
#  ('commercial', 'JJ'),
#  ('success', 'NN'),
#  ('appreciated', 'VBD'),
#  ('audiences', 'NNS'),
#  ('critics', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('41', 'CD'),
#  (']', 'NN'),
#  ('2018', 'CD'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('two', 'CD'),
#  ('major', 'JJ'),
#  ('releases', 'NNS'),
#  ('.', '.'),
#  ('first', 'JJ'),
#  ('one', 'CD'),
#  ('irumbu', 'NN'),
#  ('thirai', 'NN'),
#  ('directed', 'VBD'),
#  ('newcomer', 'JJ'),
#  ('p.', 'NN'),
#  ('s.', 'NN'),
#  ('mithran', 'NN'),
#  ('released', 'VBN'),
#  ('may', 'MD'),
#  ('2018', 'CD'),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('42', 'CD'),
#  (']', 'JJ'),
#  ('second', 'JJ'),
#  ('sandakozhi', 'NN'),
#  ('2', 'CD'),
#  ('released', 'VBN'),
#  ('october', 'NN'),
#  ('2018', 'CD'),
#  ('written', 'VBN'),
#  ('directed', 'VBN'),
#  ('n.', 'JJ'),
#  ('linguswamy', 'NN'),
#  ('.', '.'),
#  ('sequel', 'NN'),
#  ('successful', 'JJ'),
#  ...]

# %%
new_text = nltk.pos_tag(nltk_text)

# %%
new_text
# Out:
# [('vishal', 'JJ'),
#  ('krishna', 'NN'),
#  ('reddy', 'NN'),
#  ('(', '('),
#  ('born', 'JJ'),
#  ('29', 'CD'),
#  ('august', 'JJ'),
#  ('1977', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('[', '$'),
#  ('1', 'CD'),
#  (']', 'NNP'),
#  ('also', 'RB'),
#  ('known', 'VBN'),
#  ('vishal', 'NN'),
#  (',', ','),
#  ('indian', 'JJ'),
#  ('actor', 'NN'),
#  ('film', 'NN'),
#  ('producer', 'NN'),
#  ('works', 'VBZ'),
#  ('tamil', 'JJ'),
#  ('cinema', 'NN'),
#  ('.', '.'),
#  ('younger', 'JJR'),
#  ('son', 'NN'),
#  ('film', 'NN'),
#  ('producer', 'NN'),
#  ('g.', 'NN'),
#  ('k.', 'NN'),
#  ('reddy', 'NN'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('studied', 'VBN'),
#  ('visual', 'JJ'),
#  ('communications', 'NNS'),
#  ('loyola', 'VBP'),
#  ('college', 'NN'),
#  (',', ','),
#  ('chennai', 'NN'),
#  ('.', '.'),
#  ('best', 'JJS'),
#  ('known', 'JJ'),
#  ('roles', 'NNS'),
#  ('action', 'NN'),
#  ('films', 'NNS'),
#  (',', ','),
#  ('produces', 'VBZ'),
#  ('films', 'NNS'),
#  ('production', 'NN'),
#  ('company', 'NN'),
#  (',', ','),
#  ('vishal', 'NN'),
#  ('film', 'NN'),
#  ('factory', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('2', 'CD'),
#  (']', 'NN'),
#  ('vishal', 'NN'),
#  ('made', 'VBD'),
#  ('entrance', 'NN'),
#  ('film', 'NN'),
#  ('industry', 'NN'),
#  ('assistant', 'NN'),
#  ('director', 'NN'),
#  ('arjun', 'NN'),
#  ('.', '.'),
#  ('became', 'VBD'),
#  ('actor', 'JJ'),
#  ('played', 'VBD'),
#  ('first', 'JJ'),
#  ('lead', 'JJ'),
#  ('role', 'NN'),
#  ('romantic', 'JJ'),
#  ('thriller', 'NN'),
#  ('chellamae', 'NN'),
#  ('(', '('),
#  ('2004', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('going', 'VBG'),
#  ('star', 'NN'),
#  ('commercially', 'RB'),
#  ('successful', 'JJ'),
#  ('action', 'NN'),
#  ('films', 'NNS'),
#  ('sandakozhi', 'NN'),
#  (',', ','),
#  ('thimiru', 'NN'),
#  (',', ','),
#  ('thaamirabharani', 'JJ'),
#  ('malaikottai', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('3', 'CD'),
#  (']', 'NN'),
#  ('following', 'VBG'),
#  ('series', 'NN'),
#  ('unsuccessful', 'JJ'),
#  ('films', 'NNS'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  (',', ','),
#  ('vishal', 'VBP'),
#  ('chose', 'JJ'),
#  ('create', 'NN'),
#  ('production', 'NN'),
#  ('studio', 'NN'),
#  ('since', 'IN'),
#  ('produced', 'VBN'),
#  ('worked', 'VBD'),
#  ('profitable', 'JJ'),
#  ('ventures', 'NNS'),
#  ('pandiya', 'VBP'),
#  ('naadu', 'RB'),
#  ('(', '('),
#  ('2013', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('naan', 'JJ'),
#  ('sigappu', 'NN'),
#  ('manithan', 'NN'),
#  ('(', '('),
#  ('2014', 'CD'),
#  (')', ')'),
#  ('poojai', 'NN'),
#  ('(', '('),
#  ('2014', 'CD'),
#  (')', ')'),
#  ('.', '.'),
#  ('[', '$'),
#  ('4', 'CD'),
#  (']', 'NNP'),
#  ('vishal', 'NN'),
#  ('elected', 'VBD'),
#  ('general', 'JJ'),
#  ('secretary', 'NN'),
#  ('nadigar', 'NN'),
#  ('sangam', 'VBD'),
#  ('october', 'JJ'),
#  ('2015', 'CD'),
#  ('initiating', 'VBG'),
#  ('movement', 'NN'),
#  ('previous', 'JJ'),
#  ('committee', 'NN'),
#  ('.', '.'),
#  ('[', '$'),
#  ('5', 'CD'),
#  (']', 'NNP'),
#  ('expelled', 'VBD'),
#  ('tamil', 'NN'),
#  ('film', 'NN'),
#  ('producers', 'NNS'),
#  ("'", 'POS'),
#  ('council', 'NN'),
#  ('(', '('),
#  ('tfpc', 'NN'),
#  (')', ')'),
#  ('remarks', 'NNS'),
#  ('council', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('6', 'CD'),
#  (']', 'JJ'),
#  ('[', '$'),
#  ('7', 'CD'),
#  (']', 'NN'),
#  ('later', 'RB'),
#  ('april', 'JJ'),
#  ('2017', 'CD'),
#  (',', ','),
#  ('election', 'NN'),
#  ('got', 'VBD'),
#  ('elected', 'VBN'),
#  ('president', 'NN'),
#  ('tamil', 'NN'),
#  ('film', 'NN'),
#  ('producers', 'NNS'),
#  ('council', 'VBP'),
#  ('.', '.'),
#  ('vishal', 'JJ'),
#  ('krishna', 'NN'),
#  ('reddy', 'NN'),
#  ('born', 'VBD'),
#  ('29', 'CD'),
#  ('august', 'JJ'),
#  ('1977', 'CD'),
#  ('[', 'NN'),
#  ('8', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('9', 'CD'),
#  (']', 'NNP'),
#  ('telugu', 'VBD'),
#  ('family', 'NN'),
#  ('chennai', 'NN'),
#  (',', ','),
#  ('tamil', 'JJ'),
#  ('nadu', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('10', 'CD'),
#  (']', 'NN'),
#  ('father', 'NN'),
#  ('gk', 'NN'),
#  ('reddy', 'JJ'),
#  ('businessman', 'NN'),
#  ('film', 'NN'),
#  ('producer', 'NN'),
#  ('telugu', 'NN'),
#  ('tamil', 'NN'),
#  ('films', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('11', 'CD'),
#  (']', 'NNP'),
#  ('elder', 'NN'),
#  ('brother', 'NN'),
#  ('vikram', 'NN'),
#  ('krishna', 'NN'),
#  ('also', 'RB'),
#  ('actor', 'JJ'),
#  ('producer', 'NN'),
#  ('produced', 'VBD'),
#  ('several', 'JJ'),
#  ('vishal', 'NN'),
#  ("'s", 'POS'),
#  ('films', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('12', 'CD'),
#  (']', 'NNP'),
#  ('vishal', 'NN'),
#  ('obtained', 'VBD'),
#  ('degree', 'JJ'),
#  ('visual', 'JJ'),
#  ('communications', 'NNS'),
#  ('loyola', 'VBP'),
#  ('college', 'NN'),
#  (',', ','),
#  ('chennai', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('13', 'CD'),
#  (']', 'JJ'),
#  ('vishal', 'NN'),
#  ('assisted', 'VBD'),
#  ('actor-director', 'JJ'),
#  ('arjun', 'NN'),
#  ('sarja', 'JJ'),
#  ('venture', 'NN'),
#  ('vedham', 'NN'),
#  ('(', '('),
#  ('2001', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('producer', 'NN'),
#  ('spotted', 'VBD'),
#  ('vishal', 'JJ'),
#  ('sets', 'NNS'),
#  ('film', 'NN'),
#  ('signed', 'VBD'),
#  ('appear', 'RB'),
#  ('acting', 'VBG'),
#  ('role', 'NN'),
#  ('gandhi', 'NN'),
#  ('krishna', 'NN'),
#  ("'s", 'POS'),
#  ('chellamae', 'NN'),
#  ('(', '('),
#  ('2004', 'CD'),
#  (')', ')'),
#  ('.', '.'),
#  ('[', '$'),
#  ('14', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('15', 'CD'),
#  (']', 'JJ'),
#  ('accepting', 'VBG'),
#  ('role', 'NN'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('prepared', 'JJ'),
#  ('joining', 'VBG'),
#  ('koothu-p-pattarai', 'JJ'),
#  ('hone', 'NN'),
#  ('acting', 'VBG'),
#  ('skills', 'NNS'),
#  ('played', 'VBN'),
#  ('protagonist', 'JJ'),
#  ('role', 'NN'),
#  ('raghunandan', 'NN'),
#  (',', ','),
#  ('whose', 'WP$'),
#  ('wife', 'NN'),
#  ('kidnapped', 'VBD'),
#  ('childhood', 'NN'),
#  ('friend', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('15', 'CD'),
#  (']', 'JJ'),
#  ('critic', 'JJ'),
#  ('described', 'VBD'),
#  ('performance', 'NN'),
#  ('``', '``'),
#  ('apt', 'JJ'),
#  ("''", "''"),
#  ('``', '``'),
#  ('there', 'EX'),
#  ('plenty', 'JJ'),
#  ('left', 'VBD'),
#  ('hone', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('16', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('17', 'CD'),
#  (']', 'NNP'),
#  ('next', 'JJ'),
#  ('film', 'NN'),
#  ('sandakozhi', 'NN'),
#  ('(', '('),
#  ('2005', 'CD'),
#  (')', ')'),
#  ('n.', 'FW'),
#  ('linguswamy', 'NN'),
#  (',', ','),
#  ('previously', 'RB'),
#  ('worked', 'VBD'),
#  ('father', 'NN'),
#  ("'s", 'POS'),
#  ('production', 'NN'),
#  ('house', 'NN'),
#  ('assistant', 'JJ'),
#  ('director', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('18', 'CD'),
#  (']', 'JJ'),
#  ('vishal', 'NN'),
#  ('described', 'VBD'),
#  ('``', '``'),
#  ('improved', 'JJ'),
#  ('chellamae', 'NN'),
#  ('days', 'NNS'),
#  ("''", "''"),
#  ('``', '``'),
#  ('clicked', 'VBD'),
#  ('action', 'NN'),
#  ('hero', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('19', 'CD'),
#  (']', 'NNP'),
#  ('film', 'NN'),
#  ('journalists', 'NNS'),
#  ('stated', 'VBD'),
#  ('``', '``'),
#  ('the', 'DT'),
#  ('fastest', 'JJS'),
#  ('rising', 'VBG'),
#  ('action', 'NN'),
#  ('hero', 'NN'),
#  ("''", "''"),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('20', 'CD'),
#  (']', 'NNP'),
#  ('cameo', 'NN'),
#  ('sasi', 'NN'),
#  ("'s", 'POS'),
#  ('dishyum', 'NN'),
#  ('(', '('),
#  ('2006', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('went', 'VBD'),
#  ('appear', 'JJ'),
#  ('tarun', 'IN'),
#  ('gopi', 'NN'),
#  ("'s", 'POS'),
#  ('action', 'NN'),
#  ('film', 'NN'),
#  ('thimiru', 'NN'),
#  ('(', '('),
#  ('2006', 'CD'),
#  (')', ')'),
#  ('.', '.'),
#  ('film', 'NN'),
#  ('opened', 'VBD'),
#  ('mixed', 'JJ'),
#  ('reviews', 'NNS'),
#  ('vishal', 'NNS'),
#  ('praised', 'VBD'),
#  ('intense', 'JJ'),
#  ('performance', 'NN'),
#  ('critic', 'JJ'),
#  ('calling', 'VBG'),
#  ('performance', 'NN'),
#  ('``', '``'),
#  ('the', 'DT'),
#  ('film', 'NN'),
#  ("'s", 'POS'),
#  ('strength', 'NN'),
#  ('and', 'CC'),
#  (',', ','),
#  ('extent', 'NN'),
#  (',', ','),
#  ('making', 'VBG'),
#  ('weak', 'JJ'),
#  ('script', 'NN'),
#  ('poor', 'JJ'),
#  ('characterisation', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('21', 'CD'),
#  (']', 'NNP'),
#  ('film', 'NN'),
#  ('became', 'VBD'),
#  ('vishal', 'NN'),
#  ("'s", 'POS'),
#  ('third', 'JJ'),
#  ('consecutive', 'JJ'),
#  ('commercial', 'JJ'),
#  ('success', 'NN'),
#  (',', ','),
#  ('began', 'VBD'),
#  ('emerge', 'JJ'),
#  ('tamil', 'JJ'),
#  ('films', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('22', 'CD'),
#  (']', 'NNP'),
#  ('next', 'JJ'),
#  ('film', 'NN'),
#  (',', ','),
#  ('political', 'JJ'),
#  ('action', 'NN'),
#  ('drama', 'NN'),
#  ('sivappathigaram', 'NN'),
#  ('(', '('),
#  ('2006', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('directed', 'VBD'),
#  ('karu', 'NN'),
#  ('pazhaniappan', 'NN'),
#  ('failure', 'NN'),
#  ('financially', 'RB'),
#  ('despite', 'IN'),
#  ('favourable', 'JJ'),
#  ('reviews', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('23', 'CD'),
#  (']', 'NNP'),
#  ('next', 'JJ'),
#  ('film', 'NN'),
#  ('released', 'VBN'),
#  ('january', 'JJ'),
#  ('2007', 'CD'),
#  (',', ','),
#  ('hari', 'PRP'),
#  ("'s", 'VBZ'),
#  ('multi-starring', 'JJ'),
#  ('family', 'NN'),
#  ('action', 'NN'),
#  ('drama', 'NN'),
#  ('thaamirabharani', 'NN'),
#  ('(', '('),
#  ('2007', 'CD'),
#  (')', ')'),
#  ('film', 'NN'),
#  ('went', 'VBD'),
#  ('gain', 'NN'),
#  ('considerable', 'JJ'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  ('success', 'NN'),
#  (',', ','),
#  ('carrying', 'VBG'),
#  ('good', 'JJ'),
#  ('reports', 'NNS'),
#  ('amidst', 'RB'),
#  ('big', 'JJ'),
#  ('budget', 'NN'),
#  ('releases', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('24', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('25', 'CD'),
#  (']', 'NN'),
#  ('later', 'RB'),
#  ('year', 'NN'),
#  (',', ','),
#  ('appeared', 'VBD'),
#  ('boopathy', 'JJ'),
#  ('pandian', 'NN'),
#  ("'s", 'POS'),
#  ('malaikottai', 'NN'),
#  ('(', '('),
#  ('2007', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('comedy', 'NN'),
#  ('entertainer', 'NN'),
#  ('.', '.'),
#  ('first', 'JJ'),
#  ('full-length', 'JJ'),
#  ('comic', 'JJ'),
#  ('role', 'NN'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('received', 'VBD'),
#  ('mixed', 'JJ'),
#  ('feedback', 'NN'),
#  ('portrayal', 'NN'),
#  ('critics', 'NNS'),
#  (',', ','),
#  ('rediff', 'NN'),
#  ('stating', 'VBG'),
#  ('``', '``'),
#  ('a', 'DT'),
#  ('far', 'RB'),
#  ('cry', 'NN'),
#  ('rather', 'RB'),
#  ('endearing', 'VBG'),
#  ('young', 'JJ'),
#  ('man', 'NN'),
#  ('sandakozhi', 'NN'),
#  ("''", "''"),
#  (',', ','),
#  ('whilst', 'VBD'),
#  ('describing', 'VBG'),
#  ('performance', 'NN'),
#  ('``', '``'),
#  ('cringe-able', 'JJ'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('26', 'CD'),
#  (']', 'NNP'),
#  ('behindwoods', 'NNS'),
#  ('stated', 'VBD'),
#  ('``', '``'),
#  ('average', 'JJ'),
#  ('masala-mix', 'JJ'),
#  ('entertainer', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('27', 'CD'),
#  (']', 'NNP'),
#  ('film', 'NN'),
#  ('took', 'VBD'),
#  ('large', 'JJ'),
#  ('opening', 'NN'),
#  ('declared', 'VBD'),
#  ('blockbuster', 'NN'),
#  (',', ','),
#  ('featuring', 'VBG'),
#  ('top', 'JJ'),
#  ('10', 'CD'),
#  ('behindwoods', 'NNS'),
#  ('box', 'JJ'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('year', 'NN'),
#  ('2008', 'CD'),
#  (',', ','),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  (',', ','),
#  ('vishal', 'JJ'),
#  ('portrayed', 'JJ'),
#  ('police', 'NN'),
#  ('officer', 'NN'),
#  ('sathyam', 'NN'),
#  (',', ','),
#  ('became', 'VBD'),
#  ('commercial', 'JJ'),
#  ('failure', 'NN'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('films', 'NNS'),
#  ('thoranai', 'NN'),
#  ('(', '('),
#  ('2009', 'CD'),
#  (')', ')'),
#  ('theeradha', 'NN'),
#  ('vilaiyattu', 'NN'),
#  ('pillai', 'NN'),
#  ('(', '('),
#  ('2010', 'CD'),
#  (')', ')'),
#  ('average', 'NN'),
#  ('grossers', 'NNS'),
#  ('.', '.'),
#  ('additionally', 'RB'),
#  (',', ','),
#  ('box-office', 'JJ'),
#  ('duds', 'NN'),
#  (',', ','),
#  ('sathyam', 'NN'),
#  ('thoranai', 'NN'),
#  (',', ','),
#  ('bilingual', 'JJ'),
#  ('tamil', 'NN'),
#  ('telugu', 'NN'),
#  (',', ','),
#  ('failed', 'VBD'),
#  ('establish', 'VB'),
#  ('popularity', 'NN'),
#  ('telugu', 'JJ'),
#  ('cinema', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('28', 'CD'),
#  (']', 'JJ'),
#  ('vishal', 'NN'),
#  ('given', 'VBN'),
#  ('opportunity', 'NN'),
#  ('feature', 'NN'),
#  ('bala', 'NN'),
#  ("'s", 'POS'),
#  ('dark', 'JJ'),
#  ('comedy', 'NN'),
#  ('avan', 'NN'),
#  ('ivan', 'NN'),
#  ('(', '('),
#  ('2011', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('recommended', 'VBD'),
#  ('director', 'NN'),
#  ('friend', 'NN'),
#  ('arya', 'NN'),
#  ('.', '.'),
#  ('portraying', 'VBG'),
#  ('village', 'NN'),
#  ('stage', 'NN'),
#  ('actor', 'NN'),
#  ('squint', 'NN'),
#  (',', ','),
#  ('vishal', 'NN'),
#  ('severe', 'JJ'),
#  ('eye', 'NN'),
#  ('pain', 'NN'),
#  ('headaches', 'NNS'),
#  (',', ','),
#  ('also', 'RB'),
#  ('serious', 'JJ'),
#  ('muscular', 'JJ'),
#  ('injury', 'NN'),
#  ('sets', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('29', 'CD'),
#  (']', 'NNP'),
#  ('film', 'NN'),
#  ('opened', 'VBD'),
#  ('mixed', 'JJ'),
#  ('reviews', 'NNS'),
#  (',', ','),
#  ('though', 'IN'),
#  ('vishal', 'NN'),
#  ("'s", 'POS'),
#  ('performance', 'NN'),
#  ('positive', 'JJ'),
#  ('reviews', 'NNS'),
#  ('.', '.'),
#  ('indiaglitz', 'NN'),
#  ('stated', 'VBD'),
#  ('vishal', 'RB'),
#  ('delivered', 'VBN'),
#  ('``', '``'),
#  ('award', 'JJ'),
#  ('winning', 'NN'),
#  ('performance', 'NN'),
#  ("''", "''"),
#  ('``', '``'),
#  ('mannerisms', 'FW'),
#  ('body', 'NN'),
#  ('language', 'NN'),
#  ('give', 'JJ'),
#  ('goosebumps', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('reviewer', 'VB'),
#  ('cited', 'VBN'),
#  ('``', '``'),
#  ('vishal', 'NN'),
#  ("'s", 'POS'),
#  ('spontaneous', 'JJ'),
#  ('response', 'NN'),
#  ('mentor', 'NN'),
#  ("'s", 'POS'),
#  ('death', 'NN'),
#  ('movie', 'NN'),
#  ('touching', 'VBG'),
#  ('.', '.'),
#  ('demonstration', 'NN'),
#  ('navarasas', 'JJ'),
#  ('front', 'JJ'),
#  ('actor', 'NN'),
#  ('suriya', 'NN'),
#  ('melt', 'VBD'),
#  ('tears', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('30', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('31', 'CD'),
#  (']', 'NNP'),
#  ('vishal', 'FW'),
#  ('played', 'VBD'),
#  ('role', 'NN'),
#  ('police', 'NNS'),
#  ('officer', 'NN'),
#  ('following', 'VBG'),
#  ('release', 'NN'),
#  ('vedi', 'NN'),
#  ('(', '('),
#  ('2011', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('directed', 'VBD'),
#  ('prabhu', 'NN'),
#  ('deva', 'NN'),
#  (',', ','),
#  ('declared', 'VBD'),
#  ('instant', 'JJ'),
#  ('flop', 'NN'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('32', 'CD'),
#  (']', 'JJ'),
#  ('2013', 'CD'),
#  ('film', 'NN'),
#  ('samar', 'NN'),
#  (',', ','),
#  ('vishal', 'JJ'),
#  ('played', 'VBD'),
#  ('forest', 'JJS'),
#  ('trek', 'NN'),
#  ('guide', 'NN'),
#  ('.', '.'),
#  ('behindwoods', 'NNS'),
#  ('stated', 'VBD'),
#  ('``', '``'),
#  ('rocks', 'NNS'),
#  ('action', 'NN'),
#  ('sequences', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('33', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('34', 'CD'),
#  (']', 'NN'),
#  ('following', 'VBG'),
#  ('cameo', 'JJ'),
#  ('role', 'NN'),
#  ('theeya', 'NN'),
#  ('velai', 'FW'),
#  ('seiyyanum', 'NN'),
#  ('kumaru', 'NN'),
#  (',', ','),
#  ('starred', 'VBN'),
#  ('action', 'NN'),
#  ('films', 'NNS'),
#  ('pattathu', 'VBP'),
#  ('yaanai', 'JJ'),
#  ('pandiya', 'NN'),
#  ('naadu', 'NN'),
#  ('.', '.'),
#  ('latter', 'JJ'),
#  ('vishal', 'NN'),
#  ("'s", 'POS'),
#  ('debut', 'NN'),
#  ('production', 'NN'),
#  ('venture', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('35', 'CD'),
#  (']', 'JJ'),
#  ('[', '$'),
#  ('36', 'CD'),
#  (']', 'NNP'),
#  ('vishal', 'NN'),
#  ('opted', 'VBD'),
#  ('produce', 'JJ'),
#  ('collaborate', 'NN'),
#  ('thiru', 'NNS'),
#  ('third', 'JJ'),
#  ('venture', 'NN'),
#  ('naan', 'JJ'),
#  ('sigappu', 'NN'),
#  ('manithan', 'NN'),
#  ('(', '('),
#  ('2014', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('revenge', 'JJ'),
#  ('drama', 'NN'),
#  (',', ','),
#  ('character', 'NN'),
#  ('narcolepsy', 'NN'),
#  ('.', '.'),
#  ('prepare', 'JJ'),
#  ('lead', 'JJ'),
#  ('role', 'NN'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('read', 'VBP'),
#  ('studied', 'VBN'),
#  ('real', 'JJ'),
#  ('life', 'NN'),
#  ('case', 'NN'),
#  ('studies', 'NNS'),
#  ('people', 'NNS'),
#  ('disorder', 'VBP'),
#  (',', ','),
#  ('citing', 'VBG'),
#  ('references', 'NNS'),
#  ('cinema', 'NN'),
#  ('could', 'MD'),
#  ('watch', 'VB'),
#  ('learn', 'NN'),
#  ('.', '.'),
#  ('acted', 'VBN'),
#  ('director', 'NN'),
#  ('hari', 'JJ'),
#  ('second', 'JJ'),
#  ('time', 'NN'),
#  ('poojai', 'NN'),
#  ('(', '('),
#  ('2014', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('somewhat', 'RB'),
#  ('good', 'JJ'),
#  ('business', 'NN'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('2015', 'CD'),
#  (',', ','),
#  ('acted', 'VBD'),
#  ('two', 'CD'),
#  ('films', 'NNS'),
#  (',', ','),
#  ('namely', 'RB'),
#  (',', ','),
#  ('aambala', 'JJ'),
#  ('paayum', 'NN'),
#  ('puli', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('37', 'CD'),
#  (']', 'JJ'),
#  ('[', '$'),
#  ('38', 'CD'),
#  (']', 'NN'),
#  ('2016', 'CD'),
#  (',', ','),
#  ('appeared', 'VBD'),
#  ('three', 'CD'),
#  ('movies', 'NNS'),
#  (';', ':'),
#  ('kathakali', 'VB'),
#  (',', ','),
#  ('marudhu', 'FW'),
#  ('kaththi', 'FW'),
#  ('sandai', 'NN'),
#  ('.', '.'),
#  ('first', 'JJ'),
#  ('two', 'CD'),
#  ('average', 'JJ'),
#  ('grossers', 'NNS'),
#  (',', ','),
#  ('kaththi', 'FW'),
#  ('sandai', 'NN'),
#  ('became', 'VBD'),
#  ('flop', 'JJ'),
#  ('box', 'NN'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('january', 'JJ'),
#  ('2017', 'CD'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('signed', 'VBN'),
#  ('debut', 'NN'),
#  ('malayalam', 'NN'),
#  ('film', 'NN'),
#  (',', ','),
#  ('main', 'JJ'),
#  ('antagonist', 'JJ'),
#  ('mohanlal-starrer', 'NN'),
#  ('villain', 'NN'),
#  (',', ','),
#  ('directed', 'VBD'),
#  ('b', 'NN'),
#  ('.', '.'),
#  ('unnikrishnan', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('39', 'CD'),
#  (']', 'JJ'),
#  ('[', '$'),
#  ('40', 'CD'),
#  (']', 'NNP'),
#  ('september', 'NN'),
#  ('2017', 'CD'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('played', 'VBD'),
#  ('detective', 'NN'),
#  ('thupparivaalan', 'NN'),
#  ('directed', 'VBD'),
#  ('mysskin', 'RBR'),
#  ('loosely', 'RB'),
#  ('based', 'VBN'),
#  ('british', 'JJ'),
#  ('writer', 'NN'),
#  ('arthur', 'NN'),
#  ('conan', 'NN'),
#  ('doyle', 'NN'),
#  ("'s", 'POS'),
#  ('detective', 'JJ'),
#  ('character', 'NN'),
#  (',', ','),
#  ('sherlock', 'NN'),
#  ('holmes', 'NNS'),
#  ('.', '.'),
#  ('film', 'NN'),
#  ('commercial', 'JJ'),
#  ('success', 'NN'),
#  ('appreciated', 'VBD'),
#  ('audiences', 'NNS'),
#  ('critics', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('41', 'CD'),
#  (']', 'NN'),
#  ('2018', 'CD'),
#  (',', ','),
#  ('vishal', 'FW'),
#  ('two', 'CD'),
#  ('major', 'JJ'),
#  ('releases', 'NNS'),
#  ('.', '.'),
#  ('first', 'JJ'),
#  ('one', 'CD'),
#  ('irumbu', 'NN'),
#  ('thirai', 'NN'),
#  ('directed', 'VBD'),
#  ('newcomer', 'JJ'),
#  ('p.', 'NN'),
#  ('s.', 'NN'),
#  ('mithran', 'NN'),
#  ('released', 'VBN'),
#  ('may', 'MD'),
#  ('2018', 'CD'),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('42', 'CD'),
#  (']', 'JJ'),
#  ('second', 'JJ'),
#  ('sandakozhi', 'NN'),
#  ('2', 'CD'),
#  ('released', 'VBN'),
#  ('october', 'NN'),
#  ('2018', 'CD'),
#  ('written', 'VBN'),
#  ('directed', 'VBN'),
#  ('n.', 'JJ'),
#  ('linguswamy', 'NN'),
#  ('.', '.'),
#  ('sequel', 'NN'),
#  ('successful', 'JJ'),
#  ...]

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
spacy_doc = nlp(text)

# %%
spacy_doc
# Out:
# vishal krishna reddy (born 29 august 1977),[1] also known   vishal,     indian actor   film producer   works   tamil cinema.   younger son   film producer g. k. reddy, vishal studied visual communications   loyola college, chennai. best known     roles   action films,   produces films     production company, vishal film factory.[2] vishal made   entrance     film industry     assistant director   arjun.     became   actor   played   first lead role     romantic thriller chellamae (2004),   going     star     commercially successful action films sandakozhi, thimiru, thaamirabharani   malaikottai.[3] following   series   unsuccessful films     box office, vishal chose   create     production studio     since produced   worked   profitable ventures     pandiya naadu (2013), naan sigappu manithan (2014)   poojai (2014).[4] vishal   elected     general secretary     nadigar sangam   october 2015   initiating   movement     previous committee.[5]     expelled   tamil film producers' council (tfpc)   remarks     council.[6][7] later   april 2017,       election   got elected   president   tamil film producers council. vishal krishna reddy   born   29 august 1977[8][9]     telugu family   chennai, tamil nadu.[10]   father gk reddy     businessman     film producer   telugu   tamil films.[11]   elder brother vikram krishna   also   actor   producer     produced several   vishal's films.[12] vishal obtained   degree   visual communications   loyola college, chennai.[13] vishal assisted actor-director arjun sarja     venture vedham (2001),     producer spotted vishal     sets     film   signed     appear     acting role   gandhi krishna's chellamae (2004).[14][15] accepting   role, vishal prepared   joining koothu-p-pattarai   hone   acting skills   played   protagonist role   raghunandan, whose wife   kidnapped     childhood friend.[15]   critic described   performance   "apt"   "there   plenty left   hone".[16][17]   next film   sandakozhi (2005)   n. linguswamy,     previously worked     father's production house     assistant director.[18] vishal   described     "improved     chellamae days"   "clicked     action hero".[19] film journalists stated       "the fastest rising action hero"     time.[20]     cameo       sasi's dishyum (2006),   went     appear   tarun gopi's action film thimiru (2006).   film opened   mixed reviews   vishal   praised     intense performance     critic calling   performance "the film's   strength and,     extent, making       weak script   poor characterisation".[21]   film became vishal's third consecutive commercial success,     began   emerge   tamil films.[22]   next film,   political action drama sivappathigaram (2006), directed   karu pazhaniappan     failure financially despite favourable reviews.[23]   next film   released   january 2007, hari's multi-starring family action drama thaamirabharani (2007)     film went     gain considerable box office success, carrying good reports amidst   big budget releases.[24][25] later     year,   appeared   boopathy pandian's malaikottai (2007),   comedy entertainer.     first full-length comic role, vishal received mixed feedback     portrayal   critics,   rediff stating       "a far cry     rather endearing young man   sandakozhi", whilst describing   performance   "cringe-able".[26] behindwoods stated       "average masala-mix entertainer".[27]   film took   large opening     declared   blockbuster, featuring     top 10   behindwoods box office.     year 2008,     first time, vishal portrayed   police officer   sathyam,   became   commercial failure     box office.       films thoranai (2009)   theeradha vilaiyattu pillai (2010)     average grossers. additionally,   box-office duds, sathyam   thoranai,         bilingual   tamil   telugu, failed   establish   popularity   telugu cinema.[28] vishal     given   opportunity   feature   bala's dark comedy avan ivan (2011),     recommended     director     friend arya. portraying   village stage actor     squint,  ...

# %%
for token in spacy_doc:
    print(token)
# Out:
# vishal
# krishna
# reddy
# (
# born
# 29
# august
# 1977),[1
# ]
# also
# known
#
# vishal
# ,
#
# indian
# actor
#
# film
# producer
#
# works
#
# tamil
# cinema
# .
#
# younger
# son
#
# film
# producer
# g.
# k.
# reddy
# ,
# vishal
# studied
# visual
# communications
#
# loyola
# college
# ,
# chennai
# .
# best
# known
#
# roles
#
# action
# films
# ,
#
# produces
# films
#
# production
# company
# ,
# vishal
# film
# factory.[2
# ]
# vishal
# made
#
# entrance
#
# film
# industry
#
# assistant
# director
#
# arjun
# .
#
# became
#
# actor
#
# played
#
# first
# lead
# role
#
# romantic
# thriller
# chellamae
# (
# 2004
# )
# ,
#
# going
#
# star
#
# commercially
# successful
# action
# films
# sandakozhi
# ,
# thimiru
# ,
# thaamirabharani
#
# malaikottai.[3
# ]
# following
#
# series
#
# unsuccessful
# films
#
# box
# office
# ,
# vishal
# chose
#
# create
#
# production
# studio
#
# since
# produced
#
# worked
#
# profitable
# ventures
#
# pandiya
# naadu
# (
# 2013
# )
# ,
# naan
# sigappu
# manithan
# (
# 2014
# )
#
# poojai
# (
# 2014).[4
# ]
# vishal
#
# elected
#
# general
# secretary
#
# nadigar
# sangam
#
# october
# 2015
#
# initiating
#
# movement
#
# previous
# committee.[5
# ]
#
# expelled
#
# tamil
# film
# producers
# '
# council
# (
# tfpc
# )
#
# remarks
#
# council.[6][7
# ]
# later
#
# april
# 2017
# ,
#
# election
#
# got
# elected
#
# president
#
# tamil
# film
# producers
# council
# .
# vishal
# krishna
# reddy
#
# born
#
# 29
# august
# 1977[8][9
# ]
#
# telugu
# family
#
# chennai
# ,
# tamil
# nadu.[10
# ]
#
# father
# gk
# reddy
#
# businessman
#
# film
# producer
#
# telugu
#
# tamil
# films.[11
# ]
#
# elder
# brother
# vikram
# krishna
#
# also
#
# actor
#
# producer
#
# produced
# several
#
# vishal
# 's
# films.[12
# ]
# vishal
# obtained
#
# degree
#
# visual
# communications
#
# loyola
# college
# ,
# chennai.[13
# ]
# vishal
# assisted
# actor
# -
# director
# arjun
# sarja
#
# venture
# vedham
# (
# 2001
# )
# ,
#
# producer
# spotted
# vishal
#
# sets
#
# film
#
# signed
#
# appear
#
# acting
# role
#
# gandhi
# krishna
# 's
# chellamae
# (
# 2004).[14][15
# ]
# accepting
#
# role
# ,
# vishal
# prepared
#
# joining
# koothu
# -
# p
# -
# pattarai
#
# hone
#
# acting
# skills
#
# played
#
# protagonist
# role
#
# raghunandan
# ,
# whose
# wife
#
# kidnapped
#
# childhood
# friend.[15
# ]
#
# critic
# described
#
# performance
#
# "
# apt
# "
#
# "
# there
#
# plenty
# left
#
# hone".[16][17
# ]
#
# next
# film
#
# sandakozhi
# (
# 2005
# )
#
# n.
# linguswamy
# ,
#
# previously
# worked
#
# father
# 's
# production
# house
#
# assistant
# director.[18
# ]
# vishal
#
# described
#
# "
# improved
#
# chellamae
# days
# "
#
# "
# clicked
#
# action
# hero".[19
# ]
# film
# journalists
# stated
#
# "
# the
# fastest
# rising
# action
# hero
# "
#
# time.[20
# ]
#
# cameo
#
# sasi
# 's
# dishyum
# (
# 2006
# )
# ,
#
# went
#
# appear
#
# tarun
# gopi
# 's
# action
# film
# thimiru
# (
# 2006
# )
# .
#
# film
# opened
#
# mixed
# reviews
#
# vishal
#
# praised
#
# intense
# performance
#
# critic
# calling
#
# performance
# "
# the
# film
# 's
#
# strength
# and
# ,
#
# extent
# ,
# making
#
# weak
# script
#
# poor
# characterisation".[21
# ]
#
# film
# became
# vishal
# 's
# third
# consecutive
# commercial
# success
# ,
#
# began
#
# emerge
#
# tamil
# films.[22
# ]
#
# next
# film
# ,
#
# political
# action
# drama
# sivappathigaram
# (
# 2006
# )
# ,
# directed
#
# karu
# pazhaniappan
#
# failure
# financially
# despite
# favourable
# reviews.[23
# ]
#
# next
# film
#
# released
#
# january
# 2007
# ,
# hari
# 's
# multi
# -
# starring
# family
# action
# drama
# thaamirabharani
# (
# 2007
# )
#
# film
# went
#
# gain
# considerable
# box
# office
# success
# ,
# carrying
# good
# reports
# amidst
#
# big
# budget
# releases.[24][25
# ]
# later
#
# year
# ,
#
# appeared
#
# boopathy
# pandian
# 's
# malaikottai
# (
# 2007
# )
# ,
#
# comedy
# entertainer
# .
#
# first
# full
# -
# length
# comic
# role
# ,
# vishal
# received
# mixed
# feedback
#
# portrayal
#
# critics
# ,
#
# rediff
# stating
#
# "
# a
# far
# cry
#
# rather
# endearing
# young
# man
#
# sandakozhi
# "
# ,
# whilst
# describing
#
# performance
#
# "
# cringe
# -
# able".[26
# ]
# behindwoods
# stated
#
# "
# average
# masala
# -
# mix
# entertainer".[27
# ]
#
# film
# took
#
# large
# opening
#
# declared
#
# blockbuster
# ,
# featuring
#
# top
# 10
#
# behindwoods
# box
# office
# .
#
# year
# 2008
# ,
#
# first
# time
# ,
# vishal
# portrayed
#
# police
# officer
#
# sathyam
# ,
#
# became
#
# commercial
# failure
#
# box
# office
# .
#
# films
# thoranai
# (
# 2009
# )
#
# theeradha
# vilaiyattu
# pillai
# (
# 2010
# )
#
# average
# grossers
# .
# additionally
# ,
#
# box
# -
# office
# duds
# ,
# sathyam
#
# thoranai
# ,
#
# bilingual
#
# tamil
#
# telugu
# ,
# failed
#
# establish
#
# popularity
#
# telugu
# cinema.[28
# ]
# vishal
#
# given
#
# opportunity
#
# feature
#
# bala
# 's
# dark
# comedy
# avan
# ivan
# (
# 2011
# )
# ,
#
# recommended
#
# director
#
# friend
# arya
# .
# portraying
#
# village
# stage
# actor
#
# squint
# ,
# vishal
#
# severe
# eye
# pain
#
# headaches
# ,
#
# also
#
# serious
# muscular
# injury
#
# sets.[29
# ]
#
# film
# opened
#
# mixed
# reviews
# ,
# though
# vishal
# 's
# performance
#
# positive
# reviews
# .
# indiaglitz
# stated
#
# vishal
# delivered
#
# "
# award
# winning
# performance
# "
#
# "
# mannerisms
#
# body
# language
# give
#
# goosebumps
# "
# .
#
# reviewer
#
# cited
#
# "
# vishal
# 's
# spontaneous
# response
#
# mentor
# 's
# death
#
# movie
#
# touching
# .
#
# demonstration
#
# navarasas
#
# front
#
# actor
# suriya
#
# melt
#
# tears".[30][31
# ]
# vishal
# played
#
# role
#
# police
# officer
#
# following
# release
# vedi
# (
# 2011
# )
# ,
# directed
#
# prabhu
# deva
# ,
#
# declared
#
# instant
# flop
#
# box
# office.[32
# ]
#
# 2013
# film
# samar
# ,
# vishal
# played
#
# forest
# trek
# guide
# .
# behindwoods
# stated
#
# "
# rocks
#
# action
# sequences".[33][34
# ]
# following
#
# cameo
# role
#
# theeya
# velai
# seiyyanum
# kumaru
# ,
#
# starred
#
# action
# films
# pattathu
# yaanai
#
# pandiya
# naadu
# .
#
# latter
#
# vishal
# 's
# debut
# production
# venture.[35][36
# ]
# vishal
# opted
#
# produce
#
# collaborate
#
# thiru
#
# third
# venture
# naan
# sigappu
# manithan
# (
# 2014
# )
# ,
#
# revenge
# drama
# ,
#
# character
#
# narcolepsy
# .
#
# prepare
#
# lead
# role
# ,
# vishal
# read
#
# studied
# real
# life
# case
# studies
#
# people
#
# disorder
# ,
# citing
#
# references
#
# cinema
#
# could
# watch
#
# learn
# .
#
# acted
#
# director
# hari
#
# second
# time
#
# poojai
# (
# 2014
# )
# ,
#
# somewhat
# good
# business
#
# box
# office
# .
#
# 2015
# ,
#
# acted
# two
# films
# ,
# namely
# ,
# aambala
#
# paayum
# puli.[37][38
# ]
#
# 2016
# ,
#
# appeared
#
# three
# movies
# ;
# kathakali
# ,
# marudhu
#
# kaththi
# sandai
# .
#
# first
# two
#
# average
# grossers
# ,
#
# kaththi
# sandai
# became
#
# flop
#
# box
# office
# .
#
# january
# 2017
# ,
# vishal
# signed
#
# debut
# malayalam
# film
# ,
#
# main
# antagonist
#
# mohanlal
# -
# starrer
# villain
# ,
# directed
#
# b.
# unnikrishnan.[39][40
# ]
#
# september
# 2017
# ,
# vishal
# played
#
# detective
#
# thupparivaalan
# directed
#
# mysskin
#
# loosely
# based
#
# british
# writer
# arthur
# conan
# doyle
# 's
# detective
# character
# ,
# sherlock
# holmes
# .
#
# film
#
# commercial
# success
#
# appreciated
#
# audiences
#
# critics.[41
# ]
#
# 2018
# ,
# vishal
#
# two
# major
# releases
# .
#
# first
# one
#
# irumbu
# thirai
# directed
#
# newcomer
# p.
# s.
# mithran
#
# released
#
# may
# 2018.[42
# ]
#
# second
#
# sandakozhi
# 2
# released
#
# october
# 2018
#
# written
#
# directed
#
# n.
# linguswamy
# .
#
# sequel
#
# successful
# sandakozhi
# (
# 2005
# )
# ,
#
# film
# stars
# vishal
#
# 25th
# film.[43
# ]
#
# film
# turned
#
# average
# grosser.[44
# ]
#
# 2019
# ,
#
# one
# movie
# titled
# action
# directed
#
# sundar
# c.[45
# ]
#
# film
# received
# mixed
# reviews
#
# box
# office
# failure.[46
# ]
#
# 2021
# ,
#
# acted
#
# action
# thriller
# chakra
# directed
#
# newcomer
# m.s
# anandan
# .
#
# film
#
# released
#
# 19
# february
# ,
# received
# mixed
# reviews
#
# critics
#
# audience.[47
# ]
#
# elected
#
# president
#
# tamil
# film
# producers
# council
# election
# ,
#
# held
#
# 2
# april
# 2017.[48][49][50
# ]
# apart
#
# this
# ,
# vishal
#
# also
#
# staunch
# advocate
#
# online
# piracy
# since
# 2014
# ,
#
# started
#
# anti
# -
# piracy
# cell.[51
# ]
#
# made
#
# television
# début
#
# october
# 2018
#
# host
#
# sun
# naam
# oruvar
# ,
#
# talk
# show
# airing
#
# sun
# tv.[52][53
# ]
# vishal
# filed
#
# nomination
#
# independent
# candidate
#
# by
# -
# poll
#
# radhakrishnan
# nagar
# constituency
#
# chennai
# ,
#
# fell
# vacant
# following
# jayalalithaa
# 's
# death
#
# december
# 2017.[54
# ]
#
# nomination
#
# rejected.[55
# ]
# vishal
#
# arrested
#
# police
#
# december
# 2018
#
# tried
#
# enter
# inside
#
# tamil
# film
# producers
# council
#
# nagar
# ,
# chennai
#
# forcefully
# trying
#
# break
#
# lock
# .
#
# council
#
# locked
#
# 300
# film
# producers
# alleging
#
# vishal
# failed
#
# fulfil
#
# promises
#
# elections
#
# 2015.[56
# ]
# vishal
# made
#
# debut
#
# playback
# singer
#
# madha
# gaja
# raja
# ,
#
# unreleased
# film
# directed
#
# sundar
# c
# ,
# crapping
#
# song
#
# dear
# loveru
# .

# %%
for word in spacy_doc:
    print(word.text,"----------->",word.pos_,word.tag_,spacy.explain(word.tag_))
# Out:
# vishal -----------> PROPN NNP noun, proper singular
# krishna -----------> PROPN NNP noun, proper singular
# reddy -----------> PROPN NNP noun, proper singular
# ( -----------> PUNCT -LRB- left round bracket
# born -----------> VERB VBN verb, past participle
# 29 -----------> NUM CD cardinal number
# august -----------> PROPN NNP noun, proper singular
# 1977),[1 -----------> NUM CD cardinal number
# ] -----------> PUNCT -RRB- right round bracket
# also -----------> ADV RB adverb
# known -----------> VERB VBN verb, past participle
#    -----------> SPACE _SP whitespace
# vishal -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
#      -----------> SPACE _SP whitespace
# indian -----------> PROPN NNP noun, proper singular
# actor -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# producer -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# works -----------> VERB VBZ verb, 3rd person singular present
#    -----------> SPACE _SP whitespace
# tamil -----------> PROPN NNP noun, proper singular
# cinema -----------> PROPN NNP noun, proper singular
# . -----------> PUNCT . punctuation mark, sentence closer
#    -----------> SPACE _SP whitespace
# younger -----------> ADJ JJR adjective, comparative
# son -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# producer -----------> PROPN NNP noun, proper singular
# g. -----------> PROPN NNP noun, proper singular
# k. -----------> PROPN NNP noun, proper singular
# reddy -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
# vishal -----------> PROPN NNP noun, proper singular
# studied -----------> VERB VBD verb, past tense
# visual -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# communications -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# loyola -----------> PROPN NNP noun, proper singular
# college -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
# chennai -----------> PROPN NNP noun, proper singular
# . -----------> PUNCT . punctuation mark, sentence closer
# best -----------> ADV RBS adverb, superlative
# known -----------> VERB VBN verb, past participle
#      -----------> SPACE _SP whitespace
# roles -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# action -----------> NOUN NN noun, singular or mass
# films -----------> NOUN NNS noun, plural
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# produces -----------> VERB VBZ verb, 3rd person singular present
# films -----------> NOUN NNS noun, plural
#      -----------> SPACE _SP whitespace
# production -----------> NOUN NN noun, singular or mass
# company -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# vishal -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# film -----------> NOUN NN noun, singular or mass
# factory.[2 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
# vishal -----------> NOUN NN noun, singular or mass
# made -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# entrance -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# industry -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# assistant -----------> NOUN NN noun, singular or mass
# director -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# arjun -----------> PROPN NNP noun, proper singular
# . -----------> PUNCT . punctuation mark, sentence closer
#      -----------> SPACE _SP whitespace
# became -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# actor -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# played -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# first -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# lead -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# role -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# romantic -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# thriller -----------> NOUN NN noun, singular or mass
# chellamae -----------> NOUN NN noun, singular or mass
# ( -----------> PUNCT -LRB- left round bracket
# 2004 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# going -----------> VERB VBG verb, gerund or present participle
#      -----------> SPACE _SP whitespace
# star -----------> PROPN NNP noun, proper singular
#      -----------> SPACE _SP whitespace
# commercially -----------> ADV RB adverb
# successful -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# action -----------> NOUN NN noun, singular or mass
# films -----------> NOUN NNS noun, plural
# sandakozhi -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
# thimiru -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
# thaamirabharani -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# malaikottai.[3 -----------> X XX unknown
# ] -----------> PUNCT -RRB- right round bracket
# following -----------> VERB VBG verb, gerund or present participle
#    -----------> SPACE _SP whitespace
# series -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# unsuccessful -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# films -----------> NOUN NNS noun, plural
#      -----------> SPACE _SP whitespace
# box -----------> NOUN NN noun, singular or mass
# office -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# vishal -----------> NOUN NN noun, singular or mass
# chose -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# create -----------> VERB VB verb, base form
#      -----------> SPACE _SP whitespace
# production -----------> NOUN NN noun, singular or mass
# studio -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# since -----------> SCONJ IN conjunction, subordinating or preposition
# produced -----------> VERB VBN verb, past participle
#    -----------> SPACE _SP whitespace
# worked -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# profitable -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# ventures -----------> NOUN NNS noun, plural
#      -----------> SPACE _SP whitespace
# pandiya -----------> PROPN NNP noun, proper singular
# naadu -----------> PROPN NNP noun, proper singular
# ( -----------> PUNCT -LRB- left round bracket
# 2013 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
# , -----------> PUNCT , punctuation mark, comma
# naan -----------> PROPN NNP noun, proper singular
# sigappu -----------> PROPN NNP noun, proper singular
# manithan -----------> PROPN NNP noun, proper singular
# ( -----------> PUNCT -LRB- left round bracket
# 2014 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# poojai -----------> NOUN NNS noun, plural
# ( -----------> PUNCT -LRB- left round bracket
# 2014).[4 -----------> NUM CD cardinal number
# ] -----------> PUNCT -RRB- right round bracket
# vishal -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#    -----------> SPACE _SP whitespace
# elected -----------> VERB VBN verb, past participle
#      -----------> SPACE _SP whitespace
# general -----------> PROPN NNP noun, proper singular
# secretary -----------> PROPN NNP noun, proper singular
#      -----------> SPACE _SP whitespace
# nadigar -----------> PROPN NNP noun, proper singular
# sangam -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# october -----------> PROPN NNP noun, proper singular
# 2015 -----------> NUM CD cardinal number
#    -----------> SPACE _SP whitespace
# initiating -----------> VERB VBG verb, gerund or present participle
#    -----------> SPACE _SP whitespace
# movement -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# previous -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# committee.[5 -----------> NOUN NN noun, singular or mass
# ] -----------> PUNCT -RRB- right round bracket
#      -----------> SPACE _SP whitespace
# expelled -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# tamil -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# film -----------> NOUN NN noun, singular or mass
# producers -----------> NOUN NNS noun, plural
# ' -----------> PART POS possessive ending
# council -----------> NOUN NN noun, singular or mass
# ( -----------> PUNCT -LRB- left round bracket
# tfpc -----------> NOUN NN noun, singular or mass
# ) -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# remarks -----------> VERB VBZ verb, 3rd person singular present
#      -----------> SPACE _SP whitespace
# council.[6][7 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
# later -----------> ADV RB adverb
#    -----------> SPACE _SP whitespace
# april -----------> PROPN NNP noun, proper singular
# 2017 -----------> NUM CD cardinal number
# , -----------> PUNCT , punctuation mark, comma
#        -----------> SPACE _SP whitespace
# election -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# got -----------> AUX VBD verb, past tense
# elected -----------> VERB VBN verb, past participle
#    -----------> SPACE _SP whitespace
# president -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# tamil -----------> PROPN NNP noun, proper singular
# film -----------> PROPN NNP noun, proper singular
# producers -----------> NOUN NNS noun, plural
# council -----------> PROPN NNP noun, proper singular
# . -----------> PUNCT . punctuation mark, sentence closer
# vishal -----------> PROPN NNP noun, proper singular
# krishna -----------> PROPN NNP noun, proper singular
# reddy -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# born -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# 29 -----------> NUM CD cardinal number
# august -----------> PROPN NNP noun, proper singular
# 1977[8][9 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#      -----------> SPACE _SP whitespace
# telugu -----------> VERB VBP verb, non-3rd person singular present
# family -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# chennai -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
# tamil -----------> PROPN NNP noun, proper singular
# nadu.[10 -----------> NOUN NN noun, singular or mass
# ] -----------> X XX unknown
#    -----------> SPACE _SP whitespace
# father -----------> PROPN NNP noun, proper singular
# gk -----------> PROPN NNP noun, proper singular
# reddy -----------> PROPN NNP noun, proper singular
#      -----------> SPACE _SP whitespace
# businessman -----------> PROPN NNP noun, proper singular
#      -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# producer -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# telugu -----------> VERB VBP verb, non-3rd person singular present
#    -----------> SPACE _SP whitespace
# tamil -----------> PROPN NNP noun, proper singular
# films.[11 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# elder -----------> ADJ JJR adjective, comparative
# brother -----------> NOUN NN noun, singular or mass
# vikram -----------> PROPN NNP noun, proper singular
# krishna -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# also -----------> ADV RB adverb
#    -----------> SPACE _SP whitespace
# actor -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# producer -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# produced -----------> VERB VBD verb, past tense
# several -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#    -----------> SPACE _SP whitespace
# vishal -----------> NOUN NN noun, singular or mass
# 's -----------> PART POS possessive ending
# films.[12 -----------> NOUN NN noun, singular or mass
# ] -----------> PUNCT -RRB- right round bracket
# vishal -----------> NOUN NN noun, singular or mass
# obtained -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# degree -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# visual -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# communications -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# loyola -----------> PROPN NNP noun, proper singular
# college -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# chennai.[13 -----------> NOUN NN noun, singular or mass
# ] -----------> PUNCT -RRB- right round bracket
# vishal -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# assisted -----------> VERB VBN verb, past participle
# actor -----------> NOUN NN noun, singular or mass
# - -----------> PUNCT HYPH punctuation mark, hyphen
# director -----------> NOUN NN noun, singular or mass
# arjun -----------> PROPN NNP noun, proper singular
# sarja -----------> PROPN NNP noun, proper singular
#      -----------> SPACE _SP whitespace
# venture -----------> PROPN NNP noun, proper singular
# vedham -----------> NOUN NN noun, singular or mass
# ( -----------> PUNCT -LRB- left round bracket
# 2001 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
# , -----------> PUNCT , punctuation mark, comma
#      -----------> SPACE _SP whitespace
# producer -----------> NOUN NN noun, singular or mass
# spotted -----------> VERB VBD verb, past tense
# vishal -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#      -----------> SPACE _SP whitespace
# sets -----------> NOUN NNS noun, plural
#      -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# signed -----------> VERB VBN verb, past participle
#      -----------> SPACE _SP whitespace
# appear -----------> VERB VBP verb, non-3rd person singular present
#      -----------> SPACE _SP whitespace
# acting -----------> VERB VBG verb, gerund or present participle
# role -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# gandhi -----------> PROPN NNP noun, proper singular
# krishna -----------> NOUN NNS noun, plural
# 's -----------> PART POS possessive ending
# chellamae -----------> NOUN NN noun, singular or mass
# ( -----------> PUNCT -LRB- left round bracket
# 2004).[14][15 -----------> NUM CD cardinal number
# ] -----------> PUNCT -RRB- right round bracket
# accepting -----------> VERB VBG verb, gerund or present participle
#    -----------> SPACE _SP whitespace
# role -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# vishal -----------> NOUN NN noun, singular or mass
# prepared -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# joining -----------> VERB VBG verb, gerund or present participle
# koothu -----------> NOUN NN noun, singular or mass
# - -----------> PUNCT HYPH punctuation mark, hyphen
# p -----------> NOUN NN noun, singular or mass
# - -----------> PUNCT HYPH punctuation mark, hyphen
# pattarai -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# hone -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# acting -----------> NOUN NN noun, singular or mass
# skills -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# played -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# protagonist -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# role -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# raghunandan -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
# whose -----------> DET WP$ wh-pronoun, possessive
# wife -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# kidnapped -----------> VERB VBD verb, past tense
#      -----------> SPACE _SP whitespace
# childhood -----------> NOUN NN noun, singular or mass
# friend.[15 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# critic -----------> NOUN NN noun, singular or mass
# described -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# performance -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# " -----------> PUNCT `` opening quotation mark
# apt -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# " -----------> PUNCT '' closing quotation mark
#    -----------> SPACE _SP whitespace
# " -----------> PUNCT `` opening quotation mark
# there -----------> ADV RB adverb
#    -----------> SPACE _SP whitespace
# plenty -----------> NOUN NN noun, singular or mass
# left -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# hone".[16][17 -----------> X XX unknown
# ] -----------> X XX unknown
#    -----------> SPACE _SP whitespace
# next -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# film -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# sandakozhi -----------> PROPN NNP noun, proper singular
# ( -----------> PUNCT -LRB- left round bracket
# 2005 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# n. -----------> PROPN NNP noun, proper singular
# linguswamy -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
#      -----------> SPACE _SP whitespace
# previously -----------> ADV RB adverb
# worked -----------> VERB VBD verb, past tense
#      -----------> SPACE _SP whitespace
# father -----------> NOUN NN noun, singular or mass
# 's -----------> PART POS possessive ending
# production -----------> NOUN NN noun, singular or mass
# house -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# assistant -----------> PROPN NNP noun, proper singular
# director.[18 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
# vishal -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#    -----------> SPACE _SP whitespace
# described -----------> VERB VBN verb, past participle
#      -----------> SPACE _SP whitespace
# " -----------> PUNCT `` opening quotation mark
# improved -----------> VERB VBN verb, past participle
#      -----------> SPACE _SP whitespace
# chellamae -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# days -----------> NOUN NNS noun, plural
# " -----------> PUNCT '' closing quotation mark
#    -----------> SPACE _SP whitespace
# " -----------> PUNCT `` opening quotation mark
# clicked -----------> VERB VBD verb, past tense
#      -----------> SPACE _SP whitespace
# action -----------> PROPN NNP noun, proper singular
# hero".[19 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
# film -----------> NOUN NN noun, singular or mass
# journalists -----------> NOUN NNS noun, plural
# stated -----------> VERB VBD verb, past tense
#        -----------> SPACE _SP whitespace
# " -----------> PUNCT `` opening quotation mark
# the -----------> DET DT determiner
# fastest -----------> ADJ JJS adjective, superlative
# rising -----------> VERB VBG verb, gerund or present participle
# action -----------> NOUN NN noun, singular or mass
# hero -----------> NOUN NN noun, singular or mass
# " -----------> PUNCT '' closing quotation mark
#      -----------> SPACE _SP whitespace
# time.[20 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#      -----------> SPACE _SP whitespace
# cameo -----------> PROPN NNP noun, proper singular
#        -----------> SPACE _SP whitespace
# sasi -----------> PROPN NNP noun, proper singular
# 's -----------> PART POS possessive ending
# dishyum -----------> NOUN NN noun, singular or mass
# ( -----------> PUNCT -LRB- left round bracket
# 2006 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# went -----------> VERB VBD verb, past tense
#      -----------> SPACE _SP whitespace
# appear -----------> VERB VBP verb, non-3rd person singular present
#    -----------> SPACE _SP whitespace
# tarun -----------> PROPN NNP noun, proper singular
# gopi -----------> PROPN NNP noun, proper singular
# 's -----------> PART POS possessive ending
# action -----------> NOUN NN noun, singular or mass
# film -----------> NOUN NN noun, singular or mass
# thimiru -----------> PROPN NNP noun, proper singular
# ( -----------> PUNCT -LRB- left round bracket
# 2006 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
# . -----------> PUNCT . punctuation mark, sentence closer
#    -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# opened -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# mixed -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# reviews -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# vishal -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#    -----------> SPACE _SP whitespace
# praised -----------> VERB VBD verb, past tense
#      -----------> SPACE _SP whitespace
# intense -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# performance -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# critic -----------> NOUN NN noun, singular or mass
# calling -----------> VERB VBG verb, gerund or present participle
#    -----------> SPACE _SP whitespace
# performance -----------> NOUN NN noun, singular or mass
# " -----------> PUNCT `` opening quotation mark
# the -----------> DET DT determiner
# film -----------> NOUN NN noun, singular or mass
# 's -----------> PART POS possessive ending
#    -----------> SPACE _SP whitespace
# strength -----------> NOUN NN noun, singular or mass
# and -----------> CCONJ CC conjunction, coordinating
# , -----------> PUNCT , punctuation mark, comma
#      -----------> SPACE _SP whitespace
# extent -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# making -----------> VERB VBG verb, gerund or present participle
#        -----------> SPACE _SP whitespace
# weak -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# script -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# poor -----------> PROPN NNP noun, proper singular
# characterisation".[21 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# became -----------> VERB VBD verb, past tense
# vishal -----------> NOUN NN noun, singular or mass
# 's -----------> PART POS possessive ending
# third -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# consecutive -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# commercial -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# success -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
#      -----------> SPACE _SP whitespace
# began -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# emerge -----------> VERB VB verb, base form
#    -----------> SPACE _SP whitespace
# tamil -----------> PROPN NNP noun, proper singular
# films.[22 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# next -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# film -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# political -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# action -----------> NOUN NN noun, singular or mass
# drama -----------> NOUN NN noun, singular or mass
# sivappathigaram -----------> NOUN NN noun, singular or mass
# ( -----------> PUNCT -LRB- left round bracket
# 2006 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
# , -----------> PUNCT , punctuation mark, comma
# directed -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# karu -----------> PROPN NNP noun, proper singular
# pazhaniappan -----------> PROPN NNP noun, proper singular
#      -----------> SPACE _SP whitespace
# failure -----------> NOUN NN noun, singular or mass
# financially -----------> ADV RB adverb
# despite -----------> SCONJ IN conjunction, subordinating or preposition
# favourable -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# reviews.[23 -----------> NOUN NN noun, singular or mass
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# next -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# film -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# released -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# january -----------> PROPN NNP noun, proper singular
# 2007 -----------> NUM CD cardinal number
# , -----------> PUNCT , punctuation mark, comma
# hari -----------> NOUN NN noun, singular or mass
# 's -----------> PART POS possessive ending
# multi -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# - -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# starring -----------> VERB VBG verb, gerund or present participle
# family -----------> NOUN NN noun, singular or mass
# action -----------> NOUN NN noun, singular or mass
# drama -----------> NOUN NN noun, singular or mass
# thaamirabharani -----------> PROPN NNP noun, proper singular
# ( -----------> PUNCT -LRB- left round bracket
# 2007 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
#      -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# went -----------> VERB VBD verb, past tense
#      -----------> SPACE _SP whitespace
# gain -----------> VERB VB verb, base form
# considerable -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# box -----------> NOUN NN noun, singular or mass
# office -----------> NOUN NN noun, singular or mass
# success -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# carrying -----------> VERB VBG verb, gerund or present participle
# good -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# reports -----------> NOUN NNS noun, plural
# amidst -----------> ADP IN conjunction, subordinating or preposition
#    -----------> SPACE _SP whitespace
# big -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# budget -----------> NOUN NN noun, singular or mass
# releases.[24][25 -----------> NOUN NN noun, singular or mass
# ] -----------> PUNCT -RRB- right round bracket
# later -----------> ADV RB adverb
#      -----------> SPACE _SP whitespace
# year -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# appeared -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# boopathy -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# pandian -----------> PROPN NNP noun, proper singular
# 's -----------> PART POS possessive ending
# malaikottai -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# ( -----------> PUNCT -LRB- left round bracket
# 2007 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# comedy -----------> NOUN NN noun, singular or mass
# entertainer -----------> NOUN NN noun, singular or mass
# . -----------> PUNCT . punctuation mark, sentence closer
#      -----------> SPACE _SP whitespace
# first -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# full -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# - -----------> PUNCT HYPH punctuation mark, hyphen
# length -----------> NOUN NN noun, singular or mass
# comic -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# role -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# vishal -----------> NOUN NN noun, singular or mass
# received -----------> VERB VBD verb, past tense
# mixed -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# feedback -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# portrayal -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# critics -----------> NOUN NNS noun, plural
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# rediff -----------> NOUN NN noun, singular or mass
# stating -----------> VERB VBG verb, gerund or present participle
#        -----------> SPACE _SP whitespace
# " -----------> PUNCT `` opening quotation mark
# a -----------> DET DT determiner
# far -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# cry -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# rather -----------> ADV RB adverb
# endearing -----------> VERB VBG verb, gerund or present participle
# young -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# man -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# sandakozhi -----------> PROPN NNP noun, proper singular
# " -----------> PUNCT '' closing quotation mark
# , -----------> PUNCT , punctuation mark, comma
# whilst -----------> SCONJ IN conjunction, subordinating or preposition
# describing -----------> VERB VBG verb, gerund or present participle
#    -----------> SPACE _SP whitespace
# performance -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# " -----------> PUNCT `` opening quotation mark
# cringe -----------> NOUN NN noun, singular or mass
# - -----------> PUNCT HYPH punctuation mark, hyphen
# able".[26 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
# behindwoods -----------> NOUN NNS noun, plural
# stated -----------> VERB VBD verb, past tense
#        -----------> SPACE _SP whitespace
# " -----------> PUNCT `` opening quotation mark
# average -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# masala -----------> NOUN NN noun, singular or mass
# - -----------> PUNCT HYPH punctuation mark, hyphen
# mix -----------> NOUN NN noun, singular or mass
# entertainer".[27 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# took -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# large -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# opening -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# declared -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# blockbuster -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# , -----------> PUNCT , punctuation mark, comma
# featuring -----------> VERB VBG verb, gerund or present participle
#      -----------> SPACE _SP whitespace
# top -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# 10 -----------> NUM CD cardinal number
#    -----------> SPACE _SP whitespace
# behindwoods -----------> NOUN NNS noun, plural
# box -----------> NOUN NN noun, singular or mass
# office -----------> NOUN NN noun, singular or mass
# . -----------> PUNCT . punctuation mark, sentence closer
#      -----------> SPACE _SP whitespace
# year -----------> PROPN NNP noun, proper singular
# 2008 -----------> NUM CD cardinal number
# , -----------> PUNCT , punctuation mark, comma
#      -----------> SPACE _SP whitespace
# first -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# time -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# vishal -----------> PROPN NNP noun, proper singular
# portrayed -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# police -----------> NOUN NN noun, singular or mass
# officer -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# sathyam -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# became -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# commercial -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# failure -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# box -----------> NOUN NN noun, singular or mass
# office -----------> NOUN NN noun, singular or mass
# . -----------> PUNCT . punctuation mark, sentence closer
#        -----------> SPACE _SP whitespace
# films -----------> NOUN NNS noun, plural
# thoranai -----------> NUM CD cardinal number
# ( -----------> PUNCT -LRB- left round bracket
# 2009 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# theeradha -----------> PROPN NNP noun, proper singular
# vilaiyattu -----------> PROPN NNP noun, proper singular
# pillai -----------> PROPN NNP noun, proper singular
# ( -----------> PUNCT -LRB- left round bracket
# 2010 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
#      -----------> SPACE _SP whitespace
# average -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# grossers -----------> NOUN NNS noun, plural
# . -----------> PUNCT . punctuation mark, sentence closer
# additionally -----------> ADV RB adverb
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# box -----------> NOUN NN noun, singular or mass
# - -----------> PUNCT HYPH punctuation mark, hyphen
# office -----------> NOUN NN noun, singular or mass
# duds -----------> NOUN NNS noun, plural
# , -----------> PUNCT , punctuation mark, comma
# sathyam -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# thoranai -----------> NUM CD cardinal number
# , -----------> PUNCT , punctuation mark, comma
#          -----------> SPACE _SP whitespace
# bilingual -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#    -----------> SPACE _SP whitespace
# tamil -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# telugu -----------> VERB VBP verb, non-3rd person singular present
# , -----------> PUNCT , punctuation mark, comma
# failed -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# establish -----------> VERB VB verb, base form
#    -----------> SPACE _SP whitespace
# popularity -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# telugu -----------> VERB VBP verb, non-3rd person singular present
# cinema.[28 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
# vishal -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#      -----------> SPACE _SP whitespace
# given -----------> VERB VBN verb, past participle
#    -----------> SPACE _SP whitespace
# opportunity -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# feature -----------> VERB VBP verb, non-3rd person singular present
#    -----------> SPACE _SP whitespace
# bala -----------> PROPN NNP noun, proper singular
# 's -----------> PART POS possessive ending
# dark -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# comedy -----------> NOUN NN noun, singular or mass
# avan -----------> PROPN NNP noun, proper singular
# ivan -----------> PROPN NNP noun, proper singular
# ( -----------> PUNCT -LRB- left round bracket
# 2011 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
# , -----------> PUNCT , punctuation mark, comma
#      -----------> SPACE _SP whitespace
# recommended -----------> VERB VBD verb, past tense
#      -----------> SPACE _SP whitespace
# director -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# friend -----------> NOUN NN noun, singular or mass
# arya -----------> NOUN NNS noun, plural
# . -----------> PUNCT . punctuation mark, sentence closer
# portraying -----------> VERB VBG verb, gerund or present participle
#    -----------> SPACE _SP whitespace
# village -----------> NOUN NN noun, singular or mass
# stage -----------> NOUN NN noun, singular or mass
# actor -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# squint -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
# vishal -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# severe -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# eye -----------> NOUN NN noun, singular or mass
# pain -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# headaches -----------> NOUN NNS noun, plural
# , -----------> PUNCT , punctuation mark, comma
#      -----------> SPACE _SP whitespace
# also -----------> ADV RB adverb
#      -----------> SPACE _SP whitespace
# serious -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# muscular -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# injury -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# sets.[29 -----------> NOUN NN noun, singular or mass
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# opened -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# mixed -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# reviews -----------> NOUN NNS noun, plural
# , -----------> PUNCT , punctuation mark, comma
# though -----------> SCONJ IN conjunction, subordinating or preposition
# vishal -----------> PROPN NNP noun, proper singular
# 's -----------> PART POS possessive ending
# performance -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# positive -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# reviews -----------> NOUN NNS noun, plural
# . -----------> PUNCT . punctuation mark, sentence closer
# indiaglitz -----------> PROPN NNP noun, proper singular
# stated -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# vishal -----------> NOUN NN noun, singular or mass
# delivered -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# " -----------> PUNCT `` opening quotation mark
# award -----------> NOUN NN noun, singular or mass
# winning -----------> VERB VBG verb, gerund or present participle
# performance -----------> NOUN NN noun, singular or mass
# " -----------> PUNCT '' closing quotation mark
#        -----------> SPACE _SP whitespace
# " -----------> PUNCT '' closing quotation mark
# mannerisms -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# body -----------> NOUN NN noun, singular or mass
# language -----------> NOUN NN noun, singular or mass
# give -----------> VERB VBP verb, non-3rd person singular present
#    -----------> SPACE _SP whitespace
# goosebumps -----------> NOUN NNS noun, plural
# " -----------> PUNCT '' closing quotation mark
# . -----------> PUNCT . punctuation mark, sentence closer
#    -----------> SPACE _SP whitespace
# reviewer -----------> VERB VBP verb, non-3rd person singular present
#    -----------> SPACE _SP whitespace
# cited -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# " -----------> PUNCT `` opening quotation mark
# vishal -----------> NOUN NN noun, singular or mass
# 's -----------> PART POS possessive ending
# spontaneous -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# response -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# mentor -----------> NOUN NN noun, singular or mass
# 's -----------> PART POS possessive ending
# death -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# movie -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# touching -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# . -----------> PUNCT . punctuation mark, sentence closer
#    -----------> SPACE _SP whitespace
# demonstration -----------> VERB VBP verb, non-3rd person singular present
#    -----------> SPACE _SP whitespace
# navarasas -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# front -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#    -----------> SPACE _SP whitespace
# actor -----------> PROPN NNP noun, proper singular
# suriya -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# melt -----------> VERB VBP verb, non-3rd person singular present
#      -----------> SPACE _SP whitespace
# tears".[30][31 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
# vishal -----------> NOUN NN noun, singular or mass
# played -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# role -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# police -----------> NOUN NN noun, singular or mass
# officer -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# following -----------> VERB VBG verb, gerund or present participle
# release -----------> NOUN NN noun, singular or mass
# vedi -----------> PROPN NNP noun, proper singular
# ( -----------> PUNCT -LRB- left round bracket
# 2011 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
# , -----------> PUNCT , punctuation mark, comma
# directed -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# prabhu -----------> PROPN NNP noun, proper singular
# deva -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
#      -----------> SPACE _SP whitespace
# declared -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# instant -----------> NOUN NN noun, singular or mass
# flop -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# box -----------> PROPN NNP noun, proper singular
# office.[32 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#      -----------> SPACE _SP whitespace
# 2013 -----------> NUM CD cardinal number
# film -----------> NOUN NN noun, singular or mass
# samar -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
# vishal -----------> PROPN NNP noun, proper singular
# played -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# forest -----------> PROPN NNP noun, proper singular
# trek -----------> PROPN NNP noun, proper singular
# guide -----------> NOUN NN noun, singular or mass
# . -----------> PUNCT . punctuation mark, sentence closer
# behindwoods -----------> NOUN NNS noun, plural
# stated -----------> VERB VBD verb, past tense
#      -----------> SPACE _SP whitespace
# " -----------> PUNCT `` opening quotation mark
# rocks -----------> VERB VBZ verb, 3rd person singular present
#      -----------> SPACE _SP whitespace
# action -----------> PROPN NNP noun, proper singular
# sequences".[33][34 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
# following -----------> VERB VBG verb, gerund or present participle
#    -----------> SPACE _SP whitespace
# cameo -----------> NOUN NN noun, singular or mass
# role -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# theeya -----------> PROPN NNP noun, proper singular
# velai -----------> PROPN NNP noun, proper singular
# seiyyanum -----------> PROPN NNP noun, proper singular
# kumaru -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# starred -----------> VERB VBN verb, past participle
#      -----------> SPACE _SP whitespace
# action -----------> NOUN NN noun, singular or mass
# films -----------> NOUN NNS noun, plural
# pattathu -----------> VERB VBP verb, non-3rd person singular present
# yaanai -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# pandiya -----------> PROPN NNP noun, proper singular
# naadu -----------> PROPN NNP noun, proper singular
# . -----------> PUNCT . punctuation mark, sentence closer
#    -----------> SPACE _SP whitespace
# latter -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#    -----------> SPACE _SP whitespace
# vishal -----------> NOUN NN noun, singular or mass
# 's -----------> PART POS possessive ending
# debut -----------> NOUN NN noun, singular or mass
# production -----------> NOUN NN noun, singular or mass
# venture.[35][36 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
# vishal -----------> NOUN NN noun, singular or mass
# opted -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# produce -----------> VERB VBP verb, non-3rd person singular present
#    -----------> SPACE _SP whitespace
# collaborate -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#    -----------> SPACE _SP whitespace
# thiru -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#      -----------> SPACE _SP whitespace
# third -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# venture -----------> NOUN NN noun, singular or mass
# naan -----------> PROPN NNP noun, proper singular
# sigappu -----------> PROPN NNP noun, proper singular
# manithan -----------> PROPN NNP noun, proper singular
# ( -----------> PUNCT -LRB- left round bracket
# 2014 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# revenge -----------> NOUN NN noun, singular or mass
# drama -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
#        -----------> SPACE _SP whitespace
# character -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# narcolepsy -----------> PROPN NNP noun, proper singular
# . -----------> PUNCT . punctuation mark, sentence closer
#    -----------> SPACE _SP whitespace
# prepare -----------> VERB VBP verb, non-3rd person singular present
#      -----------> SPACE _SP whitespace
# lead -----------> NOUN NN noun, singular or mass
# role -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# vishal -----------> PROPN NNP noun, proper singular
# read -----------> VERB VBD verb, past tense
#      -----------> SPACE _SP whitespace
# studied -----------> VERB VBD verb, past tense
# real -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# life -----------> NOUN NN noun, singular or mass
# case -----------> NOUN NN noun, singular or mass
# studies -----------> VERB VBZ verb, 3rd person singular present
#    -----------> SPACE _SP whitespace
# people -----------> NOUN NNS noun, plural
#      -----------> SPACE _SP whitespace
# disorder -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# citing -----------> VERB VBG verb, gerund or present participle
#          -----------> SPACE _SP whitespace
# references -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# cinema -----------> NOUN NN noun, singular or mass
# ...
#    -----------> SPACE _SP whitespace
# thupparivaalan -----------> PROPN NNP noun, proper singular
# directed -----------> VERB VBN verb, past participle
#    -----------> SPACE _SP whitespace
# mysskin -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# loosely -----------> ADV RB adverb
# based -----------> VERB VBN verb, past participle
#      -----------> SPACE _SP whitespace
# british -----------> PROPN NNP noun, proper singular
# writer -----------> PROPN NNP noun, proper singular
# arthur -----------> PROPN NNP noun, proper singular
# conan -----------> PROPN NNP noun, proper singular
# doyle -----------> PROPN NNP noun, proper singular
# 's -----------> PART POS possessive ending
# detective -----------> NOUN NN noun, singular or mass
# character -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# sherlock -----------> PROPN NNP noun, proper singular
# holmes -----------> PROPN NNP noun, proper singular
# . -----------> PUNCT . punctuation mark, sentence closer
#    -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# commercial -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# success -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# appreciated -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# audiences -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# critics.[41 -----------> NOUN NN noun, singular or mass
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# 2018 -----------> NUM CD cardinal number
# , -----------> PUNCT , punctuation mark, comma
# vishal -----------> VERB VBP verb, non-3rd person singular present
#    -----------> SPACE _SP whitespace
# two -----------> NUM CD cardinal number
# major -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# releases -----------> NOUN NNS noun, plural
# . -----------> PUNCT . punctuation mark, sentence closer
#    -----------> SPACE _SP whitespace
# first -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# one -----------> NUM CD cardinal number
#    -----------> SPACE _SP whitespace
# irumbu -----------> PROPN NNP noun, proper singular
# thirai -----------> PROPN NNP noun, proper singular
# directed -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# newcomer -----------> NOUN NN noun, singular or mass
# p. -----------> PROPN NNP noun, proper singular
# s. -----------> PROPN NNP noun, proper singular
# mithran -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# released -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# may -----------> AUX MD verb, modal auxiliary
# 2018.[42 -----------> NUM CD cardinal number
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# second -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#    -----------> SPACE _SP whitespace
# sandakozhi -----------> PROPN NNP noun, proper singular
# 2 -----------> NUM CD cardinal number
# released -----------> VERB VBN verb, past participle
#    -----------> SPACE _SP whitespace
# october -----------> PROPN NNP noun, proper singular
# 2018 -----------> NUM CD cardinal number
#    -----------> SPACE _SP whitespace
# written -----------> VERB VBN verb, past participle
#    -----------> SPACE _SP whitespace
# directed -----------> VERB VBN verb, past participle
#    -----------> SPACE _SP whitespace
# n. -----------> PROPN NNP noun, proper singular
# linguswamy -----------> PROPN NNP noun, proper singular
# . -----------> PUNCT . punctuation mark, sentence closer
#    -----------> SPACE _SP whitespace
# sequel -----------> VERB VBP verb, non-3rd person singular present
#      -----------> SPACE _SP whitespace
# successful -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# sandakozhi -----------> NOUN NN noun, singular or mass
# ( -----------> PUNCT -LRB- left round bracket
# 2005 -----------> NUM CD cardinal number
# ) -----------> PUNCT -RRB- right round bracket
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# stars -----------> NOUN NNS noun, plural
# vishal -----------> VERB VBP verb, non-3rd person singular present
#      -----------> SPACE _SP whitespace
# 25th -----------> PROPN NNP noun, proper singular
# film.[43 -----------> PROPN NNP noun, proper singular
# ] -----------> X XX unknown
#    -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# turned -----------> VERB VBD verb, past tense
#          -----------> SPACE _SP whitespace
# average -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# grosser.[44 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# 2019 -----------> NUM CD cardinal number
# , -----------> PUNCT , punctuation mark, comma
#      -----------> SPACE _SP whitespace
# one -----------> NUM CD cardinal number
# movie -----------> NOUN NN noun, singular or mass
# titled -----------> VERB VBN verb, past participle
# action -----------> NOUN NN noun, singular or mass
# directed -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# sundar -----------> NOUN NN noun, singular or mass
# c.[45 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
# received -----------> VERB VBD verb, past tense
# mixed -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# reviews -----------> NOUN NNS noun, plural
#        -----------> SPACE _SP whitespace
# box -----------> NOUN NN noun, singular or mass
# office -----------> NOUN NN noun, singular or mass
# failure.[46 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# 2021 -----------> NUM CD cardinal number
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# acted -----------> VERB VBD verb, past tense
#      -----------> SPACE _SP whitespace
# action -----------> NOUN NN noun, singular or mass
# thriller -----------> NOUN NN noun, singular or mass
# chakra -----------> PROPN NNP noun, proper singular
# directed -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# newcomer -----------> NOUN NN noun, singular or mass
# m.s -----------> PROPN NNP noun, proper singular
# anandan -----------> PROPN NNP noun, proper singular
# . -----------> PUNCT . punctuation mark, sentence closer
#    -----------> SPACE _SP whitespace
# film -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# released -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# 19 -----------> NUM CD cardinal number
# february -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
# received -----------> VERB VBD verb, past tense
# mixed -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# reviews -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# critics -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# audience.[47 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
#      -----------> SPACE _SP whitespace
# elected -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# president -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# tamil -----------> PROPN NNP noun, proper singular
# film -----------> NOUN NN noun, singular or mass
# producers -----------> PROPN NNPS noun, proper plural
# council -----------> PROPN NNP noun, proper singular
# election -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
#      -----------> SPACE _SP whitespace
# held -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# 2 -----------> NUM CD cardinal number
# april -----------> PROPN NNP noun, proper singular
# 2017.[48][49][50 -----------> NUM CD cardinal number
# ] -----------> PUNCT -RRB- right round bracket
# apart -----------> ADV RB adverb
#    -----------> SPACE _SP whitespace
# this -----------> PRON DT determiner
# , -----------> PUNCT , punctuation mark, comma
# vishal -----------> VERB VBP verb, non-3rd person singular present
#    -----------> SPACE _SP whitespace
# also -----------> ADV RB adverb
#    -----------> SPACE _SP whitespace
# staunch -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# advocate -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# online -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# piracy -----------> NOUN NN noun, singular or mass
# since -----------> SCONJ IN conjunction, subordinating or preposition
# 2014 -----------> NUM CD cardinal number
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# started -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# anti -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# - -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# piracy -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# cell.[51 -----------> NOUN NN noun, singular or mass
# ] -----------> PUNCT -RRB- right round bracket
#    -----------> SPACE _SP whitespace
# made -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# television -----------> PROPN NNP noun, proper singular
# début -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# october -----------> PROPN NNP noun, proper singular
# 2018 -----------> NUM CD cardinal number
#      -----------> SPACE _SP whitespace
# host -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# sun -----------> PROPN NNP noun, proper singular
# naam -----------> PROPN NNP noun, proper singular
# oruvar -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# talk -----------> NOUN NN noun, singular or mass
# show -----------> NOUN NN noun, singular or mass
# airing -----------> VERB VBG verb, gerund or present participle
#    -----------> SPACE _SP whitespace
# sun -----------> PROPN NNP noun, proper singular
# tv.[52][53 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
# vishal -----------> NOUN NN noun, singular or mass
# filed -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# nomination -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# independent -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# candidate -----------> NOUN NN noun, singular or mass
#      -----------> SPACE _SP whitespace
# by -----------> ADP IN conjunction, subordinating or preposition
# - -----------> PUNCT HYPH punctuation mark, hyphen
# poll -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
#    -----------> SPACE _SP whitespace
# radhakrishnan -----------> PROPN NNP noun, proper singular
# nagar -----------> PROPN NNP noun, proper singular
# constituency -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# chennai -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# fell -----------> VERB VBD verb, past tense
# vacant -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# following -----------> VERB VBG verb, gerund or present participle
# jayalalithaa -----------> NOUN NN noun, singular or mass
# 's -----------> PART POS possessive ending
# death -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# december -----------> PROPN NNP noun, proper singular
# 2017.[54 -----------> NUM CD cardinal number
# ] -----------> PUNCT -RRB- right round bracket
#      -----------> SPACE _SP whitespace
# nomination -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# rejected.[55 -----------> PROPN NNP noun, proper singular
# ] -----------> PUNCT -RRB- right round bracket
# vishal -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# arrested -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# police -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# december -----------> PROPN NNP noun, proper singular
# 2018 -----------> NUM CD cardinal number
#      -----------> SPACE _SP whitespace
# tried -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# enter -----------> VERB VB verb, base form
# inside -----------> ADP IN conjunction, subordinating or preposition
#    -----------> SPACE _SP whitespace
# tamil -----------> NOUN NN noun, singular or mass
# film -----------> NOUN NN noun, singular or mass
# producers -----------> PROPN NNPS noun, proper plural
# council -----------> PROPN NNP noun, proper singular
#      -----------> SPACE _SP whitespace
# nagar -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
# chennai -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# forcefully -----------> ADV RB adverb
# trying -----------> VERB VBG verb, gerund or present participle
#    -----------> SPACE _SP whitespace
# break -----------> VERB VB verb, base form
#    -----------> SPACE _SP whitespace
# lock -----------> NOUN NN noun, singular or mass
# . -----------> PUNCT . punctuation mark, sentence closer
#    -----------> SPACE _SP whitespace
# council -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# locked -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# 300 -----------> NUM CD cardinal number
# film -----------> NOUN NN noun, singular or mass
# producers -----------> NOUN NNS noun, plural
# alleging -----------> VERB VBG verb, gerund or present participle
#    -----------> SPACE _SP whitespace
# vishal -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# failed -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# fulfil -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# promises -----------> VERB VBZ verb, 3rd person singular present
#      -----------> SPACE _SP whitespace
# elections -----------> NOUN NNS noun, plural
#    -----------> SPACE _SP whitespace
# 2015.[56 -----------> NUM CD cardinal number
# ] -----------> PUNCT -RRB- right round bracket
# vishal -----------> NOUN NN noun, singular or mass
# made -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# debut -----------> PROPN NNP noun, proper singular
#      -----------> SPACE _SP whitespace
# playback -----------> PROPN NNP noun, proper singular
# singer -----------> PROPN NNP noun, proper singular
#    -----------> SPACE _SP whitespace
# madha -----------> PROPN NNP noun, proper singular
# gaja -----------> PROPN NNP noun, proper singular
# raja -----------> PROPN NNP noun, proper singular
# , -----------> PUNCT , punctuation mark, comma
#    -----------> SPACE _SP whitespace
# unreleased -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# film -----------> NOUN NN noun, singular or mass
# directed -----------> VERB VBD verb, past tense
#    -----------> SPACE _SP whitespace
# sundar -----------> NOUN NN noun, singular or mass
# c -----------> NOUN NN noun, singular or mass
# , -----------> PUNCT , punctuation mark, comma
# crapping -----------> VERB VBG verb, gerund or present participle
#        -----------> SPACE _SP whitespace
# song -----------> NOUN NN noun, singular or mass
#    -----------> SPACE _SP whitespace
# dear -----------> ADJ JJ adjective (English), other noun-modifier (Chinese)
# loveru -----------> PROPN NNP noun, proper singular
# . -----------> PUNCT . punctuation mark, sentence closer

# %%
from spacy import displacy

# %%
displacy.render(spacy_doc,style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="af54210e777c41179561d4de57f6a796-0" class="displacy" width="210750" height="1362.0" direction="ltr" style="max-width: none; height: 1362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">vishal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">krishna</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">reddy (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">born</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">29</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">august</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">1977),[1]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">known</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">vishal,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">    </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">indian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">actor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">film</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">producer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">works</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">tamil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">cinema.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">younger</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">son</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">film</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">producer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">g.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">k.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">reddy,</tspan>
#     <

# %%
for token in spacy_doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# vishal vishal PROPN NNP compound xxxx True False
# krishna krishna PROPN NNP compound xxxx True False
# reddy reddy PROPN NNP nsubj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# born bear VERB VBN ROOT xxxx True False
# 29 29 NUM CD nummod dd False False
# august august PROPN NNP npadvmod xxxx True False
# 1977),[1 1977),[1 NUM CD nummod dddd),[d False False
# ] ] PUNCT -RRB- punct ] False False
# also also ADV RB advmod xxxx True True
# known know VERB VBN dep xxxx True False
#       SPACE _SP dep    False False
# vishal vishal PROPN NNP dobj xxxx True False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# indian indian PROPN NNP compound xxxx True False
# actor actor PROPN NNP compound xxxx True False
#       SPACE _SP dep    False False
# film film NOUN NN compound xxxx True False
# producer producer NOUN NN nsubj xxxx True False
#       SPACE _SP dep    False False
# works work VERB VBZ ccomp xxxx True False
#       SPACE _SP dep    False False
# tamil tamil PROPN NNP compound xxxx True False
# cinema cinema PROPN NNP dobj xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# younger young ADJ JJR amod xxxx True False
# son son NOUN NN nmod xxx True False
#       SPACE _SP dep    False False
# film film NOUN NN compound xxxx True False
# producer producer PROPN NNP compound xxxx True False
# g. g. PROPN NNP compound x. False False
# k. k. PROPN NNP compound x. False False
# reddy reddy PROPN NNP nsubj xxxx True False
# , , PUNCT , punct , False False
# vishal vishal PROPN NNP appos xxxx True False
# studied study VERB VBD ROOT xxxx True False
# visual visual ADJ JJ amod xxxx True False
# communications communication NOUN NNS dobj xxxx True False
#       SPACE _SP dep    False False
# loyola loyola PROPN NNP compound xxxx True False
# college college PROPN NNP appos xxxx True False
# , , PUNCT , punct , False False
# chennai chennai PROPN NNP appos xxxx True False
# . . PUNCT . punct . False False
# best well ADV RBS advmod xxxx True False
# known know VERB VBN amod xxxx True False
#           SPACE _SP dep      False False
# roles role NOUN NNS nsubj xxxx True False
#       SPACE _SP dep    False False
# action action NOUN NN compound xxxx True False
# films film NOUN NNS appos xxxx True False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# produces produce VERB VBZ ROOT xxxx True False
# films film NOUN NNS compound xxxx True False
#           SPACE _SP dep      False False
# production production NOUN NN compound xxxx True False
# company company NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# vishal vishal ADJ JJ amod xxxx True False
# film film NOUN NN nmod xxxx True False
# factory.[2 factory.[2 PROPN NNP npadvmod xxxx.[d False False
# ] ] PUNCT -RRB- punct ] False False
# vishal vishal NOUN NN nsubj xxxx True False
# made make VERB VBD ccomp xxxx True True
#       SPACE _SP dep    False False
# entrance entrance NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# film film NOUN NN compound xxxx True False
# industry industry NOUN NN nmod xxxx True False
#           SPACE _SP dep      False False
# assistant assistant NOUN NN compound xxxx True False
# director director NOUN NN dobj xxxx True False
#       SPACE _SP dep    False False
# arjun arjun PROPN NNP appos xxxx True False
# . . PUNCT . punct . False False
#           SPACE _SP dep      False False
# became become VERB VBD ccomp xxxx True True
#       SPACE _SP dep    False False
# actor actor NOUN NN appos xxxx True False
#       SPACE _SP dep    False False
# played play VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# first first ADJ JJ amod xxxx True True
# lead lead ADJ JJ amod xxxx True False
# role role NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# romantic romantic ADJ JJ amod xxxx True False
# thriller thriller NOUN NN compound xxxx True False
# chellamae chellamae NOUN NN dobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2004 2004 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# going go VERB VBG advcl xxxx True False
#           SPACE _SP dep      False False
# star star PROPN NNP compound xxxx True False
#           SPACE _SP dep      False False
# commercially commercially ADV RB advmod xxxx True False
# successful successful ADJ JJ amod xxxx True False
# action action NOUN NN compound xxxx True False
# films film NOUN NNS dobj xxxx True False
# sandakozhi sandakozhi PROPN NNP amod xxxx True False
# , , PUNCT , punct , False False
# thimiru thimiru PROPN NNP conj xxxx True False
# , , PUNCT , punct , False False
# thaamirabharani thaamirabharani PROPN NNP appos xxxx True False
#       SPACE _SP dep    False False
# malaikottai.[3 malaikottai.[3 X XX appos xxxx.[d False False
# ] ] PUNCT -RRB- punct ] False False
# following follow VERB VBG prep xxxx True False
#       SPACE _SP dep    False False
# series series PROPN NNP nmod xxxx True False
#       SPACE _SP dep    False False
# unsuccessful unsuccessful ADJ JJ amod xxxx True False
# films film NOUN NNS dobj xxxx True False
#           SPACE _SP dep      False False
# box box NOUN NN compound xxx True False
# office office NOUN NN appos xxxx True False
# , , PUNCT , punct , False False
# vishal vishal NOUN NN nsubj xxxx True False
# chose choose VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# create create VERB VB xcomp xxxx True False
#           SPACE _SP dep      False False
# production production NOUN NN compound xxxx True False
# studio studio NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# since since SCONJ IN mark xxxx True True
# produced produce VERB VBN advcl xxxx True False
#       SPACE _SP dep    False False
# worked work VERB VBD conj xxxx True False
#       SPACE _SP dep    False False
# profitable profitable ADJ JJ amod xxxx True False
# ventures venture NOUN NNS dobj xxxx True False
#           SPACE _SP dep      False False
# pandiya pandiya PROPN NNP compound xxxx True False
# naadu naadu PROPN NNP appos xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2013 2013 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
# naan naan PROPN NNP compound xxxx True False
# sigappu sigappu PROPN NNP compound xxxx True False
# manithan manithan PROPN NNP conj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2014 2014 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
#       SPACE _SP dep    False False
# poojai poojai NOUN NNS nsubj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2014).[4 2014).[4 NUM CD npadvmod dddd).[d False False
# ] ] PUNCT -RRB- punct ] False False
# vishal vishal ADJ JJ appos xxxx True False
#       SPACE _SP dep    False False
# elected elect VERB VBN amod xxxx True False
#           SPACE _SP dep      False False
# general general PROPN NNP compound xxxx True False
# secretary secretary PROPN NNP compound xxxx True False
#           SPACE _SP dep      False False
# nadigar nadigar PROPN NNP compound xxxx True False
# sangam sangam PROPN NNP npadvmod xxxx True False
#       SPACE _SP dep    False False
# october october PROPN NNP appos xxxx True False
# 2015 2015 NUM CD nummod dddd False False
#       SPACE _SP dep    False False
# initiating initiate VERB VBG acl xxxx True False
#       SPACE _SP dep    False False
# movement movement NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# previous previous ADJ JJ amod xxxx True False
# committee.[5 committee.[5 NOUN NN dobj xxxx.[d False False
# ] ] PUNCT -RRB- punct ] False False
#           SPACE _SP dep      False False
# expelled expel VERB VBD acl xxxx True False
#       SPACE _SP dep    False False
# tamil tamil ADJ JJ compound xxxx True False
# film film NOUN NN compound xxxx True False
# producers producer NOUN NNS poss xxxx True False
# ' ' PART POS case ' False False
# council council NOUN NN nmod xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# tfpc tfpc NOUN NN appos xxxx True False
# ) ) PUNCT -RRB- punct ) False False
#       SPACE _SP dep    False False
# remarks remark VERB VBZ ROOT xxxx True False
#           SPACE _SP dep      False False
# council.[6][7 council.[6][7 PROPN NNP dobj xxxx.[d][d False False
# ] ] PUNCT -RRB- punct ] False False
# later later ADV RB advmod xxxx True False
#       SPACE _SP dep    False False
# april april PROPN NNP npadvmod xxxx True False
# 2017 2017 NUM CD nummod dddd False False
# , , PUNCT , punct , False False
#               SPACE _SP dep      False False
# election election NOUN NN nsubjpass xxxx True False
#       SPACE _SP dep    False False
# got got AUX VBD auxpass xxx True False
# elected elect VERB VBN ccomp xxxx True False
#       SPACE _SP dep    False False
# president president PROPN NNP compound xxxx True False
#       SPACE _SP dep    False False
# tamil tamil PROPN NNP compound xxxx True False
# film film PROPN NNP compound xxxx True False
# producers producer NOUN NNS compound xxxx True False
# council council PROPN NNP oprd xxxx True False
# . . PUNCT . punct . False False
# vishal vishal PROPN NNP compound xxxx True False
# krishna krishna PROPN NNP compound xxxx True False
# reddy reddy PROPN NNP nsubj xxxx True False
#       SPACE _SP dep    False False
# born bear VERB VBD advcl xxxx True False
#       SPACE _SP dep    False False
# 29 29 NUM CD nummod dd False False
# august august PROPN NNP nmod xxxx True False
# 1977[8][9 1977[8][9 PROPN NNP nummod dddd[d][d False False
# ] ] PUNCT -RRB- punct ] False False
#           SPACE _SP dep      False False
# telugu telugu VERB VBP ccomp xxxx True False
# family family PROPN NNP dobj xxxx True False
#       SPACE _SP dep    False False
# chennai chennai PROPN NNP dobj xxxx True False
# , , PUNCT , punct , False False
# tamil tamil PROPN NNP punct xxxx True False
# nadu.[10 nadu.[10 NOUN NN npadvmod xxxx.[dd False False
# ] ] X XX punct ] False False
#       SPACE _SP dep    False False
# father father PROPN NNP compound xxxx True False
# gk gk PROPN NNP compound xx True False
# reddy reddy PROPN NNP dobj xxxx True False
#           SPACE _SP dep      False False
# businessman businessman PROPN NNP compound xxxx True False
#           SPACE _SP dep      False False
# film film NOUN NN compound xxxx True False
# producer producer PROPN NNP appos xxxx True False
#       SPACE _SP dep    False False
# telugu telugu VERB VBP conj xxxx True False
#       SPACE _SP dep    False False
# tamil tamil PROPN NNP compound xxxx True False
# films.[11 films.[11 PROPN NNP dobj xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# elder eld ADJ JJR amod xxxx True False
# brother brother NOUN NN compound xxxx True False
# vikram vikram PROPN NNP compound xxxx True False
# krishna krishna PROPN NNP dobj xxxx True False
#       SPACE _SP dep    False False
# also also ADV RB advmod xxxx True True
#       SPACE _SP dep    False False
# actor actor NOUN NN nmod xxxx True False
#       SPACE _SP dep    False False
# producer producer NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# produced produce VERB VBD conj xxxx True False
# several several ADJ JJ amod xxxx True True
#       SPACE _SP dep    False False
# vishal vishal NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# films.[12 films.[12 NOUN NN nmod xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
# vishal vishal NOUN NN dobj xxxx True False
# obtained obtain VERB VBD acl xxxx True False
#       SPACE _SP dep    False False
# degree degree NOUN NN nmod xxxx True False
#       SPACE _SP dep    False False
# visual visual ADJ JJ amod xxxx True False
# communications communication NOUN NNS dobj xxxx True False
#       SPACE _SP dep    False False
# loyola loyola PROPN NNP compound xxxx True False
# college college NOUN NN appos xxxx True False
# , , PUNCT , punct , False False
# chennai.[13 chennai.[13 NOUN NN nmod xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
# vishal vishal ADJ JJ compound xxxx True False
# assisted assist VERB VBN amod xxxx True False
# actor actor NOUN NN compound xxxx True False
# - - PUNCT HYPH punct - False False
# director director NOUN NN compound xxxx True False
# arjun arjun PROPN NNP compound xxxx True False
# sarja sarja PROPN NNP compound xxxx True False
#           SPACE _SP dep      False False
# venture venture PROPN NNP compound xxxx True False
# vedham vedham NOUN NN npadvmod xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2001 2001 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# producer producer NOUN NN nsubj xxxx True False
# spotted spot VERB VBD ccomp xxxx True False
# vishal vishal ADJ JJ amod xxxx True False
#           SPACE _SP dep      False False
# sets set NOUN NNS compound xxxx True False
#           SPACE _SP dep      False False
# film film NOUN NN nsubj xxxx True False
#       SPACE _SP dep    False False
# signed sign VERB VBN amod xxxx True False
#           SPACE _SP dep      False False
# appear appear VERB VBP ccomp xxxx True False
#           SPACE _SP dep      False False
# acting act VERB VBG amod xxxx True False
# role role NOUN NN oprd xxxx True False
#       SPACE _SP dep    False False
# gandhi gandhi PROPN NNP nmod xxxx True False
# krishna krishna NOUN NNS poss xxxx True False
# 's 's PART POS case 'x False True
# chellamae chellamae NOUN NN appos xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2004).[14][15 2004).[14][15 NUM CD appos dddd).[dd][dd False False
# ] ] PUNCT -RRB- punct ] False False
# accepting accept VERB VBG acl xxxx True False
#       SPACE _SP dep    False False
# role role NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# vishal vishal NOUN NN nsubj xxxx True False
# prepared prepare VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# joining join VERB VBG xcomp xxxx True False
# koothu koothu NOUN NN nmod xxxx True False
# - - PUNCT HYPH punct - False False
# p p NOUN NN compound x True False
# - - PUNCT HYPH punct - False False
# pattarai pattarai NOUN NN nmod xxxx True False
#       SPACE _SP dep    False False
# hone hone NOUN NN nmod xxxx True False
#       SPACE _SP dep    False False
# acting acting NOUN NN amod xxxx True False
# skills skill NOUN NNS dobj xxxx True False
#       SPACE _SP dep    False False
# played play VERB VBD conj xxxx True False
#       SPACE _SP dep    False False
# protagonist protagonist ADJ JJ amod xxxx True False
# role role NOUN NN dobj xxxx True False
#       SPACE _SP dep    False False
# raghunandan raghunandan PROPN NNP dobj xxxx True False
# , , PUNCT , punct , False False
# whose whose DET WP$ poss xxxx True True
# wife wife NOUN NN nsubj xxxx True False
#       SPACE _SP dep    False False
# kidnapped kidnap VERB VBD relcl xxxx True False
#           SPACE _SP dep      False False
# childhood childhood NOUN NN compound xxxx True False
# friend.[15 friend.[15 PROPN NNP dobj xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# critic critic NOUN NN nsubj xxxx True False
# described describe VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# performance performance NOUN NN compound xxxx True False
#       SPACE _SP dep    False False
# " " PUNCT `` punct " False False
# apt apt ADJ JJ amod xxx True False
# " " PUNCT '' punct " False False
#       SPACE _SP dep    False False
# " " PUNCT `` punct " False False
# there there ADV RB advmod xxxx True True
#       SPACE _SP dep    False False
# plenty plenty NOUN NN appos xxxx True False
# left leave VERB VBD acl xxxx True False
#       SPACE _SP dep    False False
# hone".[16][17 hone".[16][17 X XX oprd xxxx".[dd][dd False False
# ] ] X XX dobj ] False False
#       SPACE _SP dep    False False
# next next ADJ JJ amod xxxx True True
# film film NOUN NN oprd xxxx True False
#       SPACE _SP dep    False False
# sandakozhi sandakozhi PROPN NNP appos xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2005 2005 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
#       SPACE _SP dep    False False
# n. n. PROPN NNP compound x. False False
# linguswamy linguswamy PROPN NNP appos xxxx True False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# previously previously ADV RB advmod xxxx True False
# worked work VERB VBD ccomp xxxx True False
#           SPACE _SP dep      False False
# father father NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# production production NOUN NN compound xxxx True False
# house house NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# assistant assistant PROPN NNP nmod xxxx True False
# director.[18 director.[18 PROPN NNP nmod xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
# vishal vishal ADJ JJ nmod xxxx True False
#       SPACE _SP dep    False False
# described describe VERB VBN amod xxxx True False
#           SPACE _SP dep      False False
# " " PUNCT `` punct " False False
# improved improve VERB VBN amod xxxx True False
#           SPACE _SP dep      False False
# chellamae chellamae ADJ JJ amod xxxx True False
# days day NOUN NNS nmod xxxx True False
# " " PUNCT '' punct " False False
#       SPACE _SP dep    False False
# " " PUNCT `` punct " False False
# clicked click VERB VBD dep xxxx True False
#           SPACE _SP dep      False False
# action action PROPN NNP compound xxxx True False
# hero".[19 hero".[19 PROPN NNP nmod xxxx".[dd False False
# ] ] PUNCT -RRB- punct ] False False
# film film NOUN NN compound xxxx True False
# journalists journalist NOUN NNS nsubj xxxx True False
# stated state VERB VBD ccomp xxxx True False
#               SPACE _SP dep      False False
# " " PUNCT `` punct " False False
# the the DET DT det xxx True True
# fastest fast ADJ JJS amod xxxx True False
# rising rise VERB VBG amod xxxx True False
# action action NOUN NN nmod xxxx True False
# hero hero NOUN NN nmod xxxx True False
# " " PUNCT '' punct " False False
#           SPACE _SP dep      False False
# time.[20 time.[20 PROPN NNP appos xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#           SPACE _SP dep      False False
# cameo cameo PROPN NNP compound xxxx True False
#               SPACE _SP dep      False False
# sasi sasi PROPN NNP poss xxxx True False
# 's 's PART POS case 'x False True
# dishyum dishyum NOUN NN appos xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2006 2006 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# went go VERB VBD ROOT xxxx True False
#           SPACE _SP dep      False False
# appear appear VERB VBP dep xxxx True False
#       SPACE _SP dep    False False
# tarun tarun PROPN NNP compound xxxx True False
# gopi gopi PROPN NNP poss xxxx True False
# 's 's PART POS case 'x False True
# action action NOUN NN compound xxxx True False
# film film NOUN NN compound xxxx True False
# thimiru thimiru PROPN NNP oprd xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2006 2006 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# film film NOUN NN nsubj xxxx True False
# opened open VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# mixed mixed ADJ JJ amod xxxx True False
# reviews review NOUN NNS dobj xxxx True False
#       SPACE _SP dep    False False
# vishal vishal ADJ JJ amod xxxx True False
#       SPACE _SP dep    False False
# praised praise VERB VBD amod xxxx True False
#           SPACE _SP dep      False False
# intense intense ADJ JJ amod xxxx True False
# performance performance NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# critic critic NOUN NN dobj xxxx True False
# calling call VERB VBG acl xxxx True False
#       SPACE _SP dep    False False
# performance performance NOUN NN dobj xxxx True False
# " " PUNCT `` punct " False False
# the the DET DT det xxx True True
# film film NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
#       SPACE _SP dep    False False
# strength strength NOUN NN oprd xxxx True False
# and and CCONJ CC cc xxx True True
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# extent extent NOUN NN conj xxxx True False
# , , PUNCT , punct , False False
# making make VERB VBG advcl xxxx True False
#               SPACE _SP dep      False False
# weak weak ADJ JJ amod xxxx True False
# script script PROPN NNP compound xxxx True False
#       SPACE _SP dep    False False
# poor poor PROPN NNP amod xxxx True False
# characterisation".[21 characterisation".[21 PROPN NNP dobj xxxx".[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# film film NOUN NN nsubj xxxx True False
# became become VERB VBD conj xxxx True True
# vishal vishal NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# third third ADJ JJ amod xxxx True True
# consecutive consecutive ADJ JJ amod xxxx True False
# commercial commercial ADJ JJ amod xxxx True False
# success success NOUN NN attr xxxx True False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# began begin VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# emerge emerge VERB VB xcomp xxxx True False
#       SPACE _SP dep    False False
# tamil tamil PROPN NNP amod xxxx True False
# films.[22 films.[22 PROPN NNP npadvmod xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# next next ADJ JJ amod xxxx True True
# film film NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# political political ADJ JJ amod xxxx True False
# action action NOUN NN compound xxxx True False
# drama drama NOUN NN compound xxxx True False
# sivappathigaram sivappathigaram NOUN NN appos xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2006 2006 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
# directed direct VERB VBD conj xxxx True False
#       SPACE _SP dep    False False
# karu karu PROPN NNP compound xxxx True False
# pazhaniappan pazhaniappan PROPN NNP compound xxxx True False
#           SPACE _SP dep      False False
# failure failure NOUN NN dobj xxxx True False
# financially financially ADV RB advmod xxxx True False
# despite despite SCONJ IN prep xxxx True False
# favourable favourable ADJ JJ amod xxxx True False
# reviews.[23 reviews.[23 NOUN NN pobj xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# next next ADJ JJ amod xxxx True True
# film film NOUN NN npadvmod xxxx True False
#       SPACE _SP dep    False False
# released release VERB VBD conj xxxx True False
#       SPACE _SP dep    False False
# january january PROPN NNP dobj xxxx True False
# 2007 2007 NUM CD nummod dddd False False
# , , PUNCT , punct , False False
# hari hari NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# multi multi ADJ JJ amod xxxx True False
# - - ADJ JJ amod - False False
# starring star VERB VBG amod xxxx True False
# family family NOUN NN compound xxxx True False
# action action NOUN NN compound xxxx True False
# drama drama NOUN NN compound xxxx True False
# thaamirabharani thaamirabharani PROPN NNP nsubj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2007 2007 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
#           SPACE _SP dep      False False
# film film NOUN NN nsubj xxxx True False
# went go VERB VBD ROOT xxxx True False
#           SPACE _SP dep      False False
# gain gain VERB VB advcl xxxx True False
# considerable considerable ADJ JJ amod xxxx True False
# box box NOUN NN compound xxx True False
# office office NOUN NN compound xxxx True False
# success success NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# carrying carry VERB VBG advcl xxxx True False
# good good ADJ JJ amod xxxx True False
# reports report NOUN NNS dobj xxxx True False
# amidst amidst ADP IN prep xxxx True False
#       SPACE _SP dep    False False
# big big ADJ JJ amod xxx True False
# budget budget NOUN NN compound xxxx True False
# releases.[24][25 releases.[24][25 NOUN NN pobj xxxx.[dd][dd False False
# ] ] PUNCT -RRB- punct ] False False
# later later ADV RB advmod xxxx True False
#           SPACE _SP dep      False False
# year year NOUN NN npadvmod xxxx True False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# appeared appear VERB VBD conj xxxx True False
#       SPACE _SP dep    False False
# boopathy boopathy ADJ JJ amod xxxx True False
# pandian pandian PROPN NNP poss xxxx True False
# 's 's PART POS case 'x False True
# malaikottai malaikottai ADJ JJ oprd xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2007 2007 NUM CD npadvmod dddd False False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# comedy comedy NOUN NN compound xxxx True False
# entertainer entertainer NOUN NN conj xxxx True False
# . . PUNCT . punct . False False
#           SPACE _SP dep      False False
# first first ADJ JJ amod xxxx True True
# full full ADJ JJ amod xxxx True True
# - - PUNCT HYPH punct - False False
# length length NOUN NN nmod xxxx True False
# comic comic ADJ JJ amod xxxx True False
# role role NOUN NN nsubj xxxx True False
# , , PUNCT , punct , False False
# vishal vishal NOUN NN nsubj xxxx True False
# received receive VERB VBD ccomp xxxx True False
# mixed mixed ADJ JJ amod xxxx True False
# feedback feedback NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# portrayal portrayal PROPN NNP compound xxxx True False
#       SPACE _SP dep    False False
# critics critic NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# rediff rediff NOUN NN dep xxxx True False
# stating state VERB VBG acl xxxx True False
#               SPACE _SP dep      False False
# " " PUNCT `` punct " False False
# a a DET DT det x True True
# far far ADJ JJ amod xxx True False
# cry cry NOUN NN compound xxx True False
#           SPACE _SP dep      False False
# rather rather ADV RB advmod xxxx True True
# endearing endear VERB VBG acl xxxx True False
# young young ADJ JJ amod xxxx True False
# man man NOUN NN dobj xxx True False
#       SPACE _SP dep    False False
# sandakozhi sandakozhi PROPN NNP appos xxxx True False
# " " PUNCT '' punct " False False
# , , PUNCT , punct , False False
# whilst whilst SCONJ IN mark xxxx True False
# describing describe VERB VBG pcomp xxxx True False
#       SPACE _SP dep    False False
# performance performance NOUN NN nmod xxxx True False
#       SPACE _SP dep    False False
# " " PUNCT `` punct " False False
# cringe cringe NOUN NN nmod xxxx True False
# - - PUNCT HYPH punct - False False
# able".[26 able".[26 PROPN NNP nmod xxxx".[dd False False
# ] ] PUNCT -RRB- punct ] False False
# behindwoods behindwood NOUN NNS dobj xxxx True False
# stated state VERB VBD advcl xxxx True False
#               SPACE _SP dep      False False
# " " PUNCT `` punct " False False
# average average ADJ JJ amod xxxx True False
# masala masala NOUN NN compound xxxx True False
# - - PUNCT HYPH punct - False False
# mix mix NOUN NN compound xxx True False
# entertainer".[27 entertainer".[27 PROPN NNP dobj xxxx".[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# film film NOUN NN nsubj xxxx True False
# took take VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# large large ADJ JJ amod xxxx True False
# opening opening NOUN NN amod xxxx True False
#           SPACE _SP dep      False False
# declared declare VERB VBD acl xxxx True False
#       SPACE _SP dep    False False
# blockbuster blockbuster ADJ JJ ccomp xxxx True False
# , , PUNCT , punct , False False
# featuring feature VERB VBG advcl xxxx True False
#           SPACE _SP dep      False False
# top top ADJ JJ amod xxx True True
# 10 10 NUM CD nummod dd False False
#       SPACE _SP dep    False False
# behindwoods behindwood NOUN NNS compound xxxx True False
# box box NOUN NN compound xxx True False
# office office NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
#           SPACE _SP dep      False False
# year year PROPN NNP npadvmod xxxx True False
# 2008 2008 NUM CD nummod dddd False False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# first first ADJ JJ amod xxxx True True
# time time NOUN NN npadvmod xxxx True False
# , , PUNCT , punct , False False
# vishal vishal PROPN NNP nsubj xxxx True False
# portrayed portray VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# police police NOUN NN compound xxxx True False
# officer officer NOUN NN dobj xxxx True False
#       SPACE _SP dep    False False
# sathyam sathyam PROPN NNP appos xxxx True False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# became become VERB VBD ROOT xxxx True True
#       SPACE _SP dep    False False
# commercial commercial ADJ JJ amod xxxx True False
# failure failure NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# box box NOUN NN compound xxx True False
# office office NOUN NN attr xxxx True False
# . . PUNCT . punct . False False
#               SPACE _SP dep      False False
# films film NOUN NNS ROOT xxxx True False
# thoranai thoranai NUM CD xcomp xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2009 2009 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
#       SPACE _SP dep    False False
# theeradha theeradha PROPN NNP compound xxxx True False
# vilaiyattu vilaiyattu PROPN NNP compound xxxx True False
# pillai pillai PROPN NNP appos xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2010 2010 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
#           SPACE _SP dep      False False
# average average ADJ JJ amod xxxx True False
# grossers grosser NOUN NNS appos xxxx True False
# . . PUNCT . punct . False False
# additionally additionally ADV RB advmod xxxx True False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# box box NOUN NN compound xxx True False
# - - PUNCT HYPH punct - False False
# office office NOUN NN compound xxxx True False
# duds dud NOUN NNS nsubj xxxx True False
# , , PUNCT , punct , False False
# sathyam sathyam PROPN NNP appos xxxx True False
#       SPACE _SP dep    False False
# thoranai thoranai NUM CD appos xxxx True False
# , , PUNCT , punct , False False
#                   SPACE _SP dep      False False
# bilingual bilingual ADJ JJ amod xxxx True False
#       SPACE _SP dep    False False
# tamil tamil NOUN NNS appos xxxx True False
#       SPACE _SP dep    False False
# telugu telugu VERB VBP appos xxxx True False
# , , PUNCT , punct , False False
# failed fail VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# establish establish VERB VB ccomp xxxx True False
#       SPACE _SP dep    False False
# popularity popularity NOUN NN dobj xxxx True False
#       SPACE _SP dep    False False
# telugu telugu VERB VBP advcl xxxx True False
# cinema.[28 cinema.[28 PROPN NNP dobj xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
# vishal vishal ADJ JJ amod xxxx True False
#           SPACE _SP dep      False False
# given give VERB VBN advcl xxxx True False
#       SPACE _SP dep    False False
# opportunity opportunity NOUN NN compound xxxx True False
#       SPACE _SP dep    False False
# feature feature VERB VBP compound xxxx True False
#       SPACE _SP dep    False False
# bala bala PROPN NNP poss xxxx True False
# 's 's PART POS case 'x False True
# dark dark ADJ JJ amod xxxx True False
# comedy comedy NOUN NN compound xxxx True False
# avan avan PROPN NNP compound xxxx True False
# ivan ivan PROPN NNP dobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2011 2011 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# recommended recommend VERB VBD ROOT xxxx True False
#           SPACE _SP dep      False False
# director director NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# friend friend NOUN NN compound xxxx True False
# arya arya NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False
# portraying portray VERB VBG csubj xxxx True False
#       SPACE _SP dep    False False
# village village NOUN NN compound xxxx True False
# stage stage NOUN NN compound xxxx True False
# actor actor NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# squint squint PROPN NNP dobj xxxx True False
# , , PUNCT , punct , False False
# vishal vishal VERB VBD advcl xxxx True False
#       SPACE _SP dep    False False
# severe severe ADJ JJ amod xxxx True False
# eye eye NOUN NN compound xxx True False
# pain pain NOUN NN dobj xxxx True False
#       SPACE _SP dep    False False
# headaches headache NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# also also ADV RB advmod xxxx True True
#           SPACE _SP dep      False False
# serious serious ADJ JJ amod xxxx True True
# muscular muscular ADJ JJ amod xxxx True False
# injury injury NOUN NN compound xxxx True False
#       SPACE _SP dep    False False
# sets.[29 sets.[29 NOUN NN dobj xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# film film NOUN NN nsubj xxxx True False
# opened open VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# mixed mixed ADJ JJ amod xxxx True False
# reviews review NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# though though SCONJ IN mark xxxx True True
# vishal vishal PROPN NNP poss xxxx True False
# 's 's PART POS case 'x False True
# performance performance NOUN NN nsubj xxxx True False
#       SPACE _SP dep    False False
# positive positive ADJ JJ amod xxxx True False
# reviews review NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False
# indiaglitz indiaglitz PROPN NNP nsubj xxxx True False
# stated state VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# vishal vishal NOUN NN nsubj xxxx True False
# delivered deliver VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# " " PUNCT `` punct " False False
# award award NOUN NN npadvmod xxxx True False
# winning win VERB VBG amod xxxx True False
# performance performance NOUN NN nmod xxxx True False
# " " PUNCT '' punct " False False
#               SPACE _SP dep      False False
# " " PUNCT '' punct " False False
# mannerisms mannerism NOUN NNS nmod xxxx True False
#       SPACE _SP dep    False False
# body body NOUN NN compound xxxx True False
# language language NOUN NN dobj xxxx True False
# give give VERB VBP ccomp xxxx True True
#       SPACE _SP dep    False False
# goosebumps goosebump NOUN NNS dobj xxxx True False
# " " PUNCT '' punct " False False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# reviewer reviewer VERB VBP nsubj xxxx True False
#       SPACE _SP dep    False False
# cited cite VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# " " PUNCT `` punct " False False
# vishal vishal NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# spontaneous spontaneous ADJ JJ amod xxxx True False
# response response NOUN NN nmod xxxx True False
#           SPACE _SP dep      False False
# mentor mentor NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# death death NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# movie movie NOUN NN appos xxxx True False
#       SPACE _SP dep    False False
# touching touching ADJ JJ ccomp xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# demonstration demonstration VERB VBP nsubj xxxx True False
#       SPACE _SP dep    False False
# navarasas navarasa NOUN NNS dep xxxx True False
#       SPACE _SP dep    False False
# front front ADJ JJ amod xxxx True True
#       SPACE _SP dep    False False
# actor actor PROPN NNP compound xxxx True False
# suriya suriya PROPN NNP appos xxxx True False
#       SPACE _SP dep    False False
# melt melt VERB VBP ccomp xxxx True False
#           SPACE _SP dep      False False
# tears".[30][31 tears".[30][31 PROPN NNP punct xxxx".[dd][dd False False
# ] ] PUNCT -RRB- punct ] False False
# vishal vishal NOUN NN nsubj xxxx True False
# played play VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# role role NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# police police NOUN NN compound xxxx True False
# officer officer NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# following follow VERB VBG amod xxxx True False
# release release NOUN NN compound xxxx True False
# vedi vedi PROPN NNP dobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2011 2011 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
# directed direct VERB VBD conj xxxx True False
#       SPACE _SP dep    False False
# prabhu prabhu PROPN NNP compound xxxx True False
# deva deva PROPN NNP dobj xxxx True False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# declared declare VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# instant instant NOUN NN compound xxxx True False
# flop flop NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# box box PROPN NNP nmod xxx True False
# office.[32 office.[32 PROPN NNP nmod xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#           SPACE _SP dep      False False
# 2013 2013 NUM CD nummod dddd False False
# film film NOUN NN compound xxxx True False
# samar samar PROPN NNP dobj xxxx True False
# , , PUNCT , punct , False False
# vishal vishal PROPN NNP nsubj xxxx True False
# played play VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# forest forest PROPN NNP compound xxxx True False
# trek trek PROPN NNP compound xxxx True False
# guide guide NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# behindwoods behindwood NOUN NNS nsubj xxxx True False
# stated state VERB VBD ROOT xxxx True False
#           SPACE _SP dep      False False
# " " PUNCT `` punct " False False
# rocks rock VERB VBZ compound xxxx True False
#           SPACE _SP dep      False False
# action action PROPN NNP dobj xxxx True False
# sequences".[33][34 sequences".[33][34 PROPN NNP punct xxxx".[dd][dd False False
# ] ] PUNCT -RRB- punct ] False False
# following follow VERB VBG prep xxxx True False
#       SPACE _SP dep    False False
# cameo cameo NOUN NN compound xxxx True False
# role role NOUN NN pobj xxxx True False
#       SPACE _SP dep    False False
# theeya theeya PROPN NNP compound xxxx True False
# velai velai PROPN NNP compound xxxx True False
# seiyyanum seiyyanum PROPN NNP compound xxxx True False
# kumaru kumaru PROPN NNP nsubj xxxx True False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# starred star VERB VBN amod xxxx True False
#           SPACE _SP dep      False False
# action action NOUN NN compound xxxx True False
# films film NOUN NNS appos xxxx True False
# pattathu pattathu VERB VBP ROOT xxxx True False
# yaanai yaanai PROPN NNP dobj xxxx True False
#       SPACE _SP dep    False False
# pandiya pandiya PROPN NNP compound xxxx True False
# naadu naadu PROPN NNP appos xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# latter latter ADJ JJ amod xxxx True True
#       SPACE _SP dep    False False
# vishal vishal NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# debut debut NOUN NN compound xxxx True False
# production production NOUN NN compound xxxx True False
# venture.[35][36 venture.[35][36 PROPN NNP nmod xxxx.[dd][dd False False
# ] ] PUNCT -RRB- punct ] False False
# vishal vishal NOUN NN nsubj xxxx True False
# opted opt VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# produce produce VERB VBP ccomp xxxx True False
#       SPACE _SP dep    False False
# collaborate collaborate ADJ JJ amod xxxx True False
#       SPACE _SP dep    False False
# thiru thiru ADJ JJ amod xxxx True False
#           SPACE _SP dep      False False
# third third ADJ JJ amod xxxx True True
# venture venture NOUN NN compound xxxx True False
# naan naan PROPN NNP compound xxxx True False
# sigappu sigappu PROPN NNP compound xxxx True False
# manithan manithan PROPN NNP dobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2014 2014 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# revenge revenge NOUN NN compound xxxx True False
# drama drama NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
#               SPACE _SP dep      False False
# character character NOUN NN appos xxxx True False
#       SPACE _SP dep    False False
# narcolepsy narcolepsy PROPN NNP appos xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# prepare prepare VERB VBP ROOT xxxx True False
#           SPACE _SP dep      False False
# lead lead NOUN NN compound xxxx True False
# role role NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# vishal vishal PROPN NNP nsubj xxxx True False
# read read VERB VBD amod xxxx True False
#           SPACE _SP dep      False False
# studied study VERB VBD ccomp xxxx True False
# real real ADJ JJ amod xxxx True False
# life life NOUN NN compound xxxx True False
# case case NOUN NN nsubj xxxx True False
# studies study VERB VBZ ccomp xxxx True False
#       SPACE _SP dep    False False
# people people NOUN NNS compound xxxx True False
#           SPACE _SP dep      False False
# disorder disorder NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# citing cite VERB VBG advcl xxxx True False
#                   SPACE _SP dep      False False
# references reference NOUN NNS dobj xxxx True False
#       SPACE _SP dep    False False
# cinema cinema NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# could could AUX MD aux xxxx True True
# watch watch VERB VB ccomp xxxx True False
#       SPACE _SP dep    False False
# learn learn VERB VB ccomp xxxx True False
# . . PUNCT . punct . False False
#               SPACE _SP dep      False False
# acted act VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# director director PROPN NNP compound xxxx True False
# hari hari PROPN NNP nmod xxxx True False
#           SPACE _SP dep      False False
# second second PROPN NNP amod xxxx True False
# time time NOUN NN dobj xxxx True False
#       SPACE _SP dep    False False
# poojai poojai PROPN NNP appos xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2014 2014 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# somewhat somewhat ADV RB advmod xxxx True False
# good good ADJ JJ amod xxxx True False
# business business NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# box box NOUN NN compound xxx True False
# office office NOUN NN appos xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# 2015 2015 NUM CD appos dddd False False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# acted act VERB VBD ccomp xxxx True False
# two two NUM CD nummod xxx True True
# films film NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# namely namely ADV RB advmod xxxx True True
# , , PUNCT , punct , False False
# aambala aambala PROPN NNP compound xxxx True False
#       SPACE _SP dep    False False
# paayum paayum PROPN NNP compound xxxx True False
# puli.[37][38 puli.[37][38 PROPN NNP dep xxxx.[dd][dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# 2016 2016 NUM CD appos dddd False False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# appeared appear VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# three three NUM CD nummod xxxx True True
# movies movie NOUN NNS dobj xxxx True False
# ; ; PUNCT : punct ; False False
# kathakali kathakali PROPN NNP oprd xxxx True False
# , , PUNCT , punct , False False
# marudhu marudhu PROPN NNP compound xxxx True False
#       SPACE _SP dep    False False
# kaththi kaththi PROPN NNP compound xxxx True False
# sandai sandai PROPN NNP appos xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# first first ADJ JJ amod xxxx True True
# two two NUM CD nummod xxx True True
#       SPACE _SP dep    False False
# average average ADJ JJ amod xxxx True False
# grossers grosser NOUN NNS nsubj xxxx True False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# kaththi kaththi PROPN NNP compound xxxx True False
# sandai sandai PROPN NNP nsubj xxxx True False
# became become VERB VBD ROOT xxxx True True
#       SPACE _SP dep    False False
# flop flop NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# box box NOUN NN compound xxx True False
# office office NOUN NN attr xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# january january PROPN NNP npadvmod xxxx True False
# 2017 2017 NUM CD nummod dddd False False
# , , PUNCT , punct , False False
# vishal vishal NOUN NN nsubj xxxx True False
# signed sign VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# debut debut PROPN NNP compound xxxx True False
# malayalam malayalam PROPN NNP compound xxxx True False
# film film PROPN NNP dobj xxxx True False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# main main ADJ JJ amod xxxx True False
# antagonist antagonist NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# mohanlal mohanlal PROPN NNP compound xxxx True False
# - - PUNCT HYPH punct - False False
# starrer starrer NOUN NN compound xxxx True False
# villain villain NOUN NN appos xxxx True False
# , , PUNCT , punct , False False
# directed direct VERB VBD conj xxxx True False
#       SPACE _SP dep    False False
# b. b. PROPN NNP compound x. False False
# unnikrishnan.[39][40 unnikrishnan.[39][40 PROPN NNP dobj xxxx.[dd][dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# september september PROPN NNP appos xxxx True False
# 2017 2017 NUM CD nummod dddd False False
# , , PUNCT , punct , False False
# vishal vishal PROPN NNP nsubj xxxx True False
# played play VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# detective detective ADJ JJ dep xxxx True False
#       SPACE _SP dep    False False
# thupparivaalan thupparivaalan PROPN NNP npadvmod xxxx True False
# directed direct VERB VBN amod xxxx True False
#       SPACE _SP dep    False False
# mysskin mysskin NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# loosely loosely ADV RB advmod xxxx True False
# based base VERB VBN amod xxxx True False
#           SPACE _SP dep      False False
# british british PROPN NNP compound xxxx True False
# writer writer PROPN NNP compound xxxx True False
# arthur arthur PROPN NNP compound xxxx True False
# conan conan PROPN NNP compound xxxx True False
# doyle doyle PROPN NNP poss xxxx True False
# 's 's PART POS case 'x False True
# detective detective NOUN NN compound xxxx True False
# character character NOUN NN nsubj xxxx True False
# , , PUNCT , punct , False False
# sherlock sherlock PROPN NNP compound xxxx True False
# holmes holmes PROPN NNP appos xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# film film NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# commercial commercial ADJ JJ amod xxxx True False
# success success NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# appreciated appreciate VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# audiences audience NOUN NNS dobj xxxx True False
#       SPACE _SP dep    False False
# critics.[41 critics.[41 NOUN NN npadvmod xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# 2018 2018 NUM CD appos dddd False False
# , , PUNCT , punct , False False
# vishal vishal VERB VBP conj xxxx True False
#       SPACE _SP dep    False False
# two two NUM CD nummod xxx True True
# major major ADJ JJ amod xxxx True False
# releases release NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# first first ADJ JJ advmod xxxx True True
# one one NUM CD nummod xxx True True
#       SPACE _SP dep    False False
# irumbu irumbu PROPN NNP compound xxxx True False
# thirai thirai PROPN NNP nsubj xxxx True False
# directed direct VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# newcomer newcomer NOUN NN compound xxxx True False
# p. p. PROPN NNP compound x. False False
# s. s. PROPN NNP compound x. False False
# mithran mithran PROPN NNP npadvmod xxxx True False
#       SPACE _SP dep    False False
# released release VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# may may AUX MD aux xxx True True
# 2018.[42 2018.[42 NUM CD nummod dddd.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# second second ADJ JJ amod xxxx True False
#       SPACE _SP dep    False False
# sandakozhi sandakozhi PROPN NNP appos xxxx True False
# 2 2 NUM CD nummod d False False
# released release VERB VBN ccomp xxxx True False
#       SPACE _SP dep    False False
# october october PROPN NNP npadvmod xxxx True False
# 2018 2018 NUM CD nummod dddd False False
#       SPACE _SP dep    False False
# written write VERB VBN advcl xxxx True False
#       SPACE _SP dep    False False
# directed direct VERB VBN amod xxxx True False
#       SPACE _SP dep    False False
# n. n. PROPN NNP compound x. False False
# linguswamy linguswamy PROPN NNP dobj xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# sequel sequel VERB VBP amod xxxx True False
#           SPACE _SP dep      False False
# successful successful ADJ JJ amod xxxx True False
# sandakozhi sandakozhi NOUN NN nsubj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2005 2005 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# film film NOUN NN compound xxxx True False
# stars star NOUN NNS compound xxxx True False
# vishal vishal VERB VBP compound xxxx True False
#           SPACE _SP dep      False False
# 25th 25th PROPN NNP compound ddxx False False
# film.[43 film.[43 PROPN NNP appos xxxx.[dd False False
# ] ] X XX punct ] False False
#       SPACE _SP dep    False False
# film film NOUN NN nsubj xxxx True False
# turned turn VERB VBD ccomp xxxx True False
#                   SPACE _SP dep      False False
# average average ADJ JJ amod xxxx True False
# grosser.[44 grosser.[44 PROPN NNP npadvmod xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# 2019 2019 NUM CD npadvmod dddd False False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# one one NUM CD nummod xxx True True
# movie movie NOUN NN appos xxxx True False
# titled title VERB VBN acl xxxx True False
# action action NOUN NN oprd xxxx True False
# directed direct VERB VBD acl xxxx True False
#       SPACE _SP dep    False False
# sundar sundar NOUN NN nmod xxxx True False
# c.[45 c.[45 PROPN NNP appos x.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# film film NOUN NN nsubj xxxx True False
# received receive VERB VBD ccomp xxxx True False
# mixed mixed ADJ JJ amod xxxx True False
# reviews review NOUN NNS compound xxxx True False
#               SPACE _SP dep      False False
# box box NOUN NN compound xxx True False
# office office NOUN NN compound xxxx True False
# failure.[46 failure.[46 PROPN NNP dobj xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# 2021 2021 NUM CD npadvmod dddd False False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# acted act VERB VBD ROOT xxxx True False
#           SPACE _SP dep      False False
# action action NOUN NN compound xxxx True False
# thriller thriller NOUN NN compound xxxx True False
# chakra chakra PROPN NNP nsubj xxxx True False
# directed direct VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# newcomer newcomer NOUN NN compound xxxx True False
# m.s m.s PROPN NNP compound x.x False False
# anandan anandan PROPN NNP dobj xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# film film NOUN NN nsubj xxxx True False
#       SPACE _SP dep    False False
# released release VERB VBD relcl xxxx True False
#       SPACE _SP dep    False False
# 19 19 NUM CD nummod dd False False
# february february PROPN NNP npadvmod xxxx True False
# , , PUNCT , punct , False False
# received receive VERB VBD ccomp xxxx True False
# mixed mixed ADJ JJ amod xxxx True False
# reviews review NOUN NNS dobj xxxx True False
#       SPACE _SP dep    False False
# critics critic NOUN NNS dobj xxxx True False
#       SPACE _SP dep    False False
# audience.[47 audience.[47 PROPN NNP appos xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#           SPACE _SP dep      False False
# elected elect VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# president president PROPN NNP compound xxxx True False
#       SPACE _SP dep    False False
# tamil tamil PROPN NNP compound xxxx True False
# film film NOUN NN compound xxxx True False
# producers producers PROPN NNPS compound xxxx True False
# council council PROPN NNP compound xxxx True False
# election election NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
#           SPACE _SP dep      False False
# held hold VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# 2 2 NUM CD nummod d False False
# april april PROPN NNP npadvmod xxxx True False
# 2017.[48][49][50 2017.[48][49][50 NUM CD nummod dddd.[dd][dd][dd False False
# ] ] PUNCT -RRB- punct ] False False
# apart apart ADV RB advmod xxxx True False
#       SPACE _SP dep    False False
# this this PRON DT dobj xxxx True True
# , , PUNCT , punct , False False
# vishal vishal VERB VBP dep xxxx True False
#       SPACE _SP dep    False False
# also also ADV RB advmod xxxx True True
#       SPACE _SP dep    False False
# staunch staunch ADJ JJ amod xxxx True False
# advocate advocate NOUN NN compound xxxx True False
#       SPACE _SP dep    False False
# online online ADJ JJ amod xxxx True False
# piracy piracy NOUN NN dobj xxxx True False
# since since SCONJ IN prep xxxx True True
# 2014 2014 NUM CD pobj dddd False False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# started start VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# anti anti ADJ JJ amod xxxx True False
# - - ADJ JJ amod - False False
# piracy piracy ADJ JJ amod xxxx True False
# cell.[51 cell.[51 NOUN NN dobj xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#       SPACE _SP dep    False False
# made make VERB VBD dep xxxx True True
#       SPACE _SP dep    False False
# television television PROPN NNP compound xxxx True False
# début début PROPN NNP nmod xxxx True False
#       SPACE _SP dep    False False
# october october PROPN NNP nmod xxxx True False
# 2018 2018 NUM CD nummod dddd False False
#           SPACE _SP dep      False False
# host host NOUN NN nmod xxxx True False
#       SPACE _SP dep    False False
# sun sun PROPN NNP compound xxx True False
# naam naam PROPN NNP compound xxxx True False
# oruvar oruvar NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# talk talk NOUN NN compound xxxx True False
# show show NOUN NN conj xxxx True True
# airing air VERB VBG acl xxxx True False
#       SPACE _SP dep    False False
# sun sun PROPN NNP nmod xxx True False
# tv.[52][53 tv.[52][53 PROPN NNP punct xx.[dd][dd False False
# ] ] PUNCT -RRB- punct ] False False
# vishal vishal NOUN NN dobj xxxx True False
# filed file VERB VBD acl xxxx True False
#       SPACE _SP dep    False False
# nomination nomination NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# independent independent ADJ JJ amod xxxx True False
# candidate candidate NOUN NN compound xxxx True False
#           SPACE _SP dep      False False
# by by ADP IN prep xx True True
# - - PUNCT HYPH punct - False False
# poll poll ADJ JJ amod xxxx True False
#       SPACE _SP dep    False False
# radhakrishnan radhakrishnan PROPN NNP compound xxxx True False
# nagar nagar PROPN NNP compound xxxx True False
# constituency constituency PROPN NNP appos xxxx True False
#       SPACE _SP dep    False False
# chennai chennai PROPN NNP appos xxxx True False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# fell fall VERB VBD ccomp xxxx True False
# vacant vacant ADJ JJ oprd xxxx True False
# following follow VERB VBG amod xxxx True False
# jayalalithaa jayalalithaa NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# death death NOUN NN pobj xxxx True False
#       SPACE _SP dep    False False
# december december PROPN NNP nmod xxxx True False
# 2017.[54 2017.[54 NUM CD nummod dddd.[dd False False
# ] ] PUNCT -RRB- punct ] False False
#           SPACE _SP dep      False False
# nomination nomination NOUN NN nmod xxxx True False
#       SPACE _SP dep    False False
# rejected.[55 rejected.[55 PROPN NNP nmod xxxx.[dd False False
# ] ] PUNCT -RRB- punct ] False False
# vishal vishal NOUN NN npadvmod xxxx True False
#       SPACE _SP dep    False False
# arrested arrest VERB VBD relcl xxxx True False
#       SPACE _SP dep    False False
# police police NOUN NNS dobj xxxx True False
#       SPACE _SP dep    False False
# december december PROPN NNP npadvmod xxxx True False
# 2018 2018 NUM CD nummod dddd False False
#           SPACE _SP dep      False False
# tried try VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# enter enter VERB VB ccomp xxxx True False
# inside inside ADP IN prep xxxx True False
#       SPACE _SP dep    False False
# tamil tamil NOUN NN compound xxxx True False
# film film NOUN NN compound xxxx True False
# producers producers PROPN NNPS compound xxxx True False
# council council PROPN NNP compound xxxx True False
#           SPACE _SP dep      False False
# nagar nagar PROPN NNP pobj xxxx True False
# , , PUNCT , punct , False False
# chennai chennai PROPN NNP compound xxxx True False
#       SPACE _SP dep    False False
# forcefully forcefully ADV RB advmod xxxx True False
# trying try VERB VBG advcl xxxx True False
#       SPACE _SP dep    False False
# break break VERB VB xcomp xxxx True False
#       SPACE _SP dep    False False
# lock lock NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP dep    False False
# council council PROPN NNP nmod xxxx True False
#       SPACE _SP dep    False False
# locked lock VERB VBD ROOT xxxx True False
#       SPACE _SP dep    False False
# 300 300 NUM CD nummod ddd False False
# film film NOUN NN compound xxxx True False
# producers producer NOUN NNS nsubj xxxx True False
# alleging allege VERB VBG acl xxxx True False
#       SPACE _SP dep    False False
# vishal vishal ADJ JJ dobj xxxx True False
# failed fail VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# fulfil fulfil PROPN NNP compound xxxx True False
#       SPACE _SP dep    False False
# promises promise VERB VBZ ccomp xxxx True False
#           SPACE _SP dep      False False
# elections election NOUN NNS dobj xxxx True False
#       SPACE _SP dep    False False
# 2015.[56 2015.[56 NUM CD npadvmod dddd.[dd False False
# ] ] PUNCT -RRB- punct ] False False
# vishal vishal NOUN NN nsubj xxxx True False
# made make VERB VBD ccomp xxxx True True
#       SPACE _SP dep    False False
# debut debut PROPN NNP compound xxxx True False
#           SPACE _SP dep      False False
# playback playback PROPN NNP compound xxxx True False
# singer singer PROPN NNP compound xxxx True False
#       SPACE _SP dep    False False
# madha madha PROPN NNP compound xxxx True False
# gaja gaja PROPN NNP compound xxxx True False
# raja raja PROPN NNP dobj xxxx True False
# , , PUNCT , punct , False False
#       SPACE _SP dep    False False
# unreleased unreleased ADJ JJ amod xxxx True False
# film film NOUN NN nsubj xxxx True False
# directed direct VERB VBD ccomp xxxx True False
#       SPACE _SP dep    False False
# sundar sundar NOUN NN compound xxxx True False
# c c NOUN NN dobj x True False
# , , PUNCT , punct , False False
# crapping crap VERB VBG advcl xxxx True False
#               SPACE _SP dep      False False
# song song NOUN NN dobj xxxx True False
#       SPACE _SP dep    False False
# dear dear ADJ JJ compound xxxx True False
# loveru loveru PROPN NNP appos xxxx True False
# . . PUNCT . punct . False False
